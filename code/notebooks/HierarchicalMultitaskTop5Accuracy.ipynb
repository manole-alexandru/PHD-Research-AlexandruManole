# %% [markdown]
# # Import

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from thop) (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->thop)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->thop)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->thop)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->thop)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->thop)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->thop)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->thop) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 thop-0.1.1.post2209072238

# %%
import torchvision
import json
import os
import shutil
from google.colab.patches import cv2_imshow
import numpy as np
import math
import pickle
from torch.utils.data import random_split, DataLoader
import torch.optim as optim
import torch
import torch.nn as nn
from thop import profile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
EPOCHS = 25
DEVICE = 'cuda' # 'cpu'
EXP_NO = 69
LR = 3e-4
DROPOUT = 0.25
MAX_LR = 1e-3
LOSS_WEIGHTS = [1, 0.2] # [0.9, 0.1] # [0.2, 0.8] [0.5, 0.5]
BASE_DIR = f'/content/drive/MyDrive/New Exps/SamplesH/{EXP_NO}/'

MODEL_NAME = 'convnext_base'

DATASET = 'StandfordCars' # cifar100, INaturalist, Places365, ImageNet, StandfordCars
AUGMENTATION = True # False

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()

os.makedirs(os.path.dirname(BASE_DIR), exist_ok=True)

# %%
EXPERIMENT_DICTIONARY = {
    'EPOCHS': EPOCHS,
    'DEVICE': DEVICE,
    'EXP_NO': EXP_NO,
    'MODEL': MODEL_NAME,
    'LR': LR,
    'DROPOUT': DROPOUT,
    'LOSS_FUNCTION': str(criterion),
    'OPTIMIZER': str(optim.Adam),
    'MAX_LR': MAX_LR,
    'LOSS_WEIGHTS': LOSS_WEIGHTS,
    'DATASET': DATASET,
    'AUGMENTATION': AUGMENTATION
}

with open(BASE_DIR + "exp_info.json", "w") as outfile:
    json.dump(EXPERIMENT_DICTIONARY, outfile)

# %%
if MODEL_NAME == 'mobilenet_v3_small':
  MODEL = torchvision.models.mobilenet_v3_small
elif MODEL_NAME == 'mobilenet_v3_large':
  MODEL = torchvision.models.mobilenet_v3_large
elif MODEL_NAME == 'resnet18':
  MODEL = torchvision.models.resnet18
elif MODEL_NAME == 'resnet50':
  MODEL = torchvision.models.resnet50
elif MODEL_NAME == 'swin_b':
  MODEL = torchvision.models.swin_s
elif MODEL_NAME == 'vgg16':
  MODEL = torchvision.models.vgg16
elif MODEL_NAME == 'vgg19':
  MODEL = torchvision.models.vgg19
elif MODEL_NAME == 'densenet121':
  MODEL = torchvision.models.densenet121
elif MODEL_NAME == 'vit_b_16':
  MODEL = torchvision.models.vit_b_16
elif MODEL_NAME == 'efficientnet_b0':
  MODEL = torchvision.models.efficientnet_b0
elif MODEL_NAME == 'maxvit_t':
  MODEL = torchvision.models.maxvit_t
elif MODEL_NAME == 'convnext_base':
  MODEL = torchvision.models.convnext_base

# %% [markdown]
# # Dataset

# %%
transform2 = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),  # Resize to 224x224 to match MobileNet's input size
    torchvision.transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize with ImageNet stats
    # torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((28, 28)),  # Resize to 224x224 to match MobileNet's input size
    torchvision.transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize with ImageNet stats
    # torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),
    torchvision.transforms.RandomHorizontalFlip(),
    # torchvision.transforms.RandomCrop(32, padding=4),
    torchvision.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    # torchvision.transforms.RandomRotation(15),
    torchvision.transforms.ToTensor(),
   #  torchvision.transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761]),  # CIFAR-100 normalization values
    torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),
    torchvision.transforms.ToTensor(),
    # torchvision.transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761]),
    torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

train_transforms = test_transforms

# %%
# os.mkdir('/content/dataset/')
# os.mkdir('/content/dataset/train/')
# os.mkdir('/content/dataset/test/')

if not AUGMENTATION:
  train_transforms = test_transforms

if DATASET == 'cifar100':
  # train parameter ???
  train_dataset = torchvision.datasets.CIFAR100(root='/content/dataset/train/', download=True, transform=train_transforms)
  test_dataset = torchvision.datasets.CIFAR100(root='/content/dataset/test/', download=True, transform=test_transforms)

  NUM_CLASSES = 100
  NUM_SUPERCLASSES = 20
  NUM_SUBCLASSES = 100
elif DATASET == 'INaturalist':
  train_dataset = torchvision.datasets.INaturalist(root='/content/dataset/train/', download=True, transform=train_transforms)
  test_dataset = torchvision.datasets.INaturalist(root='/content/dataset/test/', download=True, transform=test_transforms)
elif DATASET == 'Places365':
  train_dataset = torchvision.datasets.Places365(root='/content/dataset/train/', download=True, transform=train_transforms)
  test_dataset = torchvision.datasets.Places365(root='/content/dataset/test/', download=True, transform=test_transforms)
elif DATASET == 'ImageNet': # ImageNet
  train_dataset = torchvision.datasets.ImageNet(root='/content/dataset/train/', download=True, transform=train_transforms)
  test_dataset = torchvision.datasets.ImageNet(root='/content/dataset/test/', download=True, transform=test_transforms)
else: # Standford Cars
  # !unzip /content/drive/MyDrive/New\ Exps/Dataset/standford_cars.zip -d '/content/dataset/'
  shutil.copy("/content/drive/MyDrive/New Exps/Dataset/cardatasettrain.csv", "/content/dataset/cardatasettrain.csv")
  shutil.copy("/content/drive/MyDrive/New Exps/Dataset/cardatasettest.csv", "/content/dataset/cardatasettest.csv")

  NUM_CLASSES = 196
  NUM_SUPERCLASSES = 49
  NUM_SUBCLASSES = 196
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/cars_train/cars_train/03145.jpg
#   inflating: /content/dataset/cars_train/cars_train/03146.jpg
#   inflating: /content/dataset/cars_train/cars_train/03147.jpg
#   inflating: /content/dataset/cars_train/cars_train/03148.jpg
#   inflating: /content/dataset/cars_train/cars_train/03149.jpg
#   inflating: /content/dataset/cars_train/cars_train/03150.jpg
#   inflating: /content/dataset/cars_train/cars_train/03151.jpg
#   inflating: /content/dataset/cars_train/cars_train/03152.jpg
#   inflating: /content/dataset/cars_train/cars_train/03153.jpg
#   inflating: /content/dataset/cars_train/cars_train/03154.jpg
#   inflating: /content/dataset/cars_train/cars_train/03155.jpg
#   inflating: /content/dataset/cars_train/cars_train/03156.jpg
#   inflating: /content/dataset/cars_train/cars_train/03157.jpg
#   inflating: /content/dataset/cars_train/cars_train/03158.jpg
#   inflating: /content/dataset/cars_train/cars_train/03159.jpg
#   inflating: /content/dataset/cars_train/cars_train/03160.jpg
#   inflating: /content/dataset/cars_train/cars_train/03161.jpg
#   inflating: /content/dataset/cars_train/cars_train/03162.jpg
#   inflating: /content/dataset/cars_train/cars_train/03163.jpg
#   inflating: /content/dataset/cars_train/cars_train/03164.jpg
#   inflating: /content/dataset/cars_train/cars_train/03165.jpg
#   inflating: /content/dataset/cars_train/cars_train/03166.jpg
#   inflating: /content/dataset/cars_train/cars_train/03167.jpg
#   inflating: /content/dataset/cars_train/cars_train/03168.jpg
#   inflating: /content/dataset/cars_train/cars_train/03169.jpg
#   inflating: /content/dataset/cars_train/cars_train/03170.jpg
#   inflating: /content/dataset/cars_train/cars_train/03171.jpg
#   inflating: /content/dataset/cars_train/cars_train/03172.jpg
#   inflating: /content/dataset/cars_train/cars_train/03173.jpg
#   inflating: /content/dataset/cars_train/cars_train/03174.jpg
#   inflating: /content/dataset/cars_train/cars_train/03175.jpg
#   inflating: /content/dataset/cars_train/cars_train/03176.jpg
#   inflating: /content/dataset/cars_train/cars_train/03177.jpg
#   inflating: /content/dataset/cars_train/cars_train/03178.jpg
#   inflating: /content/dataset/cars_train/cars_train/03179.jpg
#   inflating: /content/dataset/cars_train/cars_train/03180.jpg
#   inflating: /content/dataset/cars_train/cars_train/03181.jpg
#   inflating: /content/dataset/cars_train/cars_train/03182.jpg
#   inflating: /content/dataset/cars_train/cars_train/03183.jpg
#   inflating: /content/dataset/cars_train/cars_train/03184.jpg
#   inflating: /content/dataset/cars_train/cars_train/03185.jpg
#   inflating: /content/dataset/cars_train/cars_train/03186.jpg
#   inflating: /content/dataset/cars_train/cars_train/03187.jpg
#   inflating: /content/dataset/cars_train/cars_train/03188.jpg
#   inflating: /content/dataset/cars_train/cars_train/03189.jpg
#   inflating: /content/dataset/cars_train/cars_train/03190.jpg
#   inflating: /content/dataset/cars_train/cars_train/03191.jpg
#   inflating: /content/dataset/cars_train/cars_train/03192.jpg
#   inflating: /content/dataset/cars_train/cars_train/03193.jpg
#   inflating: /content/dataset/cars_train/cars_train/03194.jpg
#   inflating: /content/dataset/cars_train/cars_train/03195.jpg
#   inflating: /content/dataset/cars_train/cars_train/03196.jpg
#   inflating: /content/dataset/cars_train/cars_train/03197.jpg
#   inflating: /content/dataset/cars_train/cars_train/03198.jpg
#   inflating: /content/dataset/cars_train/cars_train/03199.jpg
#   inflating: /content/dataset/cars_train/cars_train/03200.jpg
#   inflating: /content/dataset/cars_train/cars_train/03201.jpg
#   inflating: /content/dataset/cars_train/cars_train/03202.jpg
#   inflating: /content/dataset/cars_train/cars_train/03203.jpg
#   inflating: /content/dataset/cars_train/cars_train/03204.jpg
#   inflating: /content/dataset/cars_train/cars_train/03205.jpg
#   inflating: /content/dataset/cars_train/cars_train/03206.jpg
#   inflating: /content/dataset/cars_train/cars_train/03207.jpg
#   inflating: /content/dataset/cars_train/cars_train/03208.jpg
#   inflating: /content/dataset/cars_train/cars_train/03209.jpg
#   inflating: /content/dataset/cars_train/cars_train/03210.jpg
#   inflating: /content/dataset/cars_train/cars_train/03211.jpg
#   inflating: /content/dataset/cars_train/cars_train/03212.jpg
#   inflating: /content/dataset/cars_train/cars_train/03213.jpg
#   inflating: /content/dataset/cars_train/cars_train/03214.jpg
#   inflating: /content/dataset/cars_train/cars_train/03215.jpg
#   inflating: /content/dataset/cars_train/cars_train/03216.jpg
#   inflating: /content/dataset/cars_train/cars_train/03217.jpg
#   inflating: /content/dataset/cars_train/cars_train/03218.jpg
#   inflating: /content/dataset/cars_train/cars_train/03219.jpg
#   inflating: /content/dataset/cars_train/cars_train/03220.jpg
#   inflating: /content/dataset/cars_train/cars_train/03221.jpg
#   inflating: /content/dataset/cars_train/cars_train/03222.jpg
#   inflating: /content/dataset/cars_train/cars_train/03223.jpg
#   inflating: /content/dataset/cars_train/cars_train/03224.jpg
#   inflating: /content/dataset/cars_train/cars_train/03225.jpg
#   inflating: /content/dataset/cars_train/cars_train/03226.jpg
#   inflating: /content/dataset/cars_train/cars_train/03227.jpg
#   inflating: /content/dataset/cars_train/cars_train/03228.jpg
#   inflating: /content/dataset/cars_train/cars_train/03229.jpg
#   inflating: /content/dataset/cars_train/cars_train/03230.jpg
#   inflating: /content/dataset/cars_train/cars_train/03231.jpg
#   inflating: /content/dataset/cars_train/cars_train/03232.jpg
#   inflating: /content/dataset/cars_train/cars_train/03233.jpg
#   inflating: /content/dataset/cars_train/cars_train/03234.jpg
#   inflating: /content/dataset/cars_train/cars_train/03235.jpg
#   inflating: /content/dataset/cars_train/cars_train/03236.jpg
#   inflating: /content/dataset/cars_train/cars_train/03237.jpg
#   inflating: /content/dataset/cars_train/cars_train/03238.jpg
#   inflating: /content/dataset/cars_train/cars_train/03239.jpg
#   inflating: /content/dataset/cars_train/cars_train/03240.jpg
#   inflating: /content/dataset/cars_train/cars_train/03241.jpg
#   inflating: /content/dataset/cars_train/cars_train/03242.jpg
#   inflating: /content/dataset/cars_train/cars_train/03243.jpg
#   inflating: /content/dataset/cars_train/cars_train/03244.jpg
#   inflating: /content/dataset/cars_train/cars_train/03245.jpg
#   inflating: /content/dataset/cars_train/cars_train/03246.jpg
#   inflating: /content/dataset/cars_train/cars_train/03247.jpg
#   inflating: /content/dataset/cars_train/cars_train/03248.jpg
#   inflating: /content/dataset/cars_train/cars_train/03249.jpg
#   inflating: /content/dataset/cars_train/cars_train/03250.jpg
#   inflating: /content/dataset/cars_train/cars_train/03251.jpg
#   inflating: /content/dataset/cars_train/cars_train/03252.jpg
#   inflating: /content/dataset/cars_train/cars_train/03253.jpg
#   inflating: /content/dataset/cars_train/cars_train/03254.jpg
#   inflating: /content/dataset/cars_train/cars_train/03255.jpg
#   inflating: /content/dataset/cars_train/cars_train/03256.jpg
#   inflating: /content/dataset/cars_train/cars_train/03257.jpg
#   inflating: /content/dataset/cars_train/cars_train/03258.jpg
#   inflating: /content/dataset/cars_train/cars_train/03259.jpg
#   inflating: /content/dataset/cars_train/cars_train/03260.jpg
#   inflating: /content/dataset/cars_train/cars_train/03261.jpg
#   inflating: /content/dataset/cars_train/cars_train/03262.jpg
#   inflating: /content/dataset/cars_train/cars_train/03263.jpg
#   inflating: /content/dataset/cars_train/cars_train/03264.jpg
#   inflating: /content/dataset/cars_train/cars_train/03265.jpg
#   inflating: /content/dataset/cars_train/cars_train/03266.jpg
#   inflating: /content/dataset/cars_train/cars_train/03267.jpg
#   inflating: /content/dataset/cars_train/cars_train/03268.jpg
#   inflating: /content/dataset/cars_train/cars_train/03269.jpg
#   inflating: /content/dataset/cars_train/cars_train/03270.jpg
#   inflating: /content/dataset/cars_train/cars_train/03271.jpg
#   inflating: /content/dataset/cars_train/cars_train/03272.jpg
#   inflating: /content/dataset/cars_train/cars_train/03273.jpg
#   inflating: /content/dataset/cars_train/cars_train/03274.jpg
#   inflating: /content/dataset/cars_train/cars_train/03275.jpg
#   inflating: /content/dataset/cars_train/cars_train/03276.jpg
#   inflating: /content/dataset/cars_train/cars_train/03277.jpg
#   inflating: /content/dataset/cars_train/cars_train/03278.jpg
#   inflating: /content/dataset/cars_train/cars_train/03279.jpg
#   inflating: /content/dataset/cars_train/cars_train/03280.jpg
#   inflating: /content/dataset/cars_train/cars_train/03281.jpg
#   inflating: /content/dataset/cars_train/cars_train/03282.jpg
#   inflating: /content/dataset/cars_train/cars_train/03283.jpg
#   inflating: /content/dataset/cars_train/cars_train/03284.jpg
#   inflating: /content/dataset/cars_train/cars_train/03285.jpg
#   inflating: /content/dataset/cars_train/cars_train/03286.jpg
#   inflating: /content/dataset/cars_train/cars_train/03287.jpg
#   inflating: /content/dataset/cars_train/cars_train/03288.jpg
#   inflating: /content/dataset/cars_train/cars_train/03289.jpg
#   inflating: /content/dataset/cars_train/cars_train/03290.jpg
#   inflating: /content/dataset/cars_train/cars_train/03291.jpg
#   inflating: /content/dataset/cars_train/cars_train/03292.jpg
#   inflating: /content/dataset/cars_train/cars_train/03293.jpg
#   inflating: /content/dataset/cars_train/cars_train/03294.jpg
#   inflating: /content/dataset/cars_train/cars_train/03295.jpg
#   inflating: /content/dataset/cars_train/cars_train/03296.jpg
#   inflating: /content/dataset/cars_train/cars_train/03297.jpg
#   inflating: /content/dataset/cars_train/cars_train/03298.jpg
#   inflating: /content/dataset/cars_train/cars_train/03299.jpg
#   inflating: /content/dataset/cars_train/cars_train/03300.jpg
#   inflating: /content/dataset/cars_train/cars_train/03301.jpg
#   inflating: /content/dataset/cars_train/cars_train/03302.jpg
#   inflating: /content/dataset/cars_train/cars_train/03303.jpg
#   inflating: /content/dataset/cars_train/cars_train/03304.jpg
#   inflating: /content/dataset/cars_train/cars_train/03305.jpg
#   inflating: /content/dataset/cars_train/cars_train/03306.jpg
#   inflating: /content/dataset/cars_train/cars_train/03307.jpg
#   inflating: /content/dataset/cars_train/cars_train/03308.jpg
#   inflating: /content/dataset/cars_train/cars_train/03309.jpg
#   inflating: /content/dataset/cars_train/cars_train/03310.jpg
#   inflating: /content/dataset/cars_train/cars_train/03311.jpg
#   inflating: /content/dataset/cars_train/cars_train/03312.jpg
#   inflating: /content/dataset/cars_train/cars_train/03313.jpg
#   inflating: /content/dataset/cars_train/cars_train/03314.jpg
#   inflating: /content/dataset/cars_train/cars_train/03315.jpg
#   inflating: /content/dataset/cars_train/cars_train/03316.jpg
#   inflating: /content/dataset/cars_train/cars_train/03317.jpg
#   inflating: /content/dataset/cars_train/cars_train/03318.jpg
#   inflating: /content/dataset/cars_train/cars_train/03319.jpg
#   inflating: /content/dataset/cars_train/cars_train/03320.jpg
#   inflating: /content/dataset/cars_train/cars_train/03321.jpg
#   inflating: /content/dataset/cars_train/cars_train/03322.jpg
#   inflating: /content/dataset/cars_train/cars_train/03323.jpg
#   inflating: /content/dataset/cars_train/cars_train/03324.jpg
#   inflating: /content/dataset/cars_train/cars_train/03325.jpg
#   inflating: /content/dataset/cars_train/cars_train/03326.jpg
#   inflating: /content/dataset/cars_train/cars_train/03327.jpg
#   inflating: /content/dataset/cars_train/cars_train/03328.jpg
#   inflating: /content/dataset/cars_train/cars_train/03329.jpg
#   inflating: /content/dataset/cars_train/cars_train/03330.jpg
#   inflating: /content/dataset/cars_train/cars_train/03331.jpg
#   inflating: /content/dataset/cars_train/cars_train/03332.jpg
#   inflating: /content/dataset/cars_train/cars_train/03333.jpg
#   inflating: /content/dataset/cars_train/cars_train/03334.jpg
#   inflating: /content/dataset/cars_train/cars_train/03335.jpg
#   inflating: /content/dataset/cars_train/cars_train/03336.jpg
#   inflating: /content/dataset/cars_train/cars_train/03337.jpg
#   inflating: /content/dataset/cars_train/cars_train/03338.jpg
#   inflating: /content/dataset/cars_train/cars_train/03339.jpg
#   inflating: /content/dataset/cars_train/cars_train/03340.jpg
#   inflating: /content/dataset/cars_train/cars_train/03341.jpg
#   inflating: /content/dataset/cars_train/cars_train/03342.jpg
#   inflating: /content/dataset/cars_train/cars_train/03343.jpg
#   inflating: /content/dataset/cars_train/cars_train/03344.jpg
#   inflating: /content/dataset/cars_train/cars_train/03345.jpg
#   inflating: /content/dataset/cars_train/cars_train/03346.jpg
#   inflating: /content/dataset/cars_train/cars_train/03347.jpg
#   inflating: /content/dataset/cars_train/cars_train/03348.jpg
#   inflating: /content/dataset/cars_train/cars_train/03349.jpg
#   inflating: /content/dataset/cars_train/cars_train/03350.jpg
#   inflating: /content/dataset/cars_train/cars_train/03351.jpg
#   inflating: /content/dataset/cars_train/cars_train/03352.jpg
#   inflating: /content/dataset/cars_train/cars_train/03353.jpg
#   inflating: /content/dataset/cars_train/cars_train/03354.jpg
#   inflating: /content/dataset/cars_train/cars_train/03355.jpg
#   inflating: /content/dataset/cars_train/cars_train/03356.jpg
#   inflating: /content/dataset/cars_train/cars_train/03357.jpg
#   inflating: /content/dataset/cars_train/cars_train/03358.jpg
#   inflating: /content/dataset/cars_train/cars_train/03359.jpg
#   inflating: /content/dataset/cars_train/cars_train/03360.jpg
#   inflating: /content/dataset/cars_train/cars_train/03361.jpg
#   inflating: /content/dataset/cars_train/cars_train/03362.jpg
#   inflating: /content/dataset/cars_train/cars_train/03363.jpg
#   inflating: /content/dataset/cars_train/cars_train/03364.jpg
#   inflating: /content/dataset/cars_train/cars_train/03365.jpg
#   inflating: /content/dataset/cars_train/cars_train/03366.jpg
#   inflating: /content/dataset/cars_train/cars_train/03367.jpg
#   inflating: /content/dataset/cars_train/cars_train/03368.jpg
#   inflating: /content/dataset/cars_train/cars_train/03369.jpg
#   inflating: /content/dataset/cars_train/cars_train/03370.jpg
#   inflating: /content/dataset/cars_train/cars_train/03371.jpg
#   inflating: /content/dataset/cars_train/cars_train/03372.jpg
#   inflating: /content/dataset/cars_train/cars_train/03373.jpg
#   inflating: /content/dataset/cars_train/cars_train/03374.jpg
#   inflating: /content/dataset/cars_train/cars_train/03375.jpg
#   inflating: /content/dataset/cars_train/cars_train/03376.jpg
#   inflating: /content/dataset/cars_train/cars_train/03377.jpg
#   inflating: /content/dataset/cars_train/cars_train/03378.jpg
#   inflating: /content/dataset/cars_train/cars_train/03379.jpg
#   inflating: /content/dataset/cars_train/cars_train/03380.jpg
#   inflating: /content/dataset/cars_train/cars_train/03381.jpg
#   inflating: /content/dataset/cars_train/cars_train/03382.jpg
#   inflating: /content/dataset/cars_train/cars_train/03383.jpg
#   inflating: /content/dataset/cars_train/cars_train/03384.jpg
#   inflating: /content/dataset/cars_train/cars_train/03385.jpg
#   inflating: /content/dataset/cars_train/cars_train/03386.jpg
#   inflating: /content/dataset/cars_train/cars_train/03387.jpg
#   inflating: /content/dataset/cars_train/cars_train/03388.jpg
#   inflating: /content/dataset/cars_train/cars_train/03389.jpg
#   inflating: /content/dataset/cars_train/cars_train/03390.jpg
#   inflating: /content/dataset/cars_train/cars_train/03391.jpg
#   inflating: /content/dataset/cars_train/cars_train/03392.jpg
#   inflating: /content/dataset/cars_train/cars_train/03393.jpg
#   inflating: /content/dataset/cars_train/cars_train/03394.jpg
#   inflating: /content/dataset/cars_train/cars_train/03395.jpg
#   inflating: /content/dataset/cars_train/cars_train/03396.jpg
#   inflating: /content/dataset/cars_train/cars_train/03397.jpg
#   inflating: /content/dataset/cars_train/cars_train/03398.jpg
#   inflating: /content/dataset/cars_train/cars_train/03399.jpg
#   inflating: /content/dataset/cars_train/cars_train/03400.jpg
#   inflating: /content/dataset/cars_train/cars_train/03401.jpg
#   inflating: /content/dataset/cars_train/cars_train/03402.jpg
#   inflating: /content/dataset/cars_train/cars_train/03403.jpg
#   inflating: /content/dataset/cars_train/cars_train/03404.jpg
#   inflating: /content/dataset/cars_train/cars_train/03405.jpg
#   inflating: /content/dataset/cars_train/cars_train/03406.jpg
#   inflating: /content/dataset/cars_train/cars_train/03407.jpg
#   inflating: /content/dataset/cars_train/cars_train/03408.jpg
#   inflating: /content/dataset/cars_train/cars_train/03409.jpg
#   inflating: /content/dataset/cars_train/cars_train/03410.jpg
#   inflating: /content/dataset/cars_train/cars_train/03411.jpg
#   inflating: /content/dataset/cars_train/cars_train/03412.jpg
#   inflating: /content/dataset/cars_train/cars_train/03413.jpg
#   inflating: /content/dataset/cars_train/cars_train/03414.jpg
#   inflating: /content/dataset/cars_train/cars_train/03415.jpg
#   inflating: /content/dataset/cars_train/cars_train/03416.jpg
#   inflating: /content/dataset/cars_train/cars_train/03417.jpg
#   inflating: /content/dataset/cars_train/cars_train/03418.jpg
#   inflating: /content/dataset/cars_train/cars_train/03419.jpg
#   inflating: /content/dataset/cars_train/cars_train/03420.jpg
#   inflating: /content/dataset/cars_train/cars_train/03421.jpg
#   inflating: /content/dataset/cars_train/cars_train/03422.jpg
#   inflating: /content/dataset/cars_train/cars_train/03423.jpg
#   inflating: /content/dataset/cars_train/cars_train/03424.jpg
#   inflating: /content/dataset/cars_train/cars_train/03425.jpg
#   inflating: /content/dataset/cars_train/cars_train/03426.jpg
#   inflating: /content/dataset/cars_train/cars_train/03427.jpg
#   inflating: /content/dataset/cars_train/cars_train/03428.jpg
#   inflating: /content/dataset/cars_train/cars_train/03429.jpg
#   inflating: /content/dataset/cars_train/cars_train/03430.jpg
#   inflating: /content/dataset/cars_train/cars_train/03431.jpg
#   inflating: /content/dataset/cars_train/cars_train/03432.jpg
#   inflating: /content/dataset/cars_train/cars_train/03433.jpg
#   inflating: /content/dataset/cars_train/cars_train/03434.jpg
#   inflating: /content/dataset/cars_train/cars_train/03435.jpg
#   inflating: /content/dataset/cars_train/cars_train/03436.jpg
#   inflating: /content/dataset/cars_train/cars_train/03437.jpg
#   inflating: /content/dataset/cars_train/cars_train/03438.jpg
#   inflating: /content/dataset/cars_train/cars_train/03439.jpg
#   inflating: /content/dataset/cars_train/cars_train/03440.jpg
#   inflating: /content/dataset/cars_train/cars_train/03441.jpg
#   inflating: /content/dataset/cars_train/cars_train/03442.jpg
#   inflating: /content/dataset/cars_train/cars_train/03443.jpg
#   inflating: /content/dataset/cars_train/cars_train/03444.jpg
#   inflating: /content/dataset/cars_train/cars_train/03445.jpg
#   inflating: /content/dataset/cars_train/cars_train/03446.jpg
#   inflating: /content/dataset/cars_train/cars_train/03447.jpg
#   inflating: /content/dataset/cars_train/cars_train/03448.jpg
#   inflating: /content/dataset/cars_train/cars_train/03449.jpg
#   inflating: /content/dataset/cars_train/cars_train/03450.jpg
#   inflating: /content/dataset/cars_train/cars_train/03451.jpg
#   inflating: /content/dataset/cars_train/cars_train/03452.jpg
#   inflating: /content/dataset/cars_train/cars_train/03453.jpg
#   inflating: /content/dataset/cars_train/cars_train/03454.jpg
#   inflating: /content/dataset/cars_train/cars_train/03455.jpg
#   inflating: /content/dataset/cars_train/cars_train/03456.jpg
#   inflating: /content/dataset/cars_train/cars_train/03457.jpg
#   inflating: /content/dataset/cars_train/cars_train/03458.jpg
#   inflating: /content/dataset/cars_train/cars_train/03459.jpg
#   inflating: /content/dataset/cars_train/cars_train/03460.jpg
#   inflating: /content/dataset/cars_train/cars_train/03461.jpg
#   inflating: /content/dataset/cars_train/cars_train/03462.jpg
#   inflating: /content/dataset/cars_train/cars_train/03463.jpg
#   inflating: /content/dataset/cars_train/cars_train/03464.jpg
#   inflating: /content/dataset/cars_train/cars_train/03465.jpg
#   inflating: /content/dataset/cars_train/cars_train/03466.jpg
#   inflating: /content/dataset/cars_train/cars_train/03467.jpg
#   inflating: /content/dataset/cars_train/cars_train/03468.jpg
#   inflating: /content/dataset/cars_train/cars_train/03469.jpg
#   inflating: /content/dataset/cars_train/cars_train/03470.jpg
#   inflating: /content/dataset/cars_train/cars_train/03471.jpg
#   inflating: /content/dataset/cars_train/cars_train/03472.jpg
#   inflating: /content/dataset/cars_train/cars_train/03473.jpg
#   inflating: /content/dataset/cars_train/cars_train/03474.jpg
#   inflating: /content/dataset/cars_train/cars_train/03475.jpg
#   inflating: /content/dataset/cars_train/cars_train/03476.jpg
#   inflating: /content/dataset/cars_train/cars_train/03477.jpg
#   inflating: /content/dataset/cars_train/cars_train/03478.jpg
#   inflating: /content/dataset/cars_train/cars_train/03479.jpg
#   inflating: /content/dataset/cars_train/cars_train/03480.jpg
#   inflating: /content/dataset/cars_train/cars_train/03481.jpg
#   inflating: /content/dataset/cars_train/cars_train/03482.jpg
#   inflating: /content/dataset/cars_train/cars_train/03483.jpg
#   inflating: /content/dataset/cars_train/cars_train/03484.jpg
#   inflating: /content/dataset/cars_train/cars_train/03485.jpg
#   inflating: /content/dataset/cars_train/cars_train/03486.jpg
#   inflating: /content/dataset/cars_train/cars_train/03487.jpg
#   inflating: /content/dataset/cars_train/cars_train/03488.jpg
#   inflating: /content/dataset/cars_train/cars_train/03489.jpg
#   inflating: /content/dataset/cars_train/cars_train/03490.jpg
#   inflating: /content/dataset/cars_train/cars_train/03491.jpg
#   inflating: /content/dataset/cars_train/cars_train/03492.jpg
#   inflating: /content/dataset/cars_train/cars_train/03493.jpg
#   inflating: /content/dataset/cars_train/cars_train/03494.jpg
#   inflating: /content/dataset/cars_train/cars_train/03495.jpg
#   inflating: /content/dataset/cars_train/cars_train/03496.jpg
#   inflating: /content/dataset/cars_train/cars_train/03497.jpg
#   inflating: /content/dataset/cars_train/cars_train/03498.jpg
#   inflating: /content/dataset/cars_train/cars_train/03499.jpg
#   inflating: /content/dataset/cars_train/cars_train/03500.jpg
#   inflating: /content/dataset/cars_train/cars_train/03501.jpg
#   inflating: /content/dataset/cars_train/cars_train/03502.jpg
#   inflating: /content/dataset/cars_train/cars_train/03503.jpg
#   inflating: /content/dataset/cars_train/cars_train/03504.jpg
#   inflating: /content/dataset/cars_train/cars_train/03505.jpg
#   inflating: /content/dataset/cars_train/cars_train/03506.jpg
#   inflating: /content/dataset/cars_train/cars_train/03507.jpg
#   inflating: /content/dataset/cars_train/cars_train/03508.jpg
#   inflating: /content/dataset/cars_train/cars_train/03509.jpg
#   inflating: /content/dataset/cars_train/cars_train/03510.jpg
#   inflating: /content/dataset/cars_train/cars_train/03511.jpg
#   inflating: /content/dataset/cars_train/cars_train/03512.jpg
#   inflating: /content/dataset/cars_train/cars_train/03513.jpg
#   inflating: /content/dataset/cars_train/cars_train/03514.jpg
#   inflating: /content/dataset/cars_train/cars_train/03515.jpg
#   inflating: /content/dataset/cars_train/cars_train/03516.jpg
#   inflating: /content/dataset/cars_train/cars_train/03517.jpg
#   inflating: /content/dataset/cars_train/cars_train/03518.jpg
#   inflating: /content/dataset/cars_train/cars_train/03519.jpg
#   inflating: /content/dataset/cars_train/cars_train/03520.jpg
#   inflating: /content/dataset/cars_train/cars_train/03521.jpg
#   inflating: /content/dataset/cars_train/cars_train/03522.jpg
#   inflating: /content/dataset/cars_train/cars_train/03523.jpg
#   inflating: /content/dataset/cars_train/cars_train/03524.jpg
#   inflating: /content/dataset/cars_train/cars_train/03525.jpg
#   inflating: /content/dataset/cars_train/cars_train/03526.jpg
#   inflating: /content/dataset/cars_train/cars_train/03527.jpg
#   inflating: /content/dataset/cars_train/cars_train/03528.jpg
#   inflating: /content/dataset/cars_train/cars_train/03529.jpg
#   inflating: /content/dataset/cars_train/cars_train/03530.jpg
#   inflating: /content/dataset/cars_train/cars_train/03531.jpg
#   inflating: /content/dataset/cars_train/cars_train/03532.jpg
#   inflating: /content/dataset/cars_train/cars_train/03533.jpg
#   inflating: /content/dataset/cars_train/cars_train/03534.jpg
#   inflating: /content/dataset/cars_train/cars_train/03535.jpg
#   inflating: /content/dataset/cars_train/cars_train/03536.jpg
#   inflating: /content/dataset/cars_train/cars_train/03537.jpg
#   inflating: /content/dataset/cars_train/cars_train/03538.jpg
#   inflating: /content/dataset/cars_train/cars_train/03539.jpg
#   inflating: /content/dataset/cars_train/cars_train/03540.jpg
#   inflating: /content/dataset/cars_train/cars_train/03541.jpg
#   inflating: /content/dataset/cars_train/cars_train/03542.jpg
#   inflating: /content/dataset/cars_train/cars_train/03543.jpg
#   inflating: /content/dataset/cars_train/cars_train/03544.jpg
#   inflating: /content/dataset/cars_train/cars_train/03545.jpg
#   inflating: /content/dataset/cars_train/cars_train/03546.jpg
#   inflating: /content/dataset/cars_train/cars_train/03547.jpg
#   inflating: /content/dataset/cars_train/cars_train/03548.jpg
#   inflating: /content/dataset/cars_train/cars_train/03549.jpg
#   inflating: /content/dataset/cars_train/cars_train/03550.jpg
#   inflating: /content/dataset/cars_train/cars_train/03551.jpg
#   inflating: /content/dataset/cars_train/cars_train/03552.jpg
#   inflating: /content/dataset/cars_train/cars_train/03553.jpg
#   inflating: /content/dataset/cars_train/cars_train/03554.jpg
#   inflating: /content/dataset/cars_train/cars_train/03555.jpg
#   inflating: /content/dataset/cars_train/cars_train/03556.jpg
#   inflating: /content/dataset/cars_train/cars_train/03557.jpg
#   inflating: /content/dataset/cars_train/cars_train/03558.jpg
#   inflating: /content/dataset/cars_train/cars_train/03559.jpg
#   inflating: /content/dataset/cars_train/cars_train/03560.jpg
#   inflating: /content/dataset/cars_train/cars_train/03561.jpg
#   inflating: /content/dataset/cars_train/cars_train/03562.jpg
#   inflating: /content/dataset/cars_train/cars_train/03563.jpg
#   inflating: /content/dataset/cars_train/cars_train/03564.jpg
#   inflating: /content/dataset/cars_train/cars_train/03565.jpg
#   inflating: /content/dataset/cars_train/cars_train/03566.jpg
#   inflating: /content/dataset/cars_train/cars_train/03567.jpg
#   inflating: /content/dataset/cars_train/cars_train/03568.jpg
#   inflating: /content/dataset/cars_train/cars_train/03569.jpg
#   inflating: /content/dataset/cars_train/cars_train/03570.jpg
#   inflating: /content/dataset/cars_train/cars_train/03571.jpg
#   inflating: /content/dataset/cars_train/cars_train/03572.jpg
#   inflating: /content/dataset/cars_train/cars_train/03573.jpg
#   inflating: /content/dataset/cars_train/cars_train/03574.jpg
#   inflating: /content/dataset/cars_train/cars_train/03575.jpg
#   inflating: /content/dataset/cars_train/cars_train/03576.jpg
#   inflating: /content/dataset/cars_train/cars_train/03577.jpg
#   inflating: /content/dataset/cars_train/cars_train/03578.jpg
#   inflating: /content/dataset/cars_train/cars_train/03579.jpg
#   inflating: /content/dataset/cars_train/cars_train/03580.jpg
#   inflating: /content/dataset/cars_train/cars_train/03581.jpg
#   inflating: /content/dataset/cars_train/cars_train/03582.jpg
#   inflating: /content/dataset/cars_train/cars_train/03583.jpg
#   inflating: /content/dataset/cars_train/cars_train/03584.jpg
#   inflating: /content/dataset/cars_train/cars_train/03585.jpg
#   inflating: /content/dataset/cars_train/cars_train/03586.jpg
#   inflating: /content/dataset/cars_train/cars_train/03587.jpg
#   inflating: /content/dataset/cars_train/cars_train/03588.jpg
#   inflating: /content/dataset/cars_train/cars_train/03589.jpg
#   inflating: /content/dataset/cars_train/cars_train/03590.jpg
#   inflating: /content/dataset/cars_train/cars_train/03591.jpg
#   inflating: /content/dataset/cars_train/cars_train/03592.jpg
#   inflating: /content/dataset/cars_train/cars_train/03593.jpg
#   inflating: /content/dataset/cars_train/cars_train/03594.jpg
#   inflating: /content/dataset/cars_train/cars_train/03595.jpg
#   inflating: /content/dataset/cars_train/cars_train/03596.jpg
#   inflating: /content/dataset/cars_train/cars_train/03597.jpg
#   inflating: /content/dataset/cars_train/cars_train/03598.jpg
#   inflating: /content/dataset/cars_train/cars_train/03599.jpg
#   inflating: /content/dataset/cars_train/cars_train/03600.jpg
#   inflating: /content/dataset/cars_train/cars_train/03601.jpg
#   inflating: /content/dataset/cars_train/cars_train/03602.jpg
#   inflating: /content/dataset/cars_train/cars_train/03603.jpg
#   inflating: /content/dataset/cars_train/cars_train/03604.jpg
#   inflating: /content/dataset/cars_train/cars_train/03605.jpg
#   inflating: /content/dataset/cars_train/cars_train/03606.jpg
#   inflating: /content/dataset/cars_train/cars_train/03607.jpg
#   inflating: /content/dataset/cars_train/cars_train/03608.jpg
#   inflating: /content/dataset/cars_train/cars_train/03609.jpg
#   inflating: /content/dataset/cars_train/cars_train/03610.jpg
#   inflating: /content/dataset/cars_train/cars_train/03611.jpg
#   inflating: /content/dataset/cars_train/cars_train/03612.jpg
#   inflating: /content/dataset/cars_train/cars_train/03613.jpg
#   inflating: /content/dataset/cars_train/cars_train/03614.jpg
#   inflating: /content/dataset/cars_train/cars_train/03615.jpg
#   inflating: /content/dataset/cars_train/cars_train/03616.jpg
#   inflating: /content/dataset/cars_train/cars_train/03617.jpg
#   inflating: /content/dataset/cars_train/cars_train/03618.jpg
#   inflating: /content/dataset/cars_train/cars_train/03619.jpg
#   inflating: /content/dataset/cars_train/cars_train/03620.jpg
#   inflating: /content/dataset/cars_train/cars_train/03621.jpg
#   inflating: /content/dataset/cars_train/cars_train/03622.jpg
#   inflating: /content/dataset/cars_train/cars_train/03623.jpg
#   inflating: /content/dataset/cars_train/cars_train/03624.jpg
#   inflating: /content/dataset/cars_train/cars_train/03625.jpg
#   inflating: /content/dataset/cars_train/cars_train/03626.jpg
#   inflating: /content/dataset/cars_train/cars_train/03627.jpg
#   inflating: /content/dataset/cars_train/cars_train/03628.jpg
#   inflating: /content/dataset/cars_train/cars_train/03629.jpg
#   inflating: /content/dataset/cars_train/cars_train/03630.jpg
#   inflating: /content/dataset/cars_train/cars_train/03631.jpg
#   inflating: /content/dataset/cars_train/cars_train/03632.jpg
#   inflating: /content/dataset/cars_train/cars_train/03633.jpg
#   inflating: /content/dataset/cars_train/cars_train/03634.jpg
#   inflating: /content/dataset/cars_train/cars_train/03635.jpg
#   inflating: /content/dataset/cars_train/cars_train/03636.jpg
#   inflating: /content/dataset/cars_train/cars_train/03637.jpg
#   inflating: /content/dataset/cars_train/cars_train/03638.jpg
#   inflating: /content/dataset/cars_train/cars_train/03639.jpg
#   inflating: /content/dataset/cars_train/cars_train/03640.jpg
#   inflating: /content/dataset/cars_train/cars_train/03641.jpg
#   inflating: /content/dataset/cars_train/cars_train/03642.jpg
#   inflating: /content/dataset/cars_train/cars_train/03643.jpg
#   inflating: /content/dataset/cars_train/cars_train/03644.jpg
#   inflating: /content/dataset/cars_train/cars_train/03645.jpg
#   inflating: /content/dataset/cars_train/cars_train/03646.jpg
#   inflating: /content/dataset/cars_train/cars_train/03647.jpg
#   inflating: /content/dataset/cars_train/cars_train/03648.jpg
#   inflating: /content/dataset/cars_train/cars_train/03649.jpg
#   inflating: /content/dataset/cars_train/cars_train/03650.jpg
#   inflating: /content/dataset/cars_train/cars_train/03651.jpg
#   inflating: /content/dataset/cars_train/cars_train/03652.jpg
#   inflating: /content/dataset/cars_train/cars_train/03653.jpg
#   inflating: /content/dataset/cars_train/cars_train/03654.jpg
#   inflating: /content/dataset/cars_train/cars_train/03655.jpg
#   inflating: /content/dataset/cars_train/cars_train/03656.jpg
#   inflating: /content/dataset/cars_train/cars_train/03657.jpg
#   inflating: /content/dataset/cars_train/cars_train/03658.jpg
#   inflating: /content/dataset/cars_train/cars_train/03659.jpg
#   inflating: /content/dataset/cars_train/cars_train/03660.jpg
#   inflating: /content/dataset/cars_train/cars_train/03661.jpg
#   inflating: /content/dataset/cars_train/cars_train/03662.jpg
#   inflating: /content/dataset/cars_train/cars_train/03663.jpg
#   inflating: /content/dataset/cars_train/cars_train/03664.jpg
#   inflating: /content/dataset/cars_train/cars_train/03665.jpg
#   inflating: /content/dataset/cars_train/cars_train/03666.jpg
#   inflating: /content/dataset/cars_train/cars_train/03667.jpg
#   inflating: /content/dataset/cars_train/cars_train/03668.jpg
#   inflating: /content/dataset/cars_train/cars_train/03669.jpg
#   inflating: /content/dataset/cars_train/cars_train/03670.jpg
#   inflating: /content/dataset/cars_train/cars_train/03671.jpg
#   inflating: /content/dataset/cars_train/cars_train/03672.jpg
#   inflating: /content/dataset/cars_train/cars_train/03673.jpg
#   inflating: /content/dataset/cars_train/cars_train/03674.jpg
#   inflating: /content/dataset/cars_train/cars_train/03675.jpg
#   inflating: /content/dataset/cars_train/cars_train/03676.jpg
#   inflating: /content/dataset/cars_train/cars_train/03677.jpg
#   inflating: /content/dataset/cars_train/cars_train/03678.jpg
#   inflating: /content/dataset/cars_train/cars_train/03679.jpg
#   inflating: /content/dataset/cars_train/cars_train/03680.jpg
#   inflating: /content/dataset/cars_train/cars_train/03681.jpg
#   inflating: /content/dataset/cars_train/cars_train/03682.jpg
#   inflating: /content/dataset/cars_train/cars_train/03683.jpg
#   inflating: /content/dataset/cars_train/cars_train/03684.jpg
#   inflating: /content/dataset/cars_train/cars_train/03685.jpg
#   inflating: /content/dataset/cars_train/cars_train/03686.jpg
#   inflating: /content/dataset/cars_train/cars_train/03687.jpg
#   inflating: /content/dataset/cars_train/cars_train/03688.jpg
#   inflating: /content/dataset/cars_train/cars_train/03689.jpg
#   inflating: /content/dataset/cars_train/cars_train/03690.jpg
#   inflating: /content/dataset/cars_train/cars_train/03691.jpg
#   inflating: /content/dataset/cars_train/cars_train/03692.jpg
#   inflating: /content/dataset/cars_train/cars_train/03693.jpg
#   inflating: /content/dataset/cars_train/cars_train/03694.jpg
#   inflating: /content/dataset/cars_train/cars_train/03695.jpg
#   inflating: /content/dataset/cars_train/cars_train/03696.jpg
#   inflating: /content/dataset/cars_train/cars_train/03697.jpg
#   inflating: /content/dataset/cars_train/cars_train/03698.jpg
#   inflating: /content/dataset/cars_train/cars_train/03699.jpg
#   inflating: /content/dataset/cars_train/cars_train/03700.jpg
#   inflating: /content/dataset/cars_train/cars_train/03701.jpg
#   inflating: /content/dataset/cars_train/cars_train/03702.jpg
#   inflating: /content/dataset/cars_train/cars_train/03703.jpg
#   inflating: /content/dataset/cars_train/cars_train/03704.jpg
#   inflating: /content/dataset/cars_train/cars_train/03705.jpg
#   inflating: /content/dataset/cars_train/cars_train/03706.jpg
#   inflating: /content/dataset/cars_train/cars_train/03707.jpg
#   inflating: /content/dataset/cars_train/cars_train/03708.jpg
#   inflating: /content/dataset/cars_train/cars_train/03709.jpg
#   inflating: /content/dataset/cars_train/cars_train/03710.jpg
#   inflating: /content/dataset/cars_train/cars_train/03711.jpg
#   inflating: /content/dataset/cars_train/cars_train/03712.jpg
#   inflating: /content/dataset/cars_train/cars_train/03713.jpg
#   inflating: /content/dataset/cars_train/cars_train/03714.jpg
#   inflating: /content/dataset/cars_train/cars_train/03715.jpg
#   inflating: /content/dataset/cars_train/cars_train/03716.jpg
#   inflating: /content/dataset/cars_train/cars_train/03717.jpg
#   inflating: /content/dataset/cars_train/cars_train/03718.jpg
#   inflating: /content/dataset/cars_train/cars_train/03719.jpg
#   inflating: /content/dataset/cars_train/cars_train/03720.jpg
#   inflating: /content/dataset/cars_train/cars_train/03721.jpg
#   inflating: /content/dataset/cars_train/cars_train/03722.jpg
#   inflating: /content/dataset/cars_train/cars_train/03723.jpg
#   inflating: /content/dataset/cars_train/cars_train/03724.jpg
#   inflating: /content/dataset/cars_train/cars_train/03725.jpg
#   inflating: /content/dataset/cars_train/cars_train/03726.jpg
#   inflating: /content/dataset/cars_train/cars_train/03727.jpg
#   inflating: /content/dataset/cars_train/cars_train/03728.jpg
#   inflating: /content/dataset/cars_train/cars_train/03729.jpg
#   inflating: /content/dataset/cars_train/cars_train/03730.jpg
#   inflating: /content/dataset/cars_train/cars_train/03731.jpg
#   inflating: /content/dataset/cars_train/cars_train/03732.jpg
#   inflating: /content/dataset/cars_train/cars_train/03733.jpg
#   inflating: /content/dataset/cars_train/cars_train/03734.jpg
#   inflating: /content/dataset/cars_train/cars_train/03735.jpg
#   inflating: /content/dataset/cars_train/cars_train/03736.jpg
#   inflating: /content/dataset/cars_train/cars_train/03737.jpg
#   inflating: /content/dataset/cars_train/cars_train/03738.jpg
#   inflating: /content/dataset/cars_train/cars_train/03739.jpg
#   inflating: /content/dataset/cars_train/cars_train/03740.jpg
#   inflating: /content/dataset/cars_train/cars_train/03741.jpg
#   inflating: /content/dataset/cars_train/cars_train/03742.jpg
#   inflating: /content/dataset/cars_train/cars_train/03743.jpg
#   inflating: /content/dataset/cars_train/cars_train/03744.jpg
#   inflating: /content/dataset/cars_train/cars_train/03745.jpg
#   inflating: /content/dataset/cars_train/cars_train/03746.jpg
#   inflating: /content/dataset/cars_train/cars_train/03747.jpg
#   inflating: /content/dataset/cars_train/cars_train/03748.jpg
#   inflating: /content/dataset/cars_train/cars_train/03749.jpg
#   inflating: /content/dataset/cars_train/cars_train/03750.jpg
#   inflating: /content/dataset/cars_train/cars_train/03751.jpg
#   inflating: /content/dataset/cars_train/cars_train/03752.jpg
#   inflating: /content/dataset/cars_train/cars_train/03753.jpg
#   inflating: /content/dataset/cars_train/cars_train/03754.jpg
#   inflating: /content/dataset/cars_train/cars_train/03755.jpg
#   inflating: /content/dataset/cars_train/cars_train/03756.jpg
#   inflating: /content/dataset/cars_train/cars_train/03757.jpg
#   inflating: /content/dataset/cars_train/cars_train/03758.jpg
#   inflating: /content/dataset/cars_train/cars_train/03759.jpg
#   inflating: /content/dataset/cars_train/cars_train/03760.jpg
#   inflating: /content/dataset/cars_train/cars_train/03761.jpg
#   inflating: /content/dataset/cars_train/cars_train/03762.jpg
#   inflating: /content/dataset/cars_train/cars_train/03763.jpg
#   inflating: /content/dataset/cars_train/cars_train/03764.jpg
#   inflating: /content/dataset/cars_train/cars_train/03765.jpg
#   inflating: /content/dataset/cars_train/cars_train/03766.jpg
#   inflating: /content/dataset/cars_train/cars_train/03767.jpg
#   inflating: /content/dataset/cars_train/cars_train/03768.jpg
#   inflating: /content/dataset/cars_train/cars_train/03769.jpg
#   inflating: /content/dataset/cars_train/cars_train/03770.jpg
#   inflating: /content/dataset/cars_train/cars_train/03771.jpg
#   inflating: /content/dataset/cars_train/cars_train/03772.jpg
#   inflating: /content/dataset/cars_train/cars_train/03773.jpg
#   inflating: /content/dataset/cars_train/cars_train/03774.jpg
#   inflating: /content/dataset/cars_train/cars_train/03775.jpg
#   inflating: /content/dataset/cars_train/cars_train/03776.jpg
#   inflating: /content/dataset/cars_train/cars_train/03777.jpg
#   inflating: /content/dataset/cars_train/cars_train/03778.jpg
#   inflating: /content/dataset/cars_train/cars_train/03779.jpg
#   inflating: /content/dataset/cars_train/cars_train/03780.jpg
#   inflating: /content/dataset/cars_train/cars_train/03781.jpg
#   inflating: /content/dataset/cars_train/cars_train/03782.jpg
#   inflating: /content/dataset/cars_train/cars_train/03783.jpg
#   inflating: /content/dataset/cars_train/cars_train/03784.jpg
#   inflating: /content/dataset/cars_train/cars_train/03785.jpg
#   inflating: /content/dataset/cars_train/cars_train/03786.jpg
#   inflating: /content/dataset/cars_train/cars_train/03787.jpg
#   inflating: /content/dataset/cars_train/cars_train/03788.jpg
#   inflating: /content/dataset/cars_train/cars_train/03789.jpg
#   inflating: /content/dataset/cars_train/cars_train/03790.jpg
#   inflating: /content/dataset/cars_train/cars_train/03791.jpg
#   inflating: /content/dataset/cars_train/cars_train/03792.jpg
#   inflating: /content/dataset/cars_train/cars_train/03793.jpg
#   inflating: /content/dataset/cars_train/cars_train/03794.jpg
#   inflating: /content/dataset/cars_train/cars_train/03795.jpg
#   inflating: /content/dataset/cars_train/cars_train/03796.jpg
#   inflating: /content/dataset/cars_train/cars_train/03797.jpg
#   inflating: /content/dataset/cars_train/cars_train/03798.jpg
#   inflating: /content/dataset/cars_train/cars_train/03799.jpg
#   inflating: /content/dataset/cars_train/cars_train/03800.jpg
#   inflating: /content/dataset/cars_train/cars_train/03801.jpg
#   inflating: /content/dataset/cars_train/cars_train/03802.jpg
#   inflating: /content/dataset/cars_train/cars_train/03803.jpg
#   inflating: /content/dataset/cars_train/cars_train/03804.jpg
#   inflating: /content/dataset/cars_train/cars_train/03805.jpg
#   inflating: /content/dataset/cars_train/cars_train/03806.jpg
#   inflating: /content/dataset/cars_train/cars_train/03807.jpg
#   inflating: /content/dataset/cars_train/cars_train/03808.jpg
#   inflating: /content/dataset/cars_train/cars_train/03809.jpg
#   inflating: /content/dataset/cars_train/cars_train/03810.jpg
#   inflating: /content/dataset/cars_train/cars_train/03811.jpg
#   inflating: /content/dataset/cars_train/cars_train/03812.jpg
#   inflating: /content/dataset/cars_train/cars_train/03813.jpg
#   inflating: /content/dataset/cars_train/cars_train/03814.jpg
#   inflating: /content/dataset/cars_train/cars_train/03815.jpg
#   inflating: /content/dataset/cars_train/cars_train/03816.jpg
#   inflating: /content/dataset/cars_train/cars_train/03817.jpg
#   inflating: /content/dataset/cars_train/cars_train/03818.jpg
#   inflating: /content/dataset/cars_train/cars_train/03819.jpg
#   inflating: /content/dataset/cars_train/cars_train/03820.jpg
#   inflating: /content/dataset/cars_train/cars_train/03821.jpg
#   inflating: /content/dataset/cars_train/cars_train/03822.jpg
#   inflating: /content/dataset/cars_train/cars_train/03823.jpg
#   inflating: /content/dataset/cars_train/cars_train/03824.jpg
#   inflating: /content/dataset/cars_train/cars_train/03825.jpg
#   inflating: /content/dataset/cars_train/cars_train/03826.jpg
#   inflating: /content/dataset/cars_train/cars_train/03827.jpg
#   inflating: /content/dataset/cars_train/cars_train/03828.jpg
#   inflating: /content/dataset/cars_train/cars_train/03829.jpg
#   inflating: /content/dataset/cars_train/cars_train/03830.jpg
#   inflating: /content/dataset/cars_train/cars_train/03831.jpg
#   inflating: /content/dataset/cars_train/cars_train/03832.jpg
#   inflating: /content/dataset/cars_train/cars_train/03833.jpg
#   inflating: /content/dataset/cars_train/cars_train/03834.jpg
#   inflating: /content/dataset/cars_train/cars_train/03835.jpg
#   inflating: /content/dataset/cars_train/cars_train/03836.jpg
#   inflating: /content/dataset/cars_train/cars_train/03837.jpg
#   inflating: /content/dataset/cars_train/cars_train/03838.jpg
#   inflating: /content/dataset/cars_train/cars_train/03839.jpg
#   inflating: /content/dataset/cars_train/cars_train/03840.jpg
#   inflating: /content/dataset/cars_train/cars_train/03841.jpg
#   inflating: /content/dataset/cars_train/cars_train/03842.jpg
#   inflating: /content/dataset/cars_train/cars_train/03843.jpg
#   inflating: /content/dataset/cars_train/cars_train/03844.jpg
#   inflating: /content/dataset/cars_train/cars_train/03845.jpg
#   inflating: /content/dataset/cars_train/cars_train/03846.jpg
#   inflating: /content/dataset/cars_train/cars_train/03847.jpg
#   inflating: /content/dataset/cars_train/cars_train/03848.jpg
#   inflating: /content/dataset/cars_train/cars_train/03849.jpg
#   inflating: /content/dataset/cars_train/cars_train/03850.jpg
#   inflating: /content/dataset/cars_train/cars_train/03851.jpg
#   inflating: /content/dataset/cars_train/cars_train/03852.jpg
#   inflating: /content/dataset/cars_train/cars_train/03853.jpg
#   inflating: /content/dataset/cars_train/cars_train/03854.jpg
#   inflating: /content/dataset/cars_train/cars_train/03855.jpg
#   inflating: /content/dataset/cars_train/cars_train/03856.jpg
#   inflating: /content/dataset/cars_train/cars_train/03857.jpg
#   inflating: /content/dataset/cars_train/cars_train/03858.jpg
#   inflating: /content/dataset/cars_train/cars_train/03859.jpg
#   inflating: /content/dataset/cars_train/cars_train/03860.jpg
#   inflating: /content/dataset/cars_train/cars_train/03861.jpg
#   inflating: /content/dataset/cars_train/cars_train/03862.jpg
#   inflating: /content/dataset/cars_train/cars_train/03863.jpg
#   inflating: /content/dataset/cars_train/cars_train/03864.jpg
#   inflating: /content/dataset/cars_train/cars_train/03865.jpg
#   inflating: /content/dataset/cars_train/cars_train/03866.jpg
#   inflating: /content/dataset/cars_train/cars_train/03867.jpg
#   inflating: /content/dataset/cars_train/cars_train/03868.jpg
#   inflating: /content/dataset/cars_train/cars_train/03869.jpg
#   inflating: /content/dataset/cars_train/cars_train/03870.jpg
#   inflating: /content/dataset/cars_train/cars_train/03871.jpg
#   inflating: /content/dataset/cars_train/cars_train/03872.jpg
#   inflating: /content/dataset/cars_train/cars_train/03873.jpg
#   inflating: /content/dataset/cars_train/cars_train/03874.jpg
#   inflating: /content/dataset/cars_train/cars_train/03875.jpg
#   inflating: /content/dataset/cars_train/cars_train/03876.jpg
#   inflating: /content/dataset/cars_train/cars_train/03877.jpg
#   inflating: /content/dataset/cars_train/cars_train/03878.jpg
#   inflating: /content/dataset/cars_train/cars_train/03879.jpg
#   inflating: /content/dataset/cars_train/cars_train/03880.jpg
#   inflating: /content/dataset/cars_train/cars_train/03881.jpg
#   inflating: /content/dataset/cars_train/cars_train/03882.jpg
#   inflating: /content/dataset/cars_train/cars_train/03883.jpg
#   inflating: /content/dataset/cars_train/cars_train/03884.jpg
#   inflating: /content/dataset/cars_train/cars_train/03885.jpg
#   inflating: /content/dataset/cars_train/cars_train/03886.jpg
#   inflating: /content/dataset/cars_train/cars_train/03887.jpg
#   inflating: /content/dataset/cars_train/cars_train/03888.jpg
#   inflating: /content/dataset/cars_train/cars_train/03889.jpg
#   inflating: /content/dataset/cars_train/cars_train/03890.jpg
#   inflating: /content/dataset/cars_train/cars_train/03891.jpg
#   inflating: /content/dataset/cars_train/cars_train/03892.jpg
#   inflating: /content/dataset/cars_train/cars_train/03893.jpg
# ...
#   inflating: /content/dataset/cars_train/cars_train/07895.jpg
#   inflating: /content/dataset/cars_train/cars_train/07896.jpg
#   inflating: /content/dataset/cars_train/cars_train/07897.jpg
#   inflating: /content/dataset/cars_train/cars_train/07898.jpg
#   inflating: /content/dataset/cars_train/cars_train/07899.jpg
#   inflating: /content/dataset/cars_train/cars_train/07900.jpg
#   inflating: /content/dataset/cars_train/cars_train/07901.jpg
#   inflating: /content/dataset/cars_train/cars_train/07902.jpg
#   inflating: /content/dataset/cars_train/cars_train/07903.jpg
#   inflating: /content/dataset/cars_train/cars_train/07904.jpg
#   inflating: /content/dataset/cars_train/cars_train/07905.jpg
#   inflating: /content/dataset/cars_train/cars_train/07906.jpg
#   inflating: /content/dataset/cars_train/cars_train/07907.jpg
#   inflating: /content/dataset/cars_train/cars_train/07908.jpg
#   inflating: /content/dataset/cars_train/cars_train/07909.jpg
#   inflating: /content/dataset/cars_train/cars_train/07910.jpg
#   inflating: /content/dataset/cars_train/cars_train/07911.jpg
#   inflating: /content/dataset/cars_train/cars_train/07912.jpg
#   inflating: /content/dataset/cars_train/cars_train/07913.jpg
#   inflating: /content/dataset/cars_train/cars_train/07914.jpg
#   inflating: /content/dataset/cars_train/cars_train/07915.jpg
#   inflating: /content/dataset/cars_train/cars_train/07916.jpg
#   inflating: /content/dataset/cars_train/cars_train/07917.jpg
#   inflating: /content/dataset/cars_train/cars_train/07918.jpg
#   inflating: /content/dataset/cars_train/cars_train/07919.jpg
#   inflating: /content/dataset/cars_train/cars_train/07920.jpg
#   inflating: /content/dataset/cars_train/cars_train/07921.jpg
#   inflating: /content/dataset/cars_train/cars_train/07922.jpg
#   inflating: /content/dataset/cars_train/cars_train/07923.jpg
#   inflating: /content/dataset/cars_train/cars_train/07924.jpg
#   inflating: /content/dataset/cars_train/cars_train/07925.jpg
#   inflating: /content/dataset/cars_train/cars_train/07926.jpg
#   inflating: /content/dataset/cars_train/cars_train/07927.jpg
#   inflating: /content/dataset/cars_train/cars_train/07928.jpg
#   inflating: /content/dataset/cars_train/cars_train/07929.jpg
#   inflating: /content/dataset/cars_train/cars_train/07930.jpg
#   inflating: /content/dataset/cars_train/cars_train/07931.jpg
#   inflating: /content/dataset/cars_train/cars_train/07932.jpg
#   inflating: /content/dataset/cars_train/cars_train/07933.jpg
#   inflating: /content/dataset/cars_train/cars_train/07934.jpg
#   inflating: /content/dataset/cars_train/cars_train/07935.jpg
#   inflating: /content/dataset/cars_train/cars_train/07936.jpg
#   inflating: /content/dataset/cars_train/cars_train/07937.jpg
#   inflating: /content/dataset/cars_train/cars_train/07938.jpg
#   inflating: /content/dataset/cars_train/cars_train/07939.jpg
#   inflating: /content/dataset/cars_train/cars_train/07940.jpg
#   inflating: /content/dataset/cars_train/cars_train/07941.jpg
#   inflating: /content/dataset/cars_train/cars_train/07942.jpg
#   inflating: /content/dataset/cars_train/cars_train/07943.jpg
#   inflating: /content/dataset/cars_train/cars_train/07944.jpg
#   inflating: /content/dataset/cars_train/cars_train/07945.jpg
#   inflating: /content/dataset/cars_train/cars_train/07946.jpg
#   inflating: /content/dataset/cars_train/cars_train/07947.jpg
#   inflating: /content/dataset/cars_train/cars_train/07948.jpg
#   inflating: /content/dataset/cars_train/cars_train/07949.jpg
#   inflating: /content/dataset/cars_train/cars_train/07950.jpg
#   inflating: /content/dataset/cars_train/cars_train/07951.jpg
#   inflating: /content/dataset/cars_train/cars_train/07952.jpg
#   inflating: /content/dataset/cars_train/cars_train/07953.jpg
#   inflating: /content/dataset/cars_train/cars_train/07954.jpg
#   inflating: /content/dataset/cars_train/cars_train/07955.jpg
#   inflating: /content/dataset/cars_train/cars_train/07956.jpg
#   inflating: /content/dataset/cars_train/cars_train/07957.jpg
#   inflating: /content/dataset/cars_train/cars_train/07958.jpg
#   inflating: /content/dataset/cars_train/cars_train/07959.jpg
#   inflating: /content/dataset/cars_train/cars_train/07960.jpg
#   inflating: /content/dataset/cars_train/cars_train/07961.jpg
#   inflating: /content/dataset/cars_train/cars_train/07962.jpg
#   inflating: /content/dataset/cars_train/cars_train/07963.jpg
#   inflating: /content/dataset/cars_train/cars_train/07964.jpg
#   inflating: /content/dataset/cars_train/cars_train/07965.jpg
#   inflating: /content/dataset/cars_train/cars_train/07966.jpg
#   inflating: /content/dataset/cars_train/cars_train/07967.jpg
#   inflating: /content/dataset/cars_train/cars_train/07968.jpg
#   inflating: /content/dataset/cars_train/cars_train/07969.jpg
#   inflating: /content/dataset/cars_train/cars_train/07970.jpg
#   inflating: /content/dataset/cars_train/cars_train/07971.jpg
#   inflating: /content/dataset/cars_train/cars_train/07972.jpg
#   inflating: /content/dataset/cars_train/cars_train/07973.jpg
#   inflating: /content/dataset/cars_train/cars_train/07974.jpg
#   inflating: /content/dataset/cars_train/cars_train/07975.jpg
#   inflating: /content/dataset/cars_train/cars_train/07976.jpg
#   inflating: /content/dataset/cars_train/cars_train/07977.jpg
#   inflating: /content/dataset/cars_train/cars_train/07978.jpg
#   inflating: /content/dataset/cars_train/cars_train/07979.jpg
#   inflating: /content/dataset/cars_train/cars_train/07980.jpg
#   inflating: /content/dataset/cars_train/cars_train/07981.jpg
#   inflating: /content/dataset/cars_train/cars_train/07982.jpg
#   inflating: /content/dataset/cars_train/cars_train/07983.jpg
#   inflating: /content/dataset/cars_train/cars_train/07984.jpg
#   inflating: /content/dataset/cars_train/cars_train/07985.jpg
#   inflating: /content/dataset/cars_train/cars_train/07986.jpg
#   inflating: /content/dataset/cars_train/cars_train/07987.jpg
#   inflating: /content/dataset/cars_train/cars_train/07988.jpg
#   inflating: /content/dataset/cars_train/cars_train/07989.jpg
#   inflating: /content/dataset/cars_train/cars_train/07990.jpg
#   inflating: /content/dataset/cars_train/cars_train/07991.jpg
#   inflating: /content/dataset/cars_train/cars_train/07992.jpg
#   inflating: /content/dataset/cars_train/cars_train/07993.jpg
#   inflating: /content/dataset/cars_train/cars_train/07994.jpg
#   inflating: /content/dataset/cars_train/cars_train/07995.jpg
#   inflating: /content/dataset/cars_train/cars_train/07996.jpg
#   inflating: /content/dataset/cars_train/cars_train/07997.jpg
#   inflating: /content/dataset/cars_train/cars_train/07998.jpg
#   inflating: /content/dataset/cars_train/cars_train/07999.jpg
#   inflating: /content/dataset/cars_train/cars_train/08000.jpg
#   inflating: /content/dataset/cars_train/cars_train/08001.jpg
#   inflating: /content/dataset/cars_train/cars_train/08002.jpg
#   inflating: /content/dataset/cars_train/cars_train/08003.jpg
#   inflating: /content/dataset/cars_train/cars_train/08004.jpg
#   inflating: /content/dataset/cars_train/cars_train/08005.jpg
#   inflating: /content/dataset/cars_train/cars_train/08006.jpg
#   inflating: /content/dataset/cars_train/cars_train/08007.jpg
#   inflating: /content/dataset/cars_train/cars_train/08008.jpg
#   inflating: /content/dataset/cars_train/cars_train/08009.jpg
#   inflating: /content/dataset/cars_train/cars_train/08010.jpg
#   inflating: /content/dataset/cars_train/cars_train/08011.jpg
#   inflating: /content/dataset/cars_train/cars_train/08012.jpg
#   inflating: /content/dataset/cars_train/cars_train/08013.jpg
#   inflating: /content/dataset/cars_train/cars_train/08014.jpg
#   inflating: /content/dataset/cars_train/cars_train/08015.jpg
#   inflating: /content/dataset/cars_train/cars_train/08016.jpg
#   inflating: /content/dataset/cars_train/cars_train/08017.jpg
#   inflating: /content/dataset/cars_train/cars_train/08018.jpg
#   inflating: /content/dataset/cars_train/cars_train/08019.jpg
#   inflating: /content/dataset/cars_train/cars_train/08020.jpg
#   inflating: /content/dataset/cars_train/cars_train/08021.jpg
#   inflating: /content/dataset/cars_train/cars_train/08022.jpg
#   inflating: /content/dataset/cars_train/cars_train/08023.jpg
#   inflating: /content/dataset/cars_train/cars_train/08024.jpg
#   inflating: /content/dataset/cars_train/cars_train/08025.jpg
#   inflating: /content/dataset/cars_train/cars_train/08026.jpg
#   inflating: /content/dataset/cars_train/cars_train/08027.jpg
#   inflating: /content/dataset/cars_train/cars_train/08028.jpg
#   inflating: /content/dataset/cars_train/cars_train/08029.jpg
#   inflating: /content/dataset/cars_train/cars_train/08030.jpg
#   inflating: /content/dataset/cars_train/cars_train/08031.jpg
#   inflating: /content/dataset/cars_train/cars_train/08032.jpg
#   inflating: /content/dataset/cars_train/cars_train/08033.jpg
#   inflating: /content/dataset/cars_train/cars_train/08034.jpg
#   inflating: /content/dataset/cars_train/cars_train/08035.jpg
#   inflating: /content/dataset/cars_train/cars_train/08036.jpg
#   inflating: /content/dataset/cars_train/cars_train/08037.jpg
#   inflating: /content/dataset/cars_train/cars_train/08038.jpg
#   inflating: /content/dataset/cars_train/cars_train/08039.jpg
#   inflating: /content/dataset/cars_train/cars_train/08040.jpg
#   inflating: /content/dataset/cars_train/cars_train/08041.jpg
#   inflating: /content/dataset/cars_train/cars_train/08042.jpg
#   inflating: /content/dataset/cars_train/cars_train/08043.jpg
#   inflating: /content/dataset/cars_train/cars_train/08044.jpg
#   inflating: /content/dataset/cars_train/cars_train/08045.jpg
#   inflating: /content/dataset/cars_train/cars_train/08046.jpg
#   inflating: /content/dataset/cars_train/cars_train/08047.jpg
#   inflating: /content/dataset/cars_train/cars_train/08048.jpg
#   inflating: /content/dataset/cars_train/cars_train/08049.jpg
#   inflating: /content/dataset/cars_train/cars_train/08050.jpg
#   inflating: /content/dataset/cars_train/cars_train/08051.jpg
#   inflating: /content/dataset/cars_train/cars_train/08052.jpg
#   inflating: /content/dataset/cars_train/cars_train/08053.jpg
#   inflating: /content/dataset/cars_train/cars_train/08054.jpg
#   inflating: /content/dataset/cars_train/cars_train/08055.jpg
#   inflating: /content/dataset/cars_train/cars_train/08056.jpg
#   inflating: /content/dataset/cars_train/cars_train/08057.jpg
#   inflating: /content/dataset/cars_train/cars_train/08058.jpg
#   inflating: /content/dataset/cars_train/cars_train/08059.jpg
#   inflating: /content/dataset/cars_train/cars_train/08060.jpg
#   inflating: /content/dataset/cars_train/cars_train/08061.jpg
#   inflating: /content/dataset/cars_train/cars_train/08062.jpg
#   inflating: /content/dataset/cars_train/cars_train/08063.jpg
#   inflating: /content/dataset/cars_train/cars_train/08064.jpg
#   inflating: /content/dataset/cars_train/cars_train/08065.jpg
#   inflating: /content/dataset/cars_train/cars_train/08066.jpg
#   inflating: /content/dataset/cars_train/cars_train/08067.jpg
#   inflating: /content/dataset/cars_train/cars_train/08068.jpg
#   inflating: /content/dataset/cars_train/cars_train/08069.jpg
#   inflating: /content/dataset/cars_train/cars_train/08070.jpg
#   inflating: /content/dataset/cars_train/cars_train/08071.jpg
#   inflating: /content/dataset/cars_train/cars_train/08072.jpg
#   inflating: /content/dataset/cars_train/cars_train/08073.jpg
#   inflating: /content/dataset/cars_train/cars_train/08074.jpg
#   inflating: /content/dataset/cars_train/cars_train/08075.jpg
#   inflating: /content/dataset/cars_train/cars_train/08076.jpg
#   inflating: /content/dataset/cars_train/cars_train/08077.jpg
#   inflating: /content/dataset/cars_train/cars_train/08078.jpg
#   inflating: /content/dataset/cars_train/cars_train/08079.jpg
#   inflating: /content/dataset/cars_train/cars_train/08080.jpg
#   inflating: /content/dataset/cars_train/cars_train/08081.jpg
#   inflating: /content/dataset/cars_train/cars_train/08082.jpg
#   inflating: /content/dataset/cars_train/cars_train/08083.jpg
#   inflating: /content/dataset/cars_train/cars_train/08084.jpg
#   inflating: /content/dataset/cars_train/cars_train/08085.jpg
#   inflating: /content/dataset/cars_train/cars_train/08086.jpg
#   inflating: /content/dataset/cars_train/cars_train/08087.jpg
#   inflating: /content/dataset/cars_train/cars_train/08088.jpg
#   inflating: /content/dataset/cars_train/cars_train/08089.jpg
#   inflating: /content/dataset/cars_train/cars_train/08090.jpg
#   inflating: /content/dataset/cars_train/cars_train/08091.jpg
#   inflating: /content/dataset/cars_train/cars_train/08092.jpg
#   inflating: /content/dataset/cars_train/cars_train/08093.jpg
#   inflating: /content/dataset/cars_train/cars_train/08094.jpg
#   inflating: /content/dataset/cars_train/cars_train/08095.jpg
#   inflating: /content/dataset/cars_train/cars_train/08096.jpg
#   inflating: /content/dataset/cars_train/cars_train/08097.jpg
#   inflating: /content/dataset/cars_train/cars_train/08098.jpg
#   inflating: /content/dataset/cars_train/cars_train/08099.jpg
#   inflating: /content/dataset/cars_train/cars_train/08100.jpg
#   inflating: /content/dataset/cars_train/cars_train/08101.jpg
#   inflating: /content/dataset/cars_train/cars_train/08102.jpg
#   inflating: /content/dataset/cars_train/cars_train/08103.jpg
#   inflating: /content/dataset/cars_train/cars_train/08104.jpg
#   inflating: /content/dataset/cars_train/cars_train/08105.jpg
#   inflating: /content/dataset/cars_train/cars_train/08106.jpg
#   inflating: /content/dataset/cars_train/cars_train/08107.jpg
#   inflating: /content/dataset/cars_train/cars_train/08108.jpg
#   inflating: /content/dataset/cars_train/cars_train/08109.jpg
#   inflating: /content/dataset/cars_train/cars_train/08110.jpg
#   inflating: /content/dataset/cars_train/cars_train/08111.jpg
#   inflating: /content/dataset/cars_train/cars_train/08112.jpg
#   inflating: /content/dataset/cars_train/cars_train/08113.jpg
#   inflating: /content/dataset/cars_train/cars_train/08114.jpg
#   inflating: /content/dataset/cars_train/cars_train/08115.jpg
#   inflating: /content/dataset/cars_train/cars_train/08116.jpg
#   inflating: /content/dataset/cars_train/cars_train/08117.jpg
#   inflating: /content/dataset/cars_train/cars_train/08118.jpg
#   inflating: /content/dataset/cars_train/cars_train/08119.jpg
#   inflating: /content/dataset/cars_train/cars_train/08120.jpg
#   inflating: /content/dataset/cars_train/cars_train/08121.jpg
#   inflating: /content/dataset/cars_train/cars_train/08122.jpg
#   inflating: /content/dataset/cars_train/cars_train/08123.jpg
#   inflating: /content/dataset/cars_train/cars_train/08124.jpg
#   inflating: /content/dataset/cars_train/cars_train/08125.jpg
#   inflating: /content/dataset/cars_train/cars_train/08126.jpg
#   inflating: /content/dataset/cars_train/cars_train/08127.jpg
#   inflating: /content/dataset/cars_train/cars_train/08128.jpg
#   inflating: /content/dataset/cars_train/cars_train/08129.jpg
#   inflating: /content/dataset/cars_train/cars_train/08130.jpg
#   inflating: /content/dataset/cars_train/cars_train/08131.jpg
#   inflating: /content/dataset/cars_train/cars_train/08132.jpg
#   inflating: /content/dataset/cars_train/cars_train/08133.jpg
#   inflating: /content/dataset/cars_train/cars_train/08134.jpg
#   inflating: /content/dataset/cars_train/cars_train/08135.jpg
#   inflating: /content/dataset/cars_train/cars_train/08136.jpg
#   inflating: /content/dataset/cars_train/cars_train/08137.jpg
#   inflating: /content/dataset/cars_train/cars_train/08138.jpg
#   inflating: /content/dataset/cars_train/cars_train/08139.jpg
#   inflating: /content/dataset/cars_train/cars_train/08140.jpg
#   inflating: /content/dataset/cars_train/cars_train/08141.jpg
#   inflating: /content/dataset/cars_train/cars_train/08142.jpg
#   inflating: /content/dataset/cars_train/cars_train/08143.jpg
#   inflating: /content/dataset/cars_train/cars_train/08144.jpg

# %%
#@title CIFAR100 Classes & Superclasses

if DATASET == 'cifar100':

  # Define the classes and superclasses
  cifar100_classes = [
      # Superclass: Aquatic Mammals
      {"class": "beaver", "superclass": "aquatic mammals"},
      {"class": "dolphin", "superclass": "aquatic mammals"},
      {"class": "otter", "superclass": "aquatic mammals"},
      {"class": "seal", "superclass": "aquatic mammals"},
      {"class": "whale", "superclass": "aquatic mammals"},

      # Superclass: Fish
      {"class": "aquarium fish", "superclass": "fish"},
      {"class": "flatfish", "superclass": "fish"},
      {"class": "ray", "superclass": "fish"},
      {"class": "shark", "superclass": "fish"},
      {"class": "trout", "superclass": "fish"},

      # Superclass: Flowers
      {"class": "orchid", "superclass": "flowers"},
      {"class": "poppy", "superclass": "flowers"},
      {"class": "rose", "superclass": "flowers"},
      {"class": "sunflower", "superclass": "flowers"},
      {"class": "tulip", "superclass": "flowers"},

      # Superclass: Food Containers
      {"class": "bottle", "superclass": "food containers"},
      {"class": "bowl", "superclass": "food containers"},
      {"class": "can", "superclass": "food containers"},
      {"class": "cup", "superclass": "food containers"},
      {"class": "plate", "superclass": "food containers"},

      # Superclass: Fruits and Vegetables
      {"class": "apple", "superclass": "fruits and vegetables"},
      {"class": "mushroom", "superclass": "fruits and vegetables"},
      {"class": "orange", "superclass": "fruits and vegetables"},
      {"class": "pear", "superclass": "fruits and vegetables"},
      {"class": "sweet pepper", "superclass": "fruits and vegetables"},

      # Superclass: Household Electrical Devices
      {"class": "clock", "superclass": "household electrical devices"},
      {"class": "keyboard", "superclass": "household electrical devices"},
      {"class": "lamp", "superclass": "household electrical devices"},
      {"class": "telephone", "superclass": "household electrical devices"},
      {"class": "television", "superclass": "household electrical devices"},

      # Superclass: Household Furniture
      {"class": "bed", "superclass": "household furniture"},
      {"class": "chair", "superclass": "household furniture"},
      {"class": "couch", "superclass": "household furniture"},
      {"class": "table", "superclass": "household furniture"},
      {"class": "wardrobe", "superclass": "household furniture"},

      # Superclass: Insects
      {"class": "bee", "superclass": "insects"},
      {"class": "beetle", "superclass": "insects"},
      {"class": "butterfly", "superclass": "insects"},
      {"class": "caterpillar", "superclass": "insects"},
      {"class": "cockroach", "superclass": "insects"},

      # Superclass: Large Carnivores
      {"class": "bear", "superclass": "large carnivores"},
      {"class": "leopard", "superclass": "large carnivores"},
      {"class": "lion", "superclass": "large carnivores"},
      {"class": "tiger", "superclass": "large carnivores"},
      {"class": "wolf", "superclass": "large carnivores"},

      # Superclass: Large Man-made Outdoor Things
      {"class": "bridge", "superclass": "large man-made outdoor things"},
      {"class": "castle", "superclass": "large man-made outdoor things"},
      {"class": "house", "superclass": "large man-made outdoor things"},
      {"class": "road", "superclass": "large man-made outdoor things"},
      {"class": "skyscraper", "superclass": "large man-made outdoor things"},

      # Superclass: Large Natural Outdoor Scenes
      {"class": "cloud", "superclass": "large natural outdoor scenes"},
      {"class": "forest", "superclass": "large natural outdoor scenes"},
      {"class": "mountain", "superclass": "large natural outdoor scenes"},
      {"class": "plain", "superclass": "large natural outdoor scenes"},
      {"class": "sea", "superclass": "large natural outdoor scenes"},

      # Superclass: Large Omnivores and Herbivores
      {"class": "camel", "superclass": "large omnivores and herbivores"},
      {"class": "cattle", "superclass": "large omnivores and herbivores"},
      {"class": "chimpanzee", "superclass": "large omnivores and herbivores"},
      {"class": "elephant", "superclass": "large omnivores and herbivores"},
      {"class": "kangaroo", "superclass": "large omnivores and herbivores"},

      # Superclass: Medium-sized Mammals
      {"class": "fox", "superclass": "medium-sized mammals"},
      {"class": "porcupine", "superclass": "medium-sized mammals"},
      {"class": "possum", "superclass": "medium-sized mammals"},
      {"class": "raccoon", "superclass": "medium-sized mammals"},
      {"class": "skunk", "superclass": "medium-sized mammals"},

      # Superclass: Non-insect Invertebrates
      {"class": "crab", "superclass": "non-insect invertebrates"},
      {"class": "lobster", "superclass": "non-insect invertebrates"},
      {"class": "snail", "superclass": "non-insect invertebrates"},
      {"class": "spider", "superclass": "non-insect invertebrates"},
      {"class": "worm", "superclass": "non-insect invertebrates"},

      # Superclass: People
      {"class": "baby", "superclass": "people"},
      {"class": "boy", "superclass": "people"},
      {"class": "girl", "superclass": "people"},
      {"class": "man", "superclass": "people"},
      {"class": "woman", "superclass": "people"},

      # Superclass: Reptiles
      {"class": "crocodile", "superclass": "reptiles"},
      {"class": "dinosaur", "superclass": "reptiles"},
      {"class": "lizard", "superclass": "reptiles"},
      {"class": "snake", "superclass": "reptiles"},
      {"class": "turtle", "superclass": "reptiles"},

      # Superclass: Small Mammals
      {"class": "hamster", "superclass": "small mammals"},
      {"class": "mouse", "superclass": "small mammals"},
      {"class": "rabbit", "superclass": "small mammals"},
      {"class": "shrew", "superclass": "small mammals"},
      {"class": "squirrel", "superclass": "small mammals"},

      # Superclass: Trees
      {"class": "maple tree", "superclass": "trees"},
      {"class": "oak tree", "superclass": "trees"},
      {"class": "palm tree", "superclass": "trees"},
      {"class": "pine tree", "superclass": "trees"},
      {"class": "willow tree", "superclass": "trees"},

      # Superclass: Vehicles 1
      {"class": "bicycle", "superclass": "vehicles 1"},
      {"class": "bus", "superclass": "vehicles 1"},
      {"class": "motorcycle", "superclass": "vehicles 1"},
      {"class": "pickup truck", "superclass": "vehicles 1"},
      {"class": "train", "superclass": "vehicles 1"},

      # Superclass: Vehicles 2
      {"class": "lawn mower", "superclass": "vehicles 2"},
      {"class": "rocket", "superclass": "vehicles 2"},
      {"class": "streetcar", "superclass": "vehicles 2"},
      {"class": "tank", "superclass": "vehicles 2"},
      {"class": "tractor", "superclass": "vehicles 2"},
  ]

  # Write to JSON file
  with open('cifar100_classes.json', 'w') as json_file:
      json.dump(cifar100_classes, json_file, indent=4)

  superclasses = [
      "aquatic mammals",          # 1-5
      "fish",                     # 6-10
      "flowers",                  # 11-15
      "food containers",          # 16-20
      "fruits and vegetables",    # 21-25
      "household electrical devices",  # 26-30
      "household furniture",      # 31-35
      "insects",                  # 36-40
      "large carnivores",         # 41-45
      "large man-made outdoor things", # 46-50
      "large natural outdoor scenes",  # 51-55
      "large omnivores and herbivores",# 56-60
      "medium-sized mammals",     # 61-65
      "non-insect invertebrates", # 66-70
      "people",                   # 71-75
      "reptiles",                 # 76-80
      "small mammals",            # 81-85
      "trees",                    # 86-90
      "vehicles 1",               # 91-95
      "vehicles 2"                # 96-100
  ]

  classes = [
      # Aquatic Mammals
      "beaver", "dolphin", "otter", "seal", "whale",

      # Fish
      "aquarium fish", "flatfish", "ray", "shark", "trout",

      # Flowers
      "orchid", "poppy", "rose", "sunflower", "tulip",

      # Food Containers
      "bottle", "bowl", "can", "cup", "plate",

      # Fruits and Vegetables
      "apple", "mushroom", "orange", "pear", "sweet pepper",

      # Household Electrical Devices
      "clock", "keyboard", "lamp", "telephone", "television",

      # Household Furniture
      "bed", "chair", "couch", "table", "wardrobe",

      # Insects
      "bee", "beetle", "butterfly", "caterpillar", "cockroach",

      # Large Carnivores
      "bear", "leopard", "lion", "tiger", "wolf",

      # Large Man-made Outdoor Things
      "bridge", "castle", "house", "road", "skyscraper",

      # Large Natural Outdoor Scenes
      "cloud", "forest", "mountain", "plain", "sea",

      # Large Omnivores and Herbivores
      "camel", "cattle", "chimpanzee", "elephant", "kangaroo",

      # Medium-sized Mammals
      "fox", "porcupine", "possum", "raccoon", "skunk",

      # Non-insect Invertebrates
      "crab", "lobster", "snail", "spider", "worm",

      # People
      "baby", "boy", "girl", "man", "woman",

      # Reptiles
      "crocodile", "dinosaur", "lizard", "snake", "turtle",

      # Small Mammals
      "hamster", "mouse", "rabbit", "shrew", "squirrel",

      # Trees
      "maple tree", "oak tree", "palm tree", "pine tree", "willow tree",

      # Vehicles 1
      "bicycle", "bus", "motorcycle", "pickup truck", "train",

      # Vehicles 2
      "lawn mower", "rocket", "streetcar", "tank", "tractor"
  ]

# %%
if DATASET == 'cifar100':

  file_path = '/content/dataset/test/cifar-100-python/meta'

  # Unpickle the file
  with open(file_path, 'rb') as file:
      data = pickle.load(file)

  alphabetical_to_original_label = {}

  for label_id, label in enumerate(data['fine_label_names']):
    label = label.replace('_', ' ')
    new_index = classes.index(label)
    superclass = cifar100_classes[new_index]['superclass']
    new_superclass_index = superclasses.index(superclass)
    # print(label, new_index, new_superclass_index)
    alphabetical_to_original_label[label_id] = {'index': new_index, 'class':classes[new_index], 'super_index':new_superclass_index, 'superclass': superclass}

  print(alphabetical_to_original_label)

  superclass_and_class_to_hierarchic_label = {}

  for key in alphabetical_to_original_label:
    info = alphabetical_to_original_label[key]
    superclass = info['superclass']
    if superclass not in superclass_and_class_to_hierarchic_label:
      hierarchic_label = 0
      superclass_and_class_to_hierarchic_label[superclass] = 0
    else:
      hierarchic_label = superclass_and_class_to_hierarchic_label[superclass] + 1
      superclass_and_class_to_hierarchic_label[superclass] = hierarchic_label
    info['hierarchic_index'] = hierarchic_label
    alphabetical_to_original_label[key] = info

  print(alphabetical_to_original_label)

# %%
if DATASET == 'cifar100':
  for td_id, td in enumerate(train_dataset):
    pil_img = td[0]
    numpy_img = np.clip(pil_img.permute(1, 2, 0).numpy()[:, :, ::-1] * 255, 0, 255)
    class_label = td[1]
    print(numpy_img.shape)
    # cv2_imshow(numpy_img)
    # print(alphabetical_to_original_label[class_label]['class'], alphabetical_to_original_label[class_label]['superclass'])
    if td_id % 10 == 9:
      break

# %%
if DATASET == 'cifar100':
  train_size = int(0.8 * len(train_dataset))
  val_size = len(train_dataset) - train_size

  # Split the dataset into training and validation
  train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

  # Create data loaders for each
  train_loader_classic  = DataLoader(train_dataset, batch_size=64, shuffle=True)
  val_loader_clasic = DataLoader(val_dataset, batch_size=64, shuffle=False)
  test_loader_clasic = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # INaturalist Classes and Superclasses

# %%
if DATASET == 'INaturalist':
  pass

# %% [markdown]
# # Places365

# %%
if DATASET == 'Places365':
  pass

# %% [markdown]
# # Standford Cars

# %%
from torch.utils.data import Dataset
from PIL import Image
from scipy.io import loadmat
import pandas as pd

class StandfordCarsDataset(Dataset):
    def __init__(self, root, split, transform=None, target_transform=None):
        """
        Args:
            data (any format): The data (e.g., list of file paths, array of images).
            labels (any format): The labels associated with the data.
            transform (callable, optional): Optional transform to apply to a sample.
        """
        self.root = root
        self.split = split
        if self.split == 'train' or self.split == 'val':
          self.path = 'cars_train'
        else:
          self.path = 'cars_train'

        self.image_paths = self.root + '/' + self.path + '/' + self.path + '/'
        self.label_path = self.root + '/cars_annos.mat'
        annotation_path = '/content/dataset/cardatasettrain.csv' # if self.split == 'train' else '/content/dataset/cardatasettest.csv'
        self.annotation_df = pd.read_csv(annotation_path)
        self.data = []
        self.labels = []
        self.classes = []
        self.alphabetical_to_original_label = {}
        self.load_data()
        self.transform = transform
        self.target_transform = target_transform

    def load_data(self):
      data = loadmat(self.label_path)
      self.classes = data['class_names'][0]
      self.hierarchic_classes = list(set([cls[0].split(' ')[0] for cls in self.classes]))
      # no_samples = 8144 if self.split =='train' else 8041 # len(data['annotations'][0])
      no_samples = len(self.annotation_df)
      # for ids, sample in enumerate(data['annotations'][0]):
      for ids, sample in self.annotation_df.iterrows():
        # if (self.split == 'train' and ids < no_samples * 0.7) or (self.split == 'val' and (ids >= no_samples * 0.7 and ids < no_samples * 0.9)) or (self.split == 'test' and ids >= no_samples * 0.9):
        image_name =  sample['image']  # sample[0][0].split('/')[-1]
        image_no = int(image_name.split('.')[0])
        # if (self.split == 'train' and image_no < no_samples) or (self.split == 'val' and image_no > 8144 and image_no < 8144 + no_samples *0.8) or (self.split == 'test' and image_no > 8144 and image_no >= 8144 + no_samples *0.8):
        #  if self.split in ['val', 'test']:
        if (self.split == 'train' and ids <= no_samples * 0.7) or (self.split == 'val' and ids > no_samples * 0.7 and ids < no_samples * 0.8) or (self.split == 'test' and ids >= no_samples * 0.8):
            image_name = str(image_no).zfill(5) + '.jpg'
            self.data.append(self.image_paths + image_name)
            class_id = sample['Class'] - 1 # sample[5][0][0] - 1
            if class_id not in self.alphabetical_to_original_label:
              superclass = self.classes[class_id][0].split(' ')[0]
              self.alphabetical_to_original_label[class_id] = {'index': class_id, 'class': self.classes[class_id], 'super_index': self.hierarchic_classes.index(superclass), 'superclass':superclass}
            self.labels.append(class_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Load the sample data and label
        sample = Image.open(self.data[idx]).convert("RGB") # torchvision.io.read_image(self.data[idx])
        label = self.labels[idx]

        # Apply any transformation if provided
        if self.transform:
            sample = self.transform(sample)

        if self.target_transform:
          label = self.target_transform(label)

        return sample, label

if DATASET == 'StandfordCars':
    train_dataset = StandfordCarsDataset(root='/content/dataset', split='train', transform=train_transforms)
    alphabetical_to_original_label = train_dataset.alphabetical_to_original_label
    val_dataset = StandfordCarsDataset(root='/content/dataset', split='val', transform=test_transforms)
    test_dataset = StandfordCarsDataset(root='/content/dataset', split='test', transform=test_transforms)
    train_loader_classic  = DataLoader(train_dataset, batch_size=64, shuffle=True)
    val_loader_clasic = DataLoader(val_dataset, batch_size=64, shuffle=False)
    test_loader_clasic = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # Model

# %%
def print_number_of_parameters(model):

  total_params = sum(p.numel() for p in model.parameters())

  # Print the total number of parameters
  print(f"Total number of parameters: {total_params}")

# %%
#@title Flat MobileNetv3

class ClassicMobileNetV3(nn.Module):
    def __init__(self, num_classes=100, pretrained=True, dropout_p=0.5):
        super(ClassicMobileNetV3, self).__init__()

        # Load the pre-trained MobileNetV3 model from torchvision
        self.mobilenet = MODEL(pretrained=pretrained)

        if 'mobilenet_v3' in MODEL_NAME:

          # Modify the first convolutional layer to accept (28, 28) input size
          # self.mobilenet.features[0][0] = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)

          # Extract the number of features from the original classifier
          in_features = self.mobilenet.classifier[-1].in_features

          # Replace the classifier with a new sequence including Dropout
          '''
          self.mobilenet.classifier[-1] = nn.Sequential(
              # nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          '''
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )

          self.mobilenet.classifier[-1] = model_head

        elif 'resnet' in MODEL_NAME:
          in_features = self.mobilenet.fc.in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.fc = model_head
        elif 'swin' in MODEL_NAME:
          self.mobilenet.head = nn.Linear(self.mobilenet.head.in_features, num_classes)
        elif 'vit_b_16' in MODEL_NAME:
          self.mobilenet.heads.head = nn.Linear(self.mobilenet.heads.head.in_features, num_classes)
        elif 'vgg' in MODEL_NAME:
          # ? Redundant path
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Linear(in_features, num_classes)
        elif 'densenet' in MODEL_NAME:
          in_features = self.mobilenet.classifier.in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier = model_head
        elif 'efficientnet' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier[-1] = model_head
        elif 'maxvit' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier[-1] = model_head
        elif 'convnext' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier[-1] = model_head
        else:
          assert False


    def forward(self, x):
        return self.mobilenet(x)

classic_model = ClassicMobileNetV3(num_classes=NUM_CLASSES, pretrained=True, dropout_p = DROPOUT)
print_number_of_parameters(classic_model)

input = torch.randn(1, 3, 224, 224)  # Example input
flops, params = profile(classic_model, inputs=(input,))
print(f"FLOPs: {flops}, Parameters: {params}")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Base_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Base_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/convnext_base-6075fbad.pth" to /root/.cache/torch/hub/checkpoints/convnext_base-6075fbad.pth
# 100%|██████████| 338M/338M [00:01<00:00, 228MB/s]
# Total number of parameters: 87767364
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# FLOPs: 15372622848.0, Parameters: 87745220.0

# %%
#@title Local Classifier at each hierarchic granularity

class HierarchicMobileNetV3(nn.Module):
    def __init__(self, num_superclasses=20, num_subclasses = [5 for _ in range(20)], pretrained=True, device="cuda"):

      super(HierarchicMobileNetV3, self).__init__()

      self.num_superclasses = num_superclasses
      self.num_subclasses = num_subclasses

      self.superclass_clasifier = ClassicMobileNetV3(num_superclasses, pretrained)

      # self.class_classifiers = [ClassicMobileNetV3(num_subclasses[i], pretrained) for i in range(num_superclasses)]
      self.class_classifiers = nn.ModuleList(
            [ClassicMobileNetV3(num_subclasses[i], pretrained).to(device) for i in range(num_superclasses)]
        )


    def forward(self, x):
        # Predict the superclass
        # x = x.to(next(self.parameters()).device)
        superclass_prediction = self.superclass_clasifier(x)

        # Determine the predicted superclass for each item in the batch
        chosen_superclass = torch.argmax(superclass_prediction, dim=1)

        # Prepare an empty tensor to store the subclass predictions
        batch_size = x.size(0)
        class_predictions = torch.zeros(batch_size, max(self.num_subclasses), device=x.device)

        for i in range(batch_size):
            # For each item in the batch, select the corresponding subclass classifier
            class_predictions[i] = self.class_classifiers[chosen_superclass[i]](x[i].unsqueeze(0))

        return class_predictions, superclass_prediction

# %%
#@title Global Classifier

class GlobalMobileNetV3(nn.Module):
  def __init__(self, num_superclasses=20, num_subclasses = 100, pretrained=True):

      self.num_superclasses = num_superclasses
      self.num_subclasses = num_subclasses

      self.mobilenet = ClassicMobileNetV3(num_superclasses + num_subclasses)

  def forward(self, x):
      return self.mobilenet(x)

# %%
#@title Parallel MT Hierarchical

class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x


class ParallelMultiTaskMobileNetV3(nn.Module):
    def __init__(self, num_superclasses=20, num_subclasses=100, pretrained=True, dropout_p=0.5):
        super(ParallelMultiTaskMobileNetV3, self).__init__()

        # Load the pre-trained MobileNetV3 model from torchvision
        self.mobilenet = MODEL(pretrained=pretrained)
        # Define Dropout layer

        if 'mobilenet_v3' in MODEL_NAME:
          # Modify the first convolutional layer to accept (28, 28) input size
          # self.mobilenet.features[0][0] = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)

          # Extract the number of features from the original classifier
          in_features = self.mobilenet.classifier[-1].in_features

          # Replace the original classifier with an identity layer
          self.mobilenet.classifier[-1] = Identity()

        elif 'resnet' in MODEL_NAME:
          in_features = self.mobilenet.fc.in_features
          self.mobilenet.fc = nn.Dropout(p=dropout_p)

        elif 'swin' in MODEL_NAME:
          in_features = self.mobilenet.head.in_features
          self.mobilenet.head = nn.Dropout(p=dropout_p)

        elif 'vit_b_16' in MODEL_NAME:
          in_features = self.mobilenet.heads.head.in_features
          self.mobilenet.heads.head = nn.Dropout(p=dropout_p)

        elif 'vgg' in MODEL_NAME:
          # ? Redundant path
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'densenet' in MODEL_NAME:
          in_features = self.mobilenet.classifier.in_features
          self.mobilenet.classifier = nn.Dropout(p=dropout_p)

        elif 'efficientnet' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'maxvit' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'convnext' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        self.superclass_classifier = nn.Linear(in_features, num_superclasses)
        self.subclass_classifier = nn.Linear(in_features, num_subclasses)

    def forward(self, x):
        # Pass input through the feature extractor
        features = self.mobilenet(x)
        features = torch.flatten(features, 1)  # Flatten the output for the classifier

        # Apply Dropout to the features
        # features = self.dropout(features)

        # Compute superclass and subclass predictions
        superclass_output = self.superclass_classifier(features)
        subclass_output = self.subclass_classifier(features)

        return subclass_output, superclass_output

parallel_model = ParallelMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True, dropout_p = DROPOUT)
print_number_of_parameters(parallel_model)

input = torch.randn(1, 3, 224, 224)  # Example input
flops, params = profile(parallel_model, inputs=(input,))
print(f"FLOPs: {flops}, Parameters: {params}")
# Out:
# Total number of parameters: 87817589
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# FLOPs: 15372673024.0, Parameters: 87795445.0

# %%
#@title Cascaded MT Hierarchical

class CascadedMultiTaskMobileNetV3(nn.Module):
    def __init__(self, num_superclasses=20, num_subclasses=100, pretrained=True, dropout_p=0.5):
        super(CascadedMultiTaskMobileNetV3, self).__init__()

        # Load the pre-trained MobileNetV3 model from torchvision
        self.mobilenet = MODEL(pretrained=pretrained)

        # Modify the first convolutional layer to accept (28, 28) input size
        # self.mobilenet.features[0][0] = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)
        if 'mobilenet_v3' in MODEL_NAME:
        # Adjust the classifier input size if needed (e.g., due to smaller input size)
          in_features = self.mobilenet.classifier[-1].in_features

          # Replace the original classifier with an identity layer
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'resnet' in MODEL_NAME:
          in_features = self.mobilenet.fc.in_features
          self.mobilenet.fc = nn.Dropout(p=dropout_p)

        elif 'swin' in MODEL_NAME:
          in_features = self.mobilenet.head.in_features
          self.mobilenet.head = nn.Dropout(p=dropout_p)

        elif 'vit_b_16' in MODEL_NAME:
          in_features = self.mobilenet.heads.head.in_features
          self.mobilenet.heads.head = nn.Dropout(p=dropout_p)

        elif 'vgg' in MODEL_NAME:
          # ? Redundant path
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'densenet' in MODEL_NAME:
          in_features = self.mobilenet.classifier.in_features
          self.mobilenet.classifier = nn.Dropout(p=dropout_p)

        elif 'efficientnet' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'maxvit' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'convnext' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        # Superclass classifier
        self.superclass_classifier = nn.Linear(in_features, num_superclasses)

        # Subclass classifier with additional input for superclass prediction
        self.subclass_classifier = nn.Linear(in_features + num_superclasses, num_subclasses)

    def forward(self, x):
        # Pass input through the feature extractor (all layers except the classifier)
        features = self.mobilenet(x)
        features = torch.flatten(features, 1)

        # Apply Dropout to the features
        # features = self.dropout(features)

        # Compute superclass prediction
        superclass_output = self.superclass_classifier(features)

        # Concatenate the superclass prediction with the features
        combined_input = torch.cat((features, superclass_output), dim=1)

        # Apply Dropout to the combined input before subclass classification
        # combined_input = self.dropout(combined_input)

        # Compute subclass prediction using combined input
        subclass_output = self.subclass_classifier(combined_input)

        return subclass_output, superclass_output

cascaded_model = CascadedMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True, dropout_p = DROPOUT)
print_number_of_parameters(cascaded_model)

input = torch.randn(1, 3, 224, 224)  # Example input
flops, params = profile(cascaded_model, inputs=(input,))
print(f"FLOPs: {flops}, Parameters: {params}")
# Out:
# Total number of parameters: 87827193
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# FLOPs: 15372682628.0, Parameters: 87805049.0

# %%
# Implement Deep Supervised MT

# %% [markdown]
# # Extra Dataloaders

# %%
def get_hierarchic_labels(target):
    superclass_label = alphabetical_to_original_label[target]['super_index']
    target = alphabetical_to_original_label[target]['index']
    return superclass_label, target

# Modify the dataset to return hierarchical labels
if DATASET == 'cifar100':
  train_dataset_hierarchic = torchvision.datasets.CIFAR100(root='/content/dataset/train/', train=True, download=False, transform=train_transforms, target_transform=get_hierarchic_labels)
  train_dataset_hierarchic, val_dataset_hierarchic = random_split(train_dataset_hierarchic, [train_size, val_size])
  test_dataset_hierarchic = torchvision.datasets.CIFAR100(root='/content/dataset/test/', train=False, download=False, transform=test_transforms, target_transform=get_hierarchic_labels)
elif DATASET == 'StandfordCars':
  train_dataset_hierarchic = StandfordCarsDataset(root='/content/dataset', split='train', transform=train_transforms, target_transform=get_hierarchic_labels)
  val_dataset_hierarchic = StandfordCarsDataset(root='/content/dataset', split='val', transform=test_transforms, target_transform=get_hierarchic_labels)
  test_dataset_hierarchic = StandfordCarsDataset(root='/content/dataset', split='test', transform=test_transforms, target_transform=get_hierarchic_labels)

# DataLoader for HierarchicMobileNetV3
train_loader_hierarchic = DataLoader(train_dataset_hierarchic, batch_size=32, shuffle=True, num_workers=4)
val_loader_hierarchic = DataLoader(val_dataset_hierarchic, batch_size=32, shuffle=False, num_workers=4)
test_loader_hierarchic = DataLoader(test_dataset_hierarchic, batch_size=32, shuffle=False, num_workers=4)

# %%
def get_global_labels(target):
    superclass_label = alphabetical_to_original_label[target]['super_index']
    global_label = superclass_label * 100 + v
    return global_label

# Load and split the dataset for GlobalMobileNetV3
if DATASET == 'cifar100':
  full_global_dataset = torchvision.datasets. CIFAR100(root='/content/dataset/train/', train=True, download=False, transform=transform, target_transform=get_global_labels)
  train_dataset_global, val_dataset_global = random_split(full_global_dataset, [train_size, val_size])
  test_dataset_global = torchvision.datasets.CIFAR100(root='/content/dataset/test/', train=False, download=False, transform=transform, target_transform=get_global_labels)
elif DATASET == 'StandfordCars':
   train_dataset_global = StandfordCarsDataset(root='/content/dataset', split='train', transform=train_transforms, target_transform=get_global_labels)
   val_dataset_global = StandfordCarsDataset(root='/content/dataset', split='val', transform=test_transforms, target_transform=get_global_labels)
   test_dataset_global = StandfordCarsDataset(root='/content/dataset', split='test', transform=test_transforms, target_transform=get_global_labels)

# DataLoader for GlobalMobileNetV3
train_loader_global = DataLoader(train_dataset_global, batch_size=32, shuffle=True, num_workers=4)
val_loader_global = DataLoader(val_dataset_global, batch_size=32, shuffle=False, num_workers=4)
test_loader_global = DataLoader(test_dataset_global, batch_size=32, shuffle=False, num_workers=4)

# %%
# DataLoader for ParallelMultiTaskMobileNetV3 (superclass and subclass)
train_loader_parallel = DataLoader(train_dataset_hierarchic, batch_size=32, shuffle=True, num_workers=4)
val_loader_parallel = DataLoader(val_dataset_hierarchic, batch_size=32, shuffle=False, num_workers=4)
test_loader_parallel = DataLoader(test_dataset_hierarchic, batch_size=32, shuffle=False, num_workers=4)

# %%
# DataLoader for CascadedMultiTaskMobileNetV3 (superclass and subclass)
train_loader_cascaded = DataLoader(train_dataset_hierarchic, batch_size=32, shuffle=True, num_workers=4)
val_loader_cascaded = DataLoader(val_dataset_hierarchic, batch_size=32, shuffle=False, num_workers=4)
test_loader_cascaded = DataLoader(test_dataset_hierarchic, batch_size=32, shuffle=False, num_workers=4)

# %% [markdown]
# # Training Procedures

# %%
import torch
import copy
from torch.optim.lr_scheduler import OneCycleLR

def train_classic_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda', max_lr=MAX_LR, phases=['train', 'val']):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss':[], 'test_acc':[],  'train_acc_superclass': [], 'val_acc_superclass': [], 'test_acc_superclass':[]}

    # Calculate total steps for 1CycleLR (total number of batches in training phase)
    total_steps = len(dataloaders['train']) * num_epochs

    # Initialize the 1CycleLR scheduler
    scheduler = OneCycleLR(optimizer, max_lr=max_lr, steps_per_epoch=len(dataloaders['train']), epochs=num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        scheduler.step()  # Update the learning rate according to the 1Cycle policy

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()

                superclass_labels, _ = zip(*[get_hierarchic_labels(int(element)) for element in labels.data])
                superclass_labels = torch.tensor(superclass_labels)

                superclass_preds, _ = zip(*[get_hierarchic_labels(int(element)) for element in preds])
                superclass_preds = torch.tensor(superclass_preds)

                running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()


            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)


            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Save the model if validation loss has decreased
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                model_save_path = BASE_DIR + f'classic_model_epoch.pt'
                torch.save(model.state_dict(), model_save_path)
                print(f'New best model saved with validation loss: {best_val_loss:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    return model, history

# %%
def train_hierarchic_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss':[], 'test_acc':[]}


    device2 = next(model.class_classifiers[0].mobilenet.parameters()).device
    print(f"The first classifier's MobileNetV3 model is on: {device2}")

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)
                    hierarchic_labels = torch.zeros(subclass_labels.shape[0], device=device)
                    for idx, subclass_label in enumerate(subclass_labels):
                      hierarchic_label = alphabetical_to_original_label[subclass_label.item()]['hierarchic_index']
                      hierarchic_labels[idx] = hierarchic_label
                    hierarchic_labels = hierarchic_labels.long()
                    superclass_loss = criterion(superclass_outputs, superclass_labels)
                    subclass_loss = criterion(subclass_outputs, hierarchic_labels)
                    loss = superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum((subclass_preds == hierarchic_labels.data) * (superclass_preds == superclass_labels.data)).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase])
            epoch_acc = running_corrects / len(dataloaders[phase])
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase])

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model, history

# %%
def train_hierarchic_mobilenet_fast(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss':[], 'test_acc':[]}

    # Precompute hierarchic label mapping on CPU for faster indexing
    original_to_hierarchic = torch.tensor(
        [alphabetical_to_original_label[i]['hierarchic_index'] for i in range(len(alphabetical_to_original_label))],
        dtype=torch.long, device=device
    )

    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)

                    # Vectorized label conversion
                    hierarchic_labels = original_to_hierarchic[subclass_labels]

                    superclass_loss = criterion(superclass_outputs, superclass_labels)
                    subclass_loss = criterion(subclass_outputs, hierarchic_labels)
                    loss = superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum((subclass_preds == hierarchic_labels) & (superclass_preds == superclass_labels)).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)

            # Correct the calculation of loss and accuracy
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model, history

# %%
'''
def train_global_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()

            epoch_loss = running_loss / len(dataloaders[phase])
            epoch_acc = running_corrects / len(dataloaders[phase])

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model, history
'''
# Out:
# "\ndef train_global_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):\n    model = model.to(device)\n    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}\n\n    for epoch in range(num_epochs):\n        print(f'Epoch {epoch+1}/{num_epochs}')\n        print('-' * 10)\n\n        for phase in ['train', 'val']:\n            if phase == 'train':\n                model.train()\n            else:\n                model.eval()\n\n            running_loss = 0.0\n            running_corrects = 0\n\n            for inputs, labels in dataloaders[phase]:\n                inputs, labels = inputs.to(device), labels.to(device)\n\n                optimizer.zero_grad()\n\n                with torch.set_grad_enabled(phase == 'train'):\n                    outputs = model(inputs)\n                    loss = criterion(outputs, labels)\n                    _, preds = torch.max(outputs, 1)\n\n                    if phase == 'train':\n                        loss.backward()\n                        optimizer.step()\n\n                running_loss += loss.item() * inputs.size(0)\n                running_corrects += torch.sum(preds == labels.data).item()\n\n            epoch_loss = running_loss / len(dataloaders[phase])\n            epoch_acc = running_corrects / len(dataloaders[phase])\n\n            history[f'{phase}_loss'].append(epoch_loss)\n            history[f'{phase}_acc'].append(epoch_acc)\n\n            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')\n\n    return model, history\n"

# %%
import torch
import copy

def train_parallel_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda', max_lr=MAX_LR, phases=['train', 'val']):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'train_acc_superclass': [], 'val_acc_superclass': [], 'test_loss':[], 'test_acc':[], 'test_acc_superclass':[]}

    # Calculate total steps for 1CycleLR (total number of batches in training phase)
    total_steps = len(dataloaders['train']) * num_epochs

    # Initialize the 1CycleLR scheduler
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=max_lr, steps_per_epoch=len(dataloaders['train']), epochs=num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)
                    superclass_loss = criterion(superclass_outputs, superclass_labels) * LOSS_WEIGHTS[1]
                    subclass_loss = criterion(subclass_outputs, subclass_labels) * LOSS_WEIGHTS[0]
                    loss = subclass_loss # superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum(subclass_preds == subclass_labels.data).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        superclass_loss.backward(retain_graph=True)
                        subclass_loss.backward()
                        optimizer.step()
                        scheduler.step()  # Update the learning rate according to the 1Cycle policy

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f} Superclass Acc: {epoch_acc_superclass:.4f}')

            # Save the model if validation loss has decreased
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                model_save_path = BASE_DIR + f'parallel_model_epoch.pt'
                torch.save(model.state_dict(), model_save_path)
                print(f'New best model saved with validation loss: {best_val_loss:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    return model, history

# %%
import torch
import copy

def train_cascaded_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda', max_lr=MAX_LR, phases=['train', 'val']):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'train_acc_superclass': [], 'val_acc_superclass': [], 'test_loss':[], 'test_acc':[], 'test_acc_superclass':[]}

    # Calculate total steps for 1CycleLR (total number of batches in training phase)
    total_steps = len(dataloaders['train']) * num_epochs

    # Initialize the 1CycleLR scheduler
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=max_lr, steps_per_epoch=len(dataloaders['train']), epochs=num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)
                    superclass_loss = criterion(superclass_outputs, superclass_labels) * LOSS_WEIGHTS[1]
                    subclass_loss = criterion(subclass_outputs, subclass_labels) * LOSS_WEIGHTS[0]
                    loss = subclass_loss # superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum(subclass_preds == subclass_labels.data).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        superclass_loss.backward(retain_graph=True)
                        subclass_loss.backward()
                        optimizer.step()
                        scheduler.step()  # Update the learning rate according to the 1Cycle policy

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f} Superclass Acc: {epoch_acc_superclass:.4f}')

            # Save the model if validation loss has decreased
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                model_save_path = BASE_DIR + f'cascaded_model_epoch.pt'
                torch.save(model.state_dict(), model_save_path)
                print(f'New best model saved with validation loss: {best_val_loss:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    return model, history

# %% [markdown]
# # Train

# %%
# Initialize the model
classic_model = ClassicMobileNetV3(num_classes=NUM_CLASSES, pretrained=True)

# Define the loss function and optimizer
optimizer = optim.Adam(classic_model.parameters(), lr=LR)

# Call the training function for ClassicMobileNetV3
trained_classic_model, classic_history = train_classic_mobilenet(
    model=classic_model,
    dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaxVit_T_Weights.IMAGENET1K_V1`. You can also use `weights=MaxVit_T_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/25
# ----------
# Train Loss: 5.2900 Acc: 0.0086
# Val Loss: 5.2018 Acc: 0.0196
# New best model saved with validation loss: 5.2018
# Epoch 2/25
# ----------
# Train Loss: 4.9735 Acc: 0.0477
# Val Loss: 4.5372 Acc: 0.1141
# New best model saved with validation loss: 4.5372
# Epoch 3/25
# ----------
# Train Loss: 4.0441 Acc: 0.1701
# Val Loss: 3.3799 Acc: 0.2920
# New best model saved with validation loss: 3.3799
# Epoch 4/25
# ----------
# Train Loss: 2.7128 Acc: 0.4285
# Val Loss: 2.1161 Acc: 0.5276
# New best model saved with validation loss: 2.1161
# Epoch 5/25
# ----------
# Train Loss: 1.4874 Acc: 0.6709
# Val Loss: 1.7773 Acc: 0.5190
# New best model saved with validation loss: 1.7773
# Epoch 6/25
# ----------
# Train Loss: 0.9328 Acc: 0.7753
# Val Loss: 1.6808 Acc: 0.5656
# New best model saved with validation loss: 1.6808
# Epoch 7/25
# ----------
# Train Loss: 0.7412 Acc: 0.8007
# Val Loss: 1.1867 Acc: 0.6834
# New best model saved with validation loss: 1.1867
# Epoch 8/25
# ----------
# Train Loss: 0.4582 Acc: 0.8763
# Val Loss: 1.1058 Acc: 0.6773
# New best model saved with validation loss: 1.1058
# Epoch 9/25
# ----------
# Train Loss: 0.3411 Acc: 0.9095
# Val Loss: 0.7139 Acc: 0.8123
# New best model saved with validation loss: 0.7139
# Epoch 10/25
# ----------
# Train Loss: 0.2660 Acc: 0.9288
# Val Loss: 0.7163 Acc: 0.7890
# Epoch 11/25
# ----------
# Train Loss: 0.1764 Acc: 0.9547
# Val Loss: 0.8873 Acc: 0.7350
# Epoch 12/25
# ----------
# Train Loss: 0.1924 Acc: 0.9516
# Val Loss: 0.6448 Acc: 0.8160
# New best model saved with validation loss: 0.6448
# Epoch 13/25
# ----------
# Train Loss: 0.1444 Acc: 0.9605
# Val Loss: 0.6899 Acc: 0.8037
# Epoch 14/25
# ----------
# Train Loss: 0.0598 Acc: 0.9872
# Val Loss: 0.5577 Acc: 0.8601
# New best model saved with validation loss: 0.5577
# Epoch 15/25
# ----------
# Train Loss: 0.1195 Acc: 0.9700
# Val Loss: 0.5593 Acc: 0.8540
# Epoch 16/25
# ----------
# Train Loss: 0.0405 Acc: 0.9907
# Val Loss: 0.4899 Acc: 0.8712
# New best model saved with validation loss: 0.4899
# Epoch 17/25
# ----------
# Train Loss: 0.0274 Acc: 0.9949
# Val Loss: 0.4285 Acc: 0.8933
# New best model saved with validation loss: 0.4285
# Epoch 18/25
# ----------
# Train Loss: 0.0205 Acc: 0.9956
# Val Loss: 0.4254 Acc: 0.8982
# New best model saved with validation loss: 0.4254
# Epoch 19/25
# ----------
# Train Loss: 0.0164 Acc: 0.9975
# Val Loss: 0.4264 Acc: 0.8896
# Epoch 20/25
# ----------
# Train Loss: 0.0114 Acc: 0.9982
# Val Loss: 0.4140 Acc: 0.8896
# New best model saved with validation loss: 0.4140
# Epoch 21/25
# ----------
# Train Loss: 0.0097 Acc: 0.9979
# Val Loss: 0.3978 Acc: 0.9006
# New best model saved with validation loss: 0.3978
# Epoch 22/25
# ----------
# Train Loss: 0.0098 Acc: 0.9981
# Val Loss: 0.4011 Acc: 0.8920
# Epoch 23/25
# ----------
# Train Loss: 0.0084 Acc: 0.9984
# Val Loss: 0.3984 Acc: 0.8933
# Epoch 24/25
# ----------
# Train Loss: 0.0087 Acc: 0.9981
# Val Loss: 0.3995 Acc: 0.8920
# Epoch 25/25
# ----------
# Train Loss: 0.0080 Acc: 0.9988
# Val Loss: 0.4003 Acc: 0.8920

# %%
# hierarchic_model = HierarchicMobileNetV3(num_superclasses=20, num_subclasses=[5 for _ in range(20)], pretrained=True, device=DEVICE)
# optimizer = optim.Adam(hierarchic_model.parameters(), lr=LR)

'''
trained_hierarchic_model, hierarchic_history = train_hierarchic_mobilenet_fast(
    model=hierarchic_model,
    dataloaders={'train': train_loader_hierarchic, 'val': val_loader_hierarchic, 'test':test_loader_hierarchic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
'''
# Out:
# "\ntrained_hierarchic_model, hierarchic_history = train_hierarchic_mobilenet_fast(\n    model=hierarchic_model,\n    dataloaders={'train': train_loader_hierarchic, 'val': val_loader_hierarchic, 'test':test_loader_hierarchic},\n    criterion=criterion,\n    optimizer=optimizer,\n    num_epochs=EPOCHS,\n    device=DEVICE  # or 'cpu' if you don't have a GPU\n)\n"

# %%
parallel_model = ParallelMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True)
optimizer = optim.Adam(parallel_model.parameters(), lr=LR)

# Call the training function for ParallelMultiTaskMobileNetV3
trained_parallel_model, parallel_history = train_parallel_mobilenet(
    model=parallel_model,
    dataloaders={'train': train_loader_parallel, 'val': val_loader_parallel, 'test':test_loader_parallel},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
# Out:
# Epoch 1/25
# ----------
# Train Loss: 5.2662 Acc: 0.0088 Superclass Acc: 0.1044
# Val Loss: 5.0772 Acc: 0.0429 Superclass Acc: 0.1656
# New best model saved with validation loss: 5.0772
# Epoch 2/25
# ----------
# Train Loss: 4.7386 Acc: 0.0656 Superclass Acc: 0.2664
# Val Loss: 4.1011 Acc: 0.1558 Superclass Acc: 0.4626
# New best model saved with validation loss: 4.1011
# Epoch 3/25
# ----------
# Train Loss: 3.4866 Acc: 0.2589 Superclass Acc: 0.5346
# Val Loss: 2.7189 Acc: 0.4245 Superclass Acc: 0.6945
# New best model saved with validation loss: 2.7189
# Epoch 4/25
# ----------
# Train Loss: 2.1357 Acc: 0.4887 Superclass Acc: 0.7390
# Val Loss: 2.0540 Acc: 0.4503 Superclass Acc: 0.6859
# New best model saved with validation loss: 2.0540
# Epoch 5/25
# ----------
# Train Loss: 1.4462 Acc: 0.6085 Superclass Acc: 0.8230
# Val Loss: 1.6557 Acc: 0.5362 Superclass Acc: 0.7546
# New best model saved with validation loss: 1.6557
# Epoch 6/25
# ----------
# Train Loss: 1.1948 Acc: 0.6515 Superclass Acc: 0.8327
# Val Loss: 1.7576 Acc: 0.5043 Superclass Acc: 0.7067
# Epoch 7/25
# ----------
# Train Loss: 1.0614 Acc: 0.6790 Superclass Acc: 0.8384
# Val Loss: 1.3099 Acc: 0.6037 Superclass Acc: 0.7755
# New best model saved with validation loss: 1.3099
# Epoch 8/25
# ----------
# Train Loss: 0.8695 Acc: 0.7306 Superclass Acc: 0.8756
# Val Loss: 1.1045 Acc: 0.6798 Superclass Acc: 0.7963
# New best model saved with validation loss: 1.1045
# Epoch 9/25
# ----------
# Train Loss: 0.6049 Acc: 0.8125 Superclass Acc: 0.9207
# Val Loss: 0.8691 Acc: 0.7350 Superclass Acc: 0.8748
# New best model saved with validation loss: 0.8691
# Epoch 10/25
# ----------
# Train Loss: 0.4247 Acc: 0.8655 Superclass Acc: 0.9461
# Val Loss: 0.8902 Acc: 0.7571 Superclass Acc: 0.8638
# Epoch 11/25
# ----------
# Train Loss: 0.3127 Acc: 0.9028 Superclass Acc: 0.9675
# Val Loss: 0.7476 Acc: 0.7828 Superclass Acc: 0.8982
# New best model saved with validation loss: 0.7476
# Epoch 12/25
# ----------
# Train Loss: 0.2327 Acc: 0.9255 Superclass Acc: 0.9698
# Val Loss: 0.7714 Acc: 0.7730 Superclass Acc: 0.8957
# Epoch 13/25
# ----------
# Train Loss: 0.2050 Acc: 0.9333 Superclass Acc: 0.9765
# Val Loss: 0.7328 Acc: 0.7804 Superclass Acc: 0.8908
# New best model saved with validation loss: 0.7328
# Epoch 14/25
# ----------
# Train Loss: 0.1863 Acc: 0.9419 Superclass Acc: 0.9781
# Val Loss: 0.6368 Acc: 0.8417 Superclass Acc: 0.9288
# New best model saved with validation loss: 0.6368
# Epoch 15/25
# ----------
# Train Loss: 0.1099 Acc: 0.9690 Superclass Acc: 0.9861
# Val Loss: 0.5110 Acc: 0.8601 Superclass Acc: 0.9362
# New best model saved with validation loss: 0.5110
# Epoch 16/25
# ----------
# Train Loss: 0.0822 Acc: 0.9768 Superclass Acc: 0.9907
# Val Loss: 0.4585 Acc: 0.8761 Superclass Acc: 0.9497
# New best model saved with validation loss: 0.4585
# Epoch 17/25
# ----------
# Train Loss: 0.0465 Acc: 0.9888 Superclass Acc: 0.9960
# Val Loss: 0.4618 Acc: 0.8675 Superclass Acc: 0.9448
# Epoch 18/25
# ----------
# Train Loss: 0.0323 Acc: 0.9928 Superclass Acc: 0.9975
# Val Loss: 0.4986 Acc: 0.8773 Superclass Acc: 0.9509
# Epoch 19/25
# ----------
# Train Loss: 0.0252 Acc: 0.9958 Superclass Acc: 0.9991
# Val Loss: 0.4503 Acc: 0.8773 Superclass Acc: 0.9546
# New best model saved with validation loss: 0.4503
# Epoch 20/25
# ----------
# Train Loss: 0.0187 Acc: 0.9967 Superclass Acc: 0.9988
# Val Loss: 0.4330 Acc: 0.8847 Superclass Acc: 0.9521
# New best model saved with validation loss: 0.4330
# Epoch 21/25
# ----------
# Train Loss: 0.0152 Acc: 0.9970 Superclass Acc: 0.9991
# Val Loss: 0.4503 Acc: 0.8785 Superclass Acc: 0.9558
# Epoch 22/25
# ----------
# Train Loss: 0.0128 Acc: 0.9974 Superclass Acc: 0.9993
# Val Loss: 0.4550 Acc: 0.8798 Superclass Acc: 0.9534
# Epoch 23/25
# ----------

# %%
cascaded_model = CascadedMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True)
optimizer = optim.Adam(cascaded_model.parameters(), lr=LR)

trained_cascaded_model, cascaded_history = train_cascaded_mobilenet(
    model=cascaded_model,
    dataloaders={'train': train_loader_cascaded, 'val': val_loader_cascaded, 'test':test_loader_cascaded},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)

# %% [markdown]
# # Plot

# %%
import os
import matplotlib.pyplot as plt

# Assuming you have these history dictionaries from your training sessions
# Each dictionary should contain lists like 'train_acc', 'val_acc', 'train_loss', 'val_loss'
# Example:
# classic_history = {'train_acc': [...], 'val_acc': [...], 'train_loss': [...], 'val_loss': [...]}
# hierarchic_history = {'train_acc': [...], 'val_acc': [...], 'train_loss': [...], 'val_loss': [...]}
# global_history = {'train_acc': [...], 'val_acc': [...], 'train_loss': [...], 'val_loss': [...]}
# parallel_history = {'train_acc': [...], 'val_acc': [...], 'train_loss': [...], 'val_loss': [...]}
# cascaded_history = {'train_acc': [...], 'val_acc': [...], 'train_loss': [...], 'val_loss': [...]}

# List of histories and labels for the plot
histories = [
    ('Classic', classic_history),
    # ('Hierarchic', hierarchic_history),
    ('Parallel', parallel_history),
    ('Cascaded', cascaded_history)
]

# Function to create a folder and save the plot
def save_plot(history_key, title, ylabel, save_path):
    # Create the directory if it doesn't exist

    # Plot the metric for each model
    plt.figure(figsize=(12, 8))
    for label, history in histories:
      if history_key in history:
        plt.plot(history[history_key], label=f'{label} {title}')

    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.legend(loc='best')
    plt.grid(True)

    # Save the plot to the specified path
    plt.savefig(save_path)

    # Optionally, show the plot (you can comment this out if you don't want to display it)
    plt.show()

# Define the base directory where you want to save the plots
base_dir = BASE_DIR

# Save plots for each metric
save_plot('train_acc', 'Training Accuracy', 'Accuracy', os.path.join(base_dir, 'training_accuracy.png'))
save_plot('val_acc', 'Validation Accuracy', 'Accuracy', os.path.join(base_dir, 'validation_accuracy.png'))
save_plot('train_acc_superclass', 'Training Superclass Accuracy', 'Accuracy', os.path.join(base_dir, 'training_accuracy_superclass.png'))
save_plot('val_acc_superclass', 'Validation Superclass Accuracy', 'Accuracy', os.path.join(base_dir, 'validation_accuracy_superclass.png'))
save_plot('train_loss', 'Training Loss', 'Loss', os.path.join(base_dir, 'training_loss.png'))
save_plot('val_loss', 'Validation Loss', 'Loss', os.path.join(base_dir, 'validation_loss.png'))

# %%
with open(os.path.join(base_dir, "history_classic.json"), "w") as f:
    json.dump(classic_history, f)

with open(os.path.join(base_dir, "history_parallel.json"), "w") as f:
    json.dump(parallel_history, f)

with open(os.path.join(base_dir, "history_cascaded.json"), "w") as f:
    json.dump(cascaded_history, f)

# %% [markdown]
# # Test

# %%
optimizer = optim.Adam(trained_classic_model.parameters(), lr=LR)

_, classic_history = train_classic_mobilenet(
    model=trained_classic_model,
    dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
)

classic_accuracy = classic_history['test_acc']
classic_superclass_accuracy = classic_history['test_acc_superclass']

optimizer = optim.Adam(trained_parallel_model.parameters(), lr=LR)

_, parallel_history = train_parallel_mobilenet(
    model=trained_parallel_model,
    dataloaders={'train': train_loader_parallel, 'val': val_loader_parallel, 'test':test_loader_parallel},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
)

parallel_accuracy = parallel_history['test_acc']
parallel_superclass_accuracy = parallel_history['test_acc_superclass']

optimizer = optim.Adam(trained_cascaded_model.parameters(), lr=LR)

_, cascaded_history = train_cascaded_mobilenet(
    model=trained_cascaded_model,
    dataloaders={'train': train_loader_cascaded, 'val': val_loader_cascaded, 'test':test_loader_cascaded},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
)

cascaded_accuracy = cascaded_history['test_acc']
cascaded_superclass_accuracy = cascaded_history['test_acc_superclass']

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Classic Accuracy', 'Parallel Accuracy', 'Cascaded Accuracy']

values = [classic_accuracy[0], parallel_accuracy[0], cascaded_accuracy[0]]

# Create a bar plot
plt.bar(categories, values)

# Add titles and labels
plt.title('Test Accuracy')
plt.xlabel('Method')
plt.ylabel('Accuracy')

for i, value in enumerate(values):
    plt.text(i, value + 0.01, f'{value:.3f}', ha='center', va='bottom')

plt.savefig(os.path.join(base_dir, 'test_accuracy.png'))

plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Classic Acc.', 'Parallel Acc.', 'Cascaded Acc.']

values = [classic_superclass_accuracy[0], parallel_superclass_accuracy[0], cascaded_superclass_accuracy[0]]

# Create a bar plot
plt.bar(categories, values)

# Add titles and labels
plt.title('Test Superclass Accuracy')
plt.xlabel('Method')
plt.ylabel('Accuracy')

for i, value in enumerate(values):
    plt.text(i, value + 0.01, f'{value:.3f}', ha='center', va='bottom')

plt.savefig(os.path.join(base_dir, 'test_superclass_accuracy.png'))

plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # Load Test

# %%
def re_evalutate_model(RoootPath, exp_no):
  exp_path = RootPath + str(exp_no) + '/'
  optimizer = optim.Adam(classic_model.parameters(), lr=LR)
  classic_model.load_state_dict(torch.load(exp_path + 'classic_model_epoch.pt'))
  # parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'))
  # cascaded_model.load_state_dict(torch.load(exp_path + 'cascaded_model_epoch.pt'))
  _, classic_history = train_classic_mobilenet(
    model=classic_model,
    dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
  )

  classic_accuracy = classic_history['test_acc']
  classic_superclass_accuracy = classic_history['test_acc_superclass']
  print(exp_no, classic_accuracy, classic_superclass_accuracy)

# %%
RootPath = '/content/drive/MyDrive/New Exps/SamplesH/'

max_vit_list = [43, 48, 52, 55, 58, 61]
conv_next_list = [44, 47, 53, 56, 59, 62]
dense_list = [45, 46, 54, 57, 60, 63]

for exp_no in dense_list:
  # exp_path = RootPath + str(exp_no) + '/'
  re_evalutate_model(RootPath, exp_no)
# Out:
# <ipython-input-39-2070f06296a4>:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   classic_model.load_state_dict(torch.load(exp_path + 'classic_model_epoch.pt'))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-61fd78c1ba6f> in <cell line: 0>()
#       7 for exp_no in dense_list:
#       8   # exp_path = RootPath + str(exp_no) + '/'
# ----> 9   re_evalutate_model(RootPath, exp_no)
#
# <ipython-input-39-2070f06296a4> in re_evalutate_model(RoootPath, exp_no)
#       2   exp_path = RootPath + str(exp_no) + '/'
#       3   optimizer = optim.Adam(classic_model.parameters(), lr=LR)
# ----> 4   classic_model.load_state_dict(torch.load(exp_path + 'classic_model_epoch.pt'))
#       5   # parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'))
#       6   # cascaded_model.load_state_dict(torch.load(exp_path + 'cascaded_model_epoch.pt'))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2582
#    2583         if len(error_msgs) > 0:
# -> 2584             raise RuntimeError(
#    2585                 "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586                     self.__class__.__name__, "\n\t".join(error_msgs)
#
# RuntimeError: Error(s) in loading state_dict for ClassicMobileNetV3:
# 	Missing key(s) in state_dict: "total_ops", "total_params", "mobilenet.total_ops", "mobilenet.total_params", "mobilenet.features.denseblock1.total_ops", "mobilenet.features.denseblock1.total_params", "mobilenet.features.denseblock1.denselayer1.total_ops", "mobilenet.features.denseblock1.denselayer1.total_params", "mobilenet.features.denseblock1.denselayer2.total_ops", "mobilenet.features.denseblock1.denselayer2.total_params", "mobilenet.features.denseblock1.denselayer3.total_ops", "mobilenet.features.denseblock1.denselayer3.total_params", "mobilenet.features.denseblock1.denselayer4.total_ops", "mobilenet.features.denseblock1.denselayer4.total_params", "mobilenet.features.denseblock1.denselayer5.total_ops", "mobilenet.features.denseblock1.denselayer5.total_params", "mobilenet.features.denseblock1.denselayer6.total_ops", "mobilenet.features.denseblock1.denselayer6.total_params", "mobilenet.features.transition1.total_ops", "mobilenet.features.transition1.total_params", "mobilenet.features.denseblock2.total_ops", "mobilenet.features.denseblock2.total_params", "mobilenet.features.denseblock2.denselayer1.total_ops", "mobilenet.features.denseblock2.denselayer1.total_params", "mobilenet.features.denseblock2.denselayer2.total_ops", "mobilenet.features.denseblock2.denselayer2.total_params", "mobilenet.features.denseblock2.denselayer3.total_ops", "mobilenet.features.denseblock2.denselayer3.total_params", "mobilenet.features.denseblock2.denselayer4.total_ops", "mobilenet.features.dens...

# %% [markdown]
# # Top 5 Accuracy

# %%
dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic}
device = 'cuda'

def topn_accuracy(output, target, n = 5):
    # Get the top 5 predicted class indices
    top5_preds = torch.topk(output, n, dim=1).indices  # (batch_size, 5)

    correct = top5_preds.eq(target.view(-1, 1)).sum().item()  # Count correct top-5 matches

    # Compute accuracy
    return correct / target.size(0)  # Convert to percentage


def top5acc(RoootPath, exp_no, n = 5):
  exp_path = RootPath + str(exp_no) + '/'
  optimizer = optim.Adam(classic_model.parameters(), lr=LR)
  classic_state = torch.load(exp_path + 'classic_model_epoch.pt')
  # print(classic_state.keys())
  classic_model.load_state_dict(classic_state, strict=False)
  parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'), strict=False)
  cascaded_model.load_state_dict(torch.load(exp_path + 'cascaded_model_epoch.pt'), strict=False)

  phase = 'test'
  all_classic_outputs = torch.empty(0, device=device)
  all_parallel_outputs = torch.empty(0, device=device)
  all_cascaded_outputs = torch.empty(0, device=device)
  all_labels = torch.empty(0, dtype=torch.long, device=device)
  classic_model.to(device)
  parallel_model.to(device)
  cascaded_model.to(device)
  classic_model.eval()
  parallel_model.eval()
  cascaded_model.eval()
  for inputs, labels in dataloaders[phase]:
    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()

    with torch.set_grad_enabled(phase == 'train'):
        classic_outputs = classic_model(inputs)
        parallel_outputs = parallel_model(inputs)[0]
        cascaded_outputs = cascaded_model(inputs)[0]

    all_classic_outputs = torch.cat((all_classic_outputs, classic_outputs), dim=0)
    all_parallel_outputs = torch.cat((all_parallel_outputs, parallel_outputs), dim=0)
    all_cascaded_outputs = torch.cat((all_cascaded_outputs, cascaded_outputs), dim=0)
    all_labels = torch.cat((all_labels, labels), dim=0)

  classic_top5_acc = topn_accuracy(all_classic_outputs, all_labels, n)
  parallel_top5_acc = topn_accuracy(all_parallel_outputs, all_labels, n)
  cascaded_top5_acc = topn_accuracy(all_cascaded_outputs, all_labels, n)
  print(n, round(classic_top5_acc, 3), round(parallel_top5_acc, 3), round(cascaded_top5_acc, 3))


RootPath = '/content/drive/MyDrive/New Exps/SamplesH/'
exp_no = 47
# top5acc(RootPath, exp_no, 1)
# top5acc(RootPath, exp_no, 2)
# top5acc(RootPath, exp_no, 3)
# top5acc(RootPath, exp_no, 4)
# top5acc(RootPath, exp_no, 5)
top5acc(RootPath, exp_no, 6)
top5acc(RootPath, exp_no, 7)
top5acc(RootPath, exp_no, 8)
# Out:
# <ipython-input-35-cc31c2bf1c71>:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   classic_state = torch.load(exp_path + 'classic_model_epoch.pt')
# <ipython-input-35-cc31c2bf1c71>:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'), strict=False)
# <ipython-input-35-cc31c2bf1c71>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cascaded_model.load_state_dict(torch.load(exp_path + 'cascaded_model_epoch.pt'), strict=False)
# 6 0.989 0.983 0.979
# 7 0.992 0.985 0.984
# 8 0.994 0.987 0.987
