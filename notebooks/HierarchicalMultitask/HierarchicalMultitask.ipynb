# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Install missing libraries
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->thop)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->thop)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->thop)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->thop)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->thop)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->thop)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->thop)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->thop) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 102.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 thop-0.1.1.post2209072238

# %%
import torchvision
import json
import os
import shutil
from google.colab.patches import cv2_imshow
import numpy as np
import math
import pickle
from torch.utils.data import random_split, DataLoader
import torch.optim as optim
import torch
import torch.nn as nn
from thop import profile

# %%
#@title Augementations

transform2 = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),  # Resize to 224x224 to match MobileNet's input size
    torchvision.transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize with ImageNet stats
    # torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((28, 28)),  # Resize to 224x224 to match MobileNet's input size
    torchvision.transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize with ImageNet stats
    # torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),
    torchvision.transforms.RandomHorizontalFlip(),
    # torchvision.transforms.RandomCrop(32, padding=4),
    torchvision.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    # torchvision.transforms.RandomRotation(15),
    torchvision.transforms.ToTensor(),
   #  torchvision.transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761]),  # CIFAR-100 normalization values
    torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),
    torchvision.transforms.ToTensor(),
    # torchvision.transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761]),
    torchvision.transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# train_transforms = test_transforms

# %%
EXP_NO = 150

EPOCHS = 10
DEVICE = 'cuda' # 'cpu'
LR = 3e-4
DROPOUT = 0
MAX_LR = 1e-3
LOSS_WEIGHTS = [0.9, 0.1] # [1, 0.2] # [0.2, 0.8] [0.5, 0.5]
BASE_DIR = f'/content/drive/MyDrive/New Exps/SamplesH/{EXP_NO}/'

MODEL_NAME = 'swin_b'

DATASET = 'CompCars' # 'CompCars' # cifar100, INaturalist, Places365, ImageNet, StandfordCars
AUGMENTATION = False
TRAIN_TRANSFORMS = train_transforms
TEST_TRANSFORMS = test_transforms

BATCH_SIZE = 32
SEED = 24

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()

os.makedirs(os.path.dirname(BASE_DIR), exist_ok=True)

# %%
import random

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(SEED)

# %%
EXPERIMENT_DICTIONARY = {
    'EPOCHS': EPOCHS,
    'DEVICE': DEVICE,
    'EXP_NO': EXP_NO,
    'MODEL': MODEL_NAME,
    'LR': LR,
    'DROPOUT': DROPOUT,
    'LOSS_FUNCTION': str(criterion),
    'OPTIMIZER': str(optim.Adam),
    'MAX_LR': MAX_LR,
    'LOSS_WEIGHTS': LOSS_WEIGHTS,
    'DATASET': DATASET,
    'AUGMENTATION': AUGMENTATION,
    'TRAIN_TRANSFORMS': str(TRAIN_TRANSFORMS),
    'TEST_TRANSFORMS': str(TEST_TRANSFORMS),
    'BATCH_SIZE': BATCH_SIZE,
    'SEED': SEED
}

with open(BASE_DIR + "exp_info.json", "w") as outfile:
    json.dump(EXPERIMENT_DICTIONARY, outfile)

# %%
if MODEL_NAME == 'mobilenet_v3_small':
  MODEL = torchvision.models.mobilenet_v3_small
elif MODEL_NAME == 'mobilenet_v3_large':
  MODEL = torchvision.models.mobilenet_v3_large
elif MODEL_NAME == 'resnet18':
  MODEL = torchvision.models.resnet18
elif MODEL_NAME == 'resnet50':
  MODEL = torchvision.models.resnet50
elif MODEL_NAME == 'swin_b':
  MODEL = torchvision.models.swin_s
elif MODEL_NAME == 'vgg16':
  MODEL = torchvision.models.vgg16
elif MODEL_NAME == 'vgg19':
  MODEL = torchvision.models.vgg19
elif MODEL_NAME == 'densenet121':
  MODEL = torchvision.models.densenet121
elif MODEL_NAME == 'vit_b_16':
  MODEL = torchvision.models.vit_b_16
elif MODEL_NAME == 'efficientnet_b0':
  MODEL = torchvision.models.efficientnet_b0
elif MODEL_NAME == 'maxvit_tVitV':
  MODEL = torchvision.models.maxvit_t
elif MODEL_NAME == 'convnext_base':
  MODEL = torchvision.models.convnext_base

# %% [markdown]
# # Dataset

# %%
# os.mkdir('/content/dataset/')
# os.mkdir('/content/dataset/train/')
# os.mkdir('/content/dataset/test/')

if not AUGMENTATION:
  TRAIN_TRANSFORMS = TEST_TRANSFORMS

if DATASET == 'cifar100':
  # train parameter ???
  train_dataset = torchvision.datasets.CIFAR100(root='/content/dataset/train/', download=True, transform=TRAIN_TRANSFORMS)
  test_dataset = torchvision.datasets.CIFAR100(root='/content/dataset/test/', download=True, transform=TEST_TRANSFORMS)

  NUM_CLASSES = 100
  NUM_SUPERCLASSES = 20
  NUM_SUBCLASSES = 100
elif DATASET == 'INaturalist':
  train_dataset = torchvision.datasets.INaturalist(root='/content/dataset/train/', download=True, transform=TRAIN_TRANSFORMS)
  test_dataset = torchvision.datasets.INaturalist(root='/content/dataset/test/', download=True, transform=TEST_TRANSFORMS)
elif DATASET == 'Places365':
  train_dataset = torchvision.datasets.Places365(root='/content/dataset/train/', download=True, transform=TRAIN_TRANSFORMS)
  test_dataset = torchvision.datasets.Places365(root='/content/dataset/test/', download=True, transform=TEST_TRANSFORMS)
elif DATASET == 'ImageNet': # ImageNet
  train_dataset = torchvision.datasets.ImageNet(root='/content/dataset/train/', download=True, transform=TRAIN_TRANSFORMS)
  test_dataset = torchvision.datasets.ImageNet(root='/content/dataset/test/', download=True, transform=TEST_TRANSFORMS)
elif DATASET == 'StandfordCars':
  # !unzip /content/drive/MyDrive/New\ Exps/Dataset/standford_cars.zip -d '/content/dataset/'
  shutil.copy("/content/drive/MyDrive/New Exps/Dataset/cardatasettrain.csv", "/content/dataset/cardatasettrain.csv")
  shutil.copy("/content/drive/MyDrive/New Exps/Dataset/cardatasettest.csv", "/content/dataset/cardatasettest.csv")
  NUM_CLASSES = 196
  NUM_SUPERCLASSES = 49
  NUM_SUBCLASSES = 196
elif DATASET == 'CompCars':
  # !mkdir /content/dataset
  # !unzip /content/drive/MyDrive/New\ Exps/Dataset/CompCars.zip -d /content/dataset
  NUM_CLASSES = 4446
  NUM_SUPERCLASSES = 164
  NUM_SUBCLASSES = 4446
else:
  assert False
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/image/105/309/2015/73c336fea99928.jpg
#   inflating: /content/dataset/image/105/309/2015/9912147ce7bfa5.jpg
#   inflating: /content/dataset/image/105/309/2015/e5550a932810eb.jpg
#   inflating: /content/dataset/image/105/314/2009/0cc2086f304602.jpg
#   inflating: /content/dataset/image/105/314/2009/20d36e9d285ec6.jpg
#   inflating: /content/dataset/image/105/314/2009/29108cfdb315d6.jpg
#   inflating: /content/dataset/image/105/314/2009/2cf9b22476bcc3.jpg
#   inflating: /content/dataset/image/105/314/2009/2f1cb4f7d60987.jpg
#   inflating: /content/dataset/image/105/314/2009/3cc2e3b1ec40b7.jpg
#   inflating: /content/dataset/image/105/314/2009/403253be593288.jpg
#   inflating: /content/dataset/image/105/314/2009/4aa0b57dd199da.jpg
#   inflating: /content/dataset/image/105/314/2009/4f802f13712433.jpg
#   inflating: /content/dataset/image/105/314/2009/5f04981b0a0529.jpg
#   inflating: /content/dataset/image/105/314/2009/67555989a0c0f5.jpg
#   inflating: /content/dataset/image/105/314/2009/73dea2016c3918.jpg
#   inflating: /content/dataset/image/105/314/2009/81a9854a3c08c2.jpg
#   inflating: /content/dataset/image/105/314/2009/8504a01936ee64.jpg
#   inflating: /content/dataset/image/105/314/2009/896200f31c6449.jpg
#   inflating: /content/dataset/image/105/314/2009/955ac46103cc24.jpg
#   inflating: /content/dataset/image/105/314/2009/96cde70d8de27a.jpg
#   inflating: /content/dataset/image/105/314/2009/986583a071462f.jpg
#   inflating: /content/dataset/image/105/314/2009/a53d903c6e3b9b.jpg
#   inflating: /content/dataset/image/105/314/2009/a97ee79227e551.jpg
#   inflating: /content/dataset/image/105/314/2009/acec0514f10235.jpg
#   inflating: /content/dataset/image/105/314/2009/b23bbe05978457.jpg
#   inflating: /content/dataset/image/105/314/2009/beb0ac3a7cdb4f.jpg
#   inflating: /content/dataset/image/105/314/2009/bf7e2fb1af94fa.jpg
#   inflating: /content/dataset/image/105/314/2009/cbb79e8a74b09c.jpg
#   inflating: /content/dataset/image/105/314/2009/e4057121ca4445.jpg
#   inflating: /content/dataset/image/105/314/2009/e47ffab69ed59c.jpg
#   inflating: /content/dataset/image/105/314/2009/ee2881a65628ce.jpg
#   inflating: /content/dataset/image/105/314/2009/ee45137a5be198.jpg
#   inflating: /content/dataset/image/105/314/2009/f143677e6f1c88.jpg
#   inflating: /content/dataset/image/105/314/2011/031d39b5115fb0.jpg
#   inflating: /content/dataset/image/105/314/2011/0eb3428118d3fa.jpg
#   inflating: /content/dataset/image/105/314/2011/113255df5e5cb5.jpg
#   inflating: /content/dataset/image/105/314/2011/2883fea0c11a51.jpg
#   inflating: /content/dataset/image/105/314/2011/2964b72a490d2a.jpg
#   inflating: /content/dataset/image/105/314/2011/330052ceca2275.jpg
#   inflating: /content/dataset/image/105/314/2011/370aa6650bc530.jpg
#   inflating: /content/dataset/image/105/314/2011/41f381d54d1c34.jpg
#   inflating: /content/dataset/image/105/314/2011/42c0371ece12b3.jpg
#   inflating: /content/dataset/image/105/314/2011/65eca6b48ea475.jpg
#   inflating: /content/dataset/image/105/314/2011/6d0b6e5a958afb.jpg
#   inflating: /content/dataset/image/105/314/2011/79b1f6f1c39fac.jpg
#   inflating: /content/dataset/image/105/314/2011/8eed5b7b05b0c0.jpg
#   inflating: /content/dataset/image/105/314/2011/916a32311312ce.jpg
#   inflating: /content/dataset/image/105/314/2011/9765681ed47524.jpg
#   inflating: /content/dataset/image/105/314/2011/9e5982a0cdf9e8.jpg
#   inflating: /content/dataset/image/105/314/2011/a14b0a19925801.jpg
#   inflating: /content/dataset/image/105/314/2011/b237168f383084.jpg
#   inflating: /content/dataset/image/105/314/2011/be40c8d189c69f.jpg
#   inflating: /content/dataset/image/105/314/2011/c1603bbacb7bf8.jpg
#   inflating: /content/dataset/image/105/314/2011/d3d18e4854e311.jpg
#   inflating: /content/dataset/image/105/314/2011/d44696e2de55b0.jpg
#   inflating: /content/dataset/image/105/314/2011/d49df01e11a1ac.jpg
#   inflating: /content/dataset/image/105/314/2011/ebcad298586a21.jpg
#   inflating: /content/dataset/image/105/314/2011/f86049726dd781.jpg
#   inflating: /content/dataset/image/105/314/2012/18f61e0cb6d47d.jpg
#   inflating: /content/dataset/image/105/314/2012/42a4531ec5448d.jpg
#   inflating: /content/dataset/image/105/314/2012/43ba75f7321958.jpg
#   inflating: /content/dataset/image/105/314/2012/4459de0c881650.jpg
#   inflating: /content/dataset/image/105/314/2012/4ef63e7f88e269.jpg
#   inflating: /content/dataset/image/105/314/2012/57f23c7d003811.jpg
#   inflating: /content/dataset/image/105/314/2012/7ba768389eaa64.jpg
#   inflating: /content/dataset/image/105/314/2012/7e77f3fc65e691.jpg
#   inflating: /content/dataset/image/105/314/2012/a360b07bd883db.jpg
#   inflating: /content/dataset/image/105/314/2012/a4fd6cc4780cc0.jpg
#   inflating: /content/dataset/image/105/314/2012/a8a3d453be38f1.jpg
#   inflating: /content/dataset/image/105/314/2012/b57bcdb38e37f5.jpg
#   inflating: /content/dataset/image/105/314/2012/c3b1e40d1cb9c9.jpg
#   inflating: /content/dataset/image/105/314/2012/e584fa79adf176.jpg
#   inflating: /content/dataset/image/105/314/2012/e916680ef6e241.jpg
#   inflating: /content/dataset/image/105/314/2012/e95b38ba53a924.jpg
#   inflating: /content/dataset/image/105/314/2013/019cc9d017e03e.jpg
#   inflating: /content/dataset/image/105/314/2013/0c254c51f2a880.jpg
#   inflating: /content/dataset/image/105/314/2013/1abd81bf68eabd.jpg
#   inflating: /content/dataset/image/105/314/2013/28b8cba32dc773.jpg
#   inflating: /content/dataset/image/105/314/2013/2b39837c3405af.jpg
#   inflating: /content/dataset/image/105/314/2013/34ffaec86f5a03.jpg
#   inflating: /content/dataset/image/105/314/2013/3af7fd41a17904.jpg
#   inflating: /content/dataset/image/105/314/2013/4eb0e187d1c42e.jpg
#   inflating: /content/dataset/image/105/314/2013/562c5a6d927218.jpg
#   inflating: /content/dataset/image/105/314/2013/59f725dd043aed.jpg
#   inflating: /content/dataset/image/105/314/2013/62346cc46ad77b.jpg
#   inflating: /content/dataset/image/105/314/2013/8118b2554d9ea5.jpg
#   inflating: /content/dataset/image/105/314/2013/8ce75330b2ad61.jpg
#   inflating: /content/dataset/image/105/314/2013/926e50eab34d0a.jpg
#   inflating: /content/dataset/image/105/314/2013/a4825b87d796d9.jpg
#   inflating: /content/dataset/image/105/314/2013/ae729b2db0e596.jpg
#   inflating: /content/dataset/image/105/314/2013/b870149df5b2cd.jpg
#   inflating: /content/dataset/image/105/314/2013/b9e959c3bdf90e.jpg
#   inflating: /content/dataset/image/105/314/2013/c220c88edf80d1.jpg
#   inflating: /content/dataset/image/105/314/2013/daaf43ebb760c9.jpg
#   inflating: /content/dataset/image/105/314/2014/19eb6825604a97.jpg
#   inflating: /content/dataset/image/105/314/2014/31359cb2a3e978.jpg
#   inflating: /content/dataset/image/105/314/2014/4fc207e5c135b9.jpg
#   inflating: /content/dataset/image/105/314/2014/50a3f41473bf4d.jpg
#   inflating: /content/dataset/image/105/314/2014/56bb97d926e8c1.jpg
#   inflating: /content/dataset/image/105/314/2014/68e27b257d3c32.jpg
#   inflating: /content/dataset/image/105/314/2014/6aab3647dad2b2.jpg
#   inflating: /content/dataset/image/105/314/2014/714618eb338efc.jpg
#   inflating: /content/dataset/image/105/314/2014/737c7d5f952a5b.jpg
#   inflating: /content/dataset/image/105/314/2014/8080d234241510.jpg
#   inflating: /content/dataset/image/105/314/2014/8a0ef13aff9df8.jpg
#   inflating: /content/dataset/image/105/314/2014/8cf72adebaae3d.jpg
#   inflating: /content/dataset/image/105/314/2014/8ea1d3f0cb1090.jpg
#   inflating: /content/dataset/image/105/314/2014/91f70d3c7a3bac.jpg
#   inflating: /content/dataset/image/105/314/2014/a28df312826763.jpg
#   inflating: /content/dataset/image/105/314/2014/a4592883d1fd60.jpg
#   inflating: /content/dataset/image/105/314/2014/c5fa9b64684985.jpg
#   inflating: /content/dataset/image/105/314/2014/ce52eaf47fcbf3.jpg
#   inflating: /content/dataset/image/105/314/2014/d192afed336679.jpg
#   inflating: /content/dataset/image/105/314/2014/ec339aa44ecaf6.jpg
#   inflating: /content/dataset/image/105/314/2015/44e19d5cb3deac.jpg
#   inflating: /content/dataset/image/105/314/2015/791c5cfd00d3b9.jpg
#   inflating: /content/dataset/image/105/314/2015/7b1a7583d08985.jpg
#   inflating: /content/dataset/image/105/314/2015/adf0e88ecf1888.jpg
#   inflating: /content/dataset/image/105/314/2015/b49c1a6838fcb4.jpg
#   inflating: /content/dataset/image/105/314/2015/d0b628fba9e8d6.jpg
#   inflating: /content/dataset/image/105/314/2015/d938b145f910db.jpg
#   inflating: /content/dataset/image/105/314/2015/de3081d0c14435.jpg
#   inflating: /content/dataset/image/105/314/2015/e756c7774b7eb7.jpg
#   inflating: /content/dataset/image/106/1311/2013/00c913e693c642.jpg
#   inflating: /content/dataset/image/106/1311/2013/1c5405f98afa56.jpg
#   inflating: /content/dataset/image/106/1311/2013/2269711095b904.jpg
#   inflating: /content/dataset/image/106/1311/2013/2de1cb6c412fe3.jpg
#   inflating: /content/dataset/image/106/1311/2013/32523b89560601.jpg
#   inflating: /content/dataset/image/106/1311/2013/38b14aa52a1238.jpg
#   inflating: /content/dataset/image/106/1311/2013/3f6d2dd4926928.jpg
#   inflating: /content/dataset/image/106/1311/2013/41901eaa65fdc8.jpg
#   inflating: /content/dataset/image/106/1311/2013/48c083c1533e8c.jpg
#   inflating: /content/dataset/image/106/1311/2013/61b484ca9a21d4.jpg
#   inflating: /content/dataset/image/106/1311/2013/62ae2c9d424005.jpg
#   inflating: /content/dataset/image/106/1311/2013/7876d9ee029ebf.jpg
#   inflating: /content/dataset/image/106/1311/2013/7cad9aadb36820.jpg
#   inflating: /content/dataset/image/106/1311/2013/9496ef099e165d.jpg
#   inflating: /content/dataset/image/106/1311/2013/95f78aed1f9bf0.jpg
#   inflating: /content/dataset/image/106/1311/2013/99daa737518fe9.jpg
#   inflating: /content/dataset/image/106/1311/2013/a198ae9f59e058.jpg
#   inflating: /content/dataset/image/106/1311/2013/b37dba6c0f6520.jpg
#   inflating: /content/dataset/image/106/1311/2013/bf6dc0787b9cbc.jpg
#   inflating: /content/dataset/image/106/1311/2015/0e74a58b281d6b.jpg
#   inflating: /content/dataset/image/106/1311/2015/1779fcaf6ee586.jpg
#   inflating: /content/dataset/image/106/1311/2015/5d820524d61698.jpg
#   inflating: /content/dataset/image/106/1311/2015/99df652802e4d8.jpg
#   inflating: /content/dataset/image/106/1312/2012/019d8e903e84ef.jpg
#   inflating: /content/dataset/image/106/1312/2012/01ca5d72b8cf15.jpg
#   inflating: /content/dataset/image/106/1312/2012/084c2c0070236e.jpg
#   inflating: /content/dataset/image/106/1312/2012/12c9c4d04b15b5.jpg
#   inflating: /content/dataset/image/106/1312/2012/24404ace23ee5c.jpg
#   inflating: /content/dataset/image/106/1312/2012/25544b1d4a9b49.jpg
#   inflating: /content/dataset/image/106/1312/2012/280c6a9fdef23a.jpg
#   inflating: /content/dataset/image/106/1312/2012/3bf5cda4f04a60.jpg
#   inflating: /content/dataset/image/106/1312/2012/45bbb56d9d2ca9.jpg
#   inflating: /content/dataset/image/106/1312/2012/49df85c7704c2c.jpg
#   inflating: /content/dataset/image/106/1312/2012/4a8805f8d4b0f1.jpg
#   inflating: /content/dataset/image/106/1312/2012/5347f865a1801b.jpg
#   inflating: /content/dataset/image/106/1312/2012/6119f2db698085.jpg
#   inflating: /content/dataset/image/106/1312/2012/69e4709fae9440.jpg
#   inflating: /content/dataset/image/106/1312/2012/7af6145bfdefad.jpg
#   inflating: /content/dataset/image/106/1312/2012/7b59fa2516411a.jpg
#   inflating: /content/dataset/image/106/1312/2012/8cb2f07a4a2c5b.jpg
#   inflating: /content/dataset/image/106/1312/2012/8f0eb895c8f4af.jpg
#   inflating: /content/dataset/image/106/1312/2012/942eca2b3f99a2.jpg
#   inflating: /content/dataset/image/106/1312/2012/a0385236f9e525.jpg
#   inflating: /content/dataset/image/106/1312/2012/a09ef4886ed96b.jpg
#   inflating: /content/dataset/image/106/1312/2012/b1c2a16e912719.jpg
#   inflating: /content/dataset/image/106/1312/2012/b7129fb56e5694.jpg
#   inflating: /content/dataset/image/106/1312/2012/c0f0676d9a0e36.jpg
#   inflating: /content/dataset/image/106/1312/2012/db91416c2ae3ba.jpg
#   inflating: /content/dataset/image/106/1312/2012/dc4127f9995938.jpg
#   inflating: /content/dataset/image/106/1312/2012/e5900f8a874060.jpg
#   inflating: /content/dataset/image/106/1312/2012/fc97768370fd47.jpg
#   inflating: /content/dataset/image/106/1313/2006/408b4d096b2a63.jpg
#   inflating: /content/dataset/image/106/1313/2006/50ba49f4662b81.jpg
#   inflating: /content/dataset/image/106/1313/2006/5dee7cd19bffef.jpg
#   inflating: /content/dataset/image/106/1313/2006/f9842c6de02743.jpg
#   inflating: /content/dataset/image/106/1313/2008/0e9aae9c2b14b0.jpg
#   inflating: /content/dataset/image/106/1313/2008/15360347870298.jpg
#   inflating: /content/dataset/image/106/1313/2008/1c829dc0fa7609.jpg
#   inflating: /content/dataset/image/106/1313/2008/2036b33804aebf.jpg
#   inflating: /content/dataset/image/106/1313/2008/2869d72ec8b4e9.jpg
#   inflating: /content/dataset/image/106/1313/2008/3d558f904bcefa.jpg
#   inflating: /content/dataset/image/106/1313/2008/4304f653d7716c.jpg
#   inflating: /content/dataset/image/106/1313/2008/434b3ac0a2c5d2.jpg
#   inflating: /content/dataset/image/106/1313/2008/4cfbde18100e25.jpg
#   inflating: /content/dataset/image/106/1313/2008/54dc240c3345ae.jpg
#   inflating: /content/dataset/image/106/1313/2008/5d0bebe6071533.jpg
#   inflating: /content/dataset/image/106/1313/2008/6d3472369fd19e.jpg
#   inflating: /content/dataset/image/106/1313/2008/720d33d10782b5.jpg
#   inflating: /content/dataset/image/106/1313/2008/730ec6d415a830.jpg
#   inflating: /content/dataset/image/106/1313/2008/8a9bcd5ccea874.jpg
#   inflating: /content/dataset/image/106/1313/2008/8f4fa805ef501e.jpg
#   inflating: /content/dataset/image/106/1313/2008/92e70f9d751e26.jpg
#   inflating: /content/dataset/image/106/1313/2008/941375aa9a3dbc.jpg
#   inflating: /content/dataset/image/106/1313/2008/c31600c858740d.jpg
#   inflating: /content/dataset/image/106/1313/2008/ca99a1301e6612.jpg
#   inflating: /content/dataset/image/106/1313/2008/d00bd2cac5a0be.jpg
#   inflating: /content/dataset/image/106/1313/2008/d1e7d4d311d6c4.jpg
#   inflating: /content/dataset/image/106/1313/2008/d980eab7e9b5a2.jpg
#   inflating: /content/dataset/image/106/1313/2008/ebfd199ff0a11c.jpg
#   inflating: /content/dataset/image/106/1313/2008/ed80e74bb03a07.jpg
#   inflating: /content/dataset/image/106/1313/2008/f1bce21c7a2bf2.jpg
#   inflating: /content/dataset/image/106/1313/2010/0c499e25349ff0.jpg
#   inflating: /content/dataset/image/106/1313/2010/0cdfc9a036f47b.jpg
#   inflating: /content/dataset/image/106/1313/2010/1aaf79c9bc1f96.jpg
#   inflating: /content/dataset/image/106/1313/2010/1b829507623919.jpg
#   inflating: /content/dataset/image/106/1313/2010/46b777fd81a12d.jpg
#   inflating: /content/dataset/image/106/1313/2010/6b263e64a7f849.jpg
#   inflating: /content/dataset/image/106/1313/2010/6d9254bdedc0bb.jpg
#   inflating: /content/dataset/image/106/1313/2010/ab7457f1305076.jpg
#   inflating: /content/dataset/image/106/1313/2010/c5d9ece4aa6f22.jpg
#   inflating: /content/dataset/image/106/1313/2010/d3f10745da597f.jpg
#   inflating: /content/dataset/image/106/1313/2012/0ce0e13164259e.jpg
#   inflating: /content/dataset/image/106/1313/2012/16110eb2a2559e.jpg
#   inflating: /content/dataset/image/106/1313/2012/2e04ec770e7119.jpg
#   inflating: /content/dataset/image/106/1313/2012/2e764e5e4efcae.jpg
#   inflating: /content/dataset/image/106/1313/2012/398241fcab675e.jpg
#   inflating: /content/dataset/image/106/1313/2012/3e9d88604e52e7.jpg
#   inflating: /content/dataset/image/106/1313/2012/402dc7a81e0070.jpg
#   inflating: /content/dataset/image/106/1313/2012/41be6080abf94a.jpg
#   inflating: /content/dataset/image/106/1313/2012/52da254ddf496b.jpg
#   inflating: /content/dataset/image/106/1313/2012/55425185386fd4.jpg
#   inflating: /content/dataset/image/106/1313/2012/57778d63c6932f.jpg
#   inflating: /content/dataset/image/106/1313/2012/74ab1f0fa856c9.jpg
#   inflating: /content/dataset/image/106/1313/2012/93cc711c7ff459.jpg
#   inflating: /content/dataset/image/106/1313/2012/93eb441c1dec65.jpg
#   inflating: /content/dataset/image/106/1313/2012/957950d69a2a9f.jpg
#   inflating: /content/dataset/image/106/1313/2012/96c724dec42f53.jpg
#   inflating: /content/dataset/image/106/1313/2012/9ba6928151e1ca.jpg
#   inflating: /content/dataset/image/106/1313/2012/a449f6b3b49033.jpg
#   inflating: /content/dataset/image/106/1313/2012/a7b01c92d211e6.jpg
#   inflating: /content/dataset/image/106/1313/2012/c0cd78b815977a.jpg
#   inflating: /content/dataset/image/106/1313/2012/e8ad5ffd99e572.jpg
#   inflating: /content/dataset/image/106/1313/2012/f6bca1da32a6bb.jpg
#   inflating: /content/dataset/image/106/1313/2012/f7e195981d14d0.jpg
#   inflating: /content/dataset/image/106/1313/2012/f990c1b90a9342.jpg
#   inflating: /content/dataset/image/106/1313/2012/fb971615d9e40d.jpg
#   inflating: /content/dataset/image/106/1313/2012/fd1f8e060500e9.jpg
#   inflating: /content/dataset/image/106/1313/2013/07c4c1a567534d.jpg
#   inflating: /content/dataset/image/106/1313/2013/13530b01908a1f.jpg
#   inflating: /content/dataset/image/106/1313/2013/2152908ba620df.jpg
#   inflating: /content/dataset/image/106/1313/2013/263add47f34577.jpg
#   inflating: /content/dataset/image/106/1313/2013/2b04808e5403f6.jpg
#   inflating: /content/dataset/image/106/1313/2013/2c025deea4b457.jpg
#   inflating: /content/dataset/image/106/1313/2013/3df678b742f83c.jpg
#   inflating: /content/dataset/image/106/1313/2013/3f06a40b02068a.jpg
#   inflating: /content/dataset/image/106/1313/2013/51dbaca3aacbc7.jpg
#   inflating: /content/dataset/image/106/1313/2013/536a85868b0a2b.jpg
#   inflating: /content/dataset/image/106/1313/2013/55134fd74db16a.jpg
#   inflating: /content/dataset/image/106/1313/2013/56e8c5e6bd7614.jpg
#   inflating: /content/dataset/image/106/1313/2013/5c8fe55fd251f6.jpg
#   inflating: /content/dataset/image/106/1313/2013/647591b4ab8e56.jpg
#   inflating: /content/dataset/image/106/1313/2013/73a54963e5859d.jpg
#   inflating: /content/dataset/image/106/1313/2013/75ea40161042d9.jpg
#   inflating: /content/dataset/image/106/1313/2013/771041bda7a4ff.jpg
#   inflating: /content/dataset/image/106/1313/2013/97587042496633.jpg
#   inflating: /content/dataset/image/106/1313/2013/97e77936049dea.jpg
#   inflating: /content/dataset/image/106/1313/2013/adae8c813ffa10.jpg
#   inflating: /content/dataset/image/106/1313/2013/ade46a87f46db0.jpg
#   inflating: /content/dataset/image/106/1313/2013/b01ab981a04e6d.jpg
#   inflating: /content/dataset/image/106/1313/2013/b81f40fecbed43.jpg
#   inflating: /content/dataset/image/106/1313/2013/c9f2870498d923.jpg
#   inflating: /content/dataset/image/106/1313/2013/d7550738f1d1bb.jpg
#   inflating: /content/dataset/image/106/1313/2013/d8209c3242644c.jpg
#   inflating: /content/dataset/image/106/1313/2013/e295cb4686ca88.jpg
#   inflating: /content/dataset/image/106/1313/2013/fe59f2fd31f884.jpg
#   inflating: /content/dataset/image/106/1313/2014/1a22809e8456d9.jpg
#   inflating: /content/dataset/image/106/1313/2014/2118c2a875832a.jpg
#   inflating: /content/dataset/image/106/1313/2014/264d7c2cee1644.jpg
#   inflating: /content/dataset/image/106/1313/2014/2923f1ce4c5382.jpg
#   inflating: /content/dataset/image/106/1313/2014/2b6061ffd9e8dd.jpg
#   inflating: /content/dataset/image/106/1313/2014/2bd951c62a8999.jpg
#   inflating: /content/dataset/image/106/1313/2014/53a166a7de3dbf.jpg
#   inflating: /content/dataset/image/106/1313/2014/5defdd3aabef9d.jpg
#   inflating: /content/dataset/image/106/1313/2014/84f91ec46f0dae.jpg
#   inflating: /content/dataset/image/106/1313/2014/8cd58f10548f44.jpg
#   inflating: /content/dataset/image/106/1313/2014/8f9ad86080256c.jpg
#   inflating: /content/dataset/image/106/1313/2014/97b259a13b3462.jpg
#   inflating: /content/dataset/image/106/1313/2014/9b28a7b82b2984.jpg
#   inflating: /content/dataset/image/106/1313/2014/9e6aad42908c42.jpg
#   inflating: /content/dataset/image/106/1313/2014/a32130345be900.jpg
#   inflating: /content/dataset/image/106/1313/2014/acc2e9a2966bc9.jpg
#   inflating: /content/dataset/image/106/1313/2014/c981841f4f68d6.jpg
#   inflating: /content/dataset/image/106/1313/2014/cb65cd0d5ecc1b.jpg
#   inflating: /content/dataset/image/106/1313/2014/dd2540c82237fa.jpg
#   inflating: /content/dataset/image/106/1313/2014/e683eed0f32de2.jpg
#   inflating: /content/dataset/image/106/1313/2014/f093b83284dec2.jpg
#   inflating: /content/dataset/image/106/1313/2014/f8dfdf8e8c2994.jpg
#   inflating: /content/dataset/image/107/1470/2012/768727463fff79.jpg
#   inflating: /content/dataset/image/107/1470/2012/a9389ffe9449fa.jpg
#   inflating: /content/dataset/image/108/1516/2008/79d8f372132b03.jpg
#   inflating: /content/dataset/image/108/1516/2009/01a471f692a867.jpg
#   inflating: /content/dataset/image/108/1516/2009/067b58d0050083.jpg
#   inflating: /content/dataset/image/108/1516/2009/1324476d04ac33.jpg
#   inflating: /content/dataset/image/108/1516/2009/189ce7e7a595a2.jpg
#   inflating: /content/dataset/image/108/1516/2009/2193855a5b9a81.jpg
#   inflating: /content/dataset/image/108/1516/2009/266031a44bede6.jpg
#   inflating: /content/dataset/image/108/1516/2009/290966cf273a72.jpg
#   inflating: /content/dataset/image/108/1516/2009/2a9aca12a6b7a9.jpg
#   inflating: /content/dataset/image/108/1516/2009/34ad6b6b26834d.jpg
#   inflating: /content/dataset/image/108/1516/2009/34b3d632a50d51.jpg
#   inflating: /content/dataset/image/108/1516/2009/3a9089fcf4140b.jpg
#   inflating: /content/dataset/image/108/1516/2009/3cd53e6609b39f.jpg
#   inflating: /content/dataset/image/108/1516/2009/40aeeb1c05c70f.jpg
#   inflating: /content/dataset/image/108/1516/2009/47b959df0e248c.jpg
#   inflating: /content/dataset/image/108/1516/2009/4a414de0a50c62.jpg
#   inflating: /content/dataset/image/108/1516/2009/52aa56fb22d318.jpg
#   inflating: /content/dataset/image/108/1516/2009/552bf612e20867.jpg
#   inflating: /content/dataset/image/108/1516/2009/61877098c09472.jpg
#   inflating: /content/dataset/image/108/1516/2009/64c7dd4942a790.jpg
#   inflating: /content/dataset/image/108/1516/2009/801f8e34d93d8b.jpg
#   inflating: /content/dataset/image/108/1516/2009/80455d26a1a454.jpg
#   inflating: /content/dataset/image/108/1516/2009/81cd1bb7fd71b4.jpg
#   inflating: /content/dataset/image/108/1516/2009/822b865354e725.jpg
#   inflating: /content/dataset/image/108/1516/2009/82347e60164ec6.jpg
#   inflating: /content/dataset/image/108/1516/2009/8f26475d4e354a.jpg
#   inflating: /content/dataset/image/108/1516/2009/8f31b1f4d011bd.jpg
#   inflating: /content/dataset/image/108/1516/2009/9d1754bb4829e5.jpg
#   inflating: /content/dataset/image/108/1516/2009/a5b4919f587b09.jpg
#   inflating: /content/dataset/image/108/1516/2009/ab71216755719b.jpg
#   inflating: /content/dataset/image/108/1516/2009/ba1e201e8fbaab.jpg
#   inflating: /content/dataset/image/108/1516/2009/c37d657f2052bf.jpg
#   inflating: /content/dataset/image/108/1516/2009/c4d43c2a2748fa.jpg
#   inflating: /content/dataset/image/108/1516/2009/cc4bcd3f46c9d0.jpg
#   inflating: /content/dataset/image/108/1516/2009/cf4fc7e127db9d.jpg
#   inflating: /content/dataset/image/108/1516/2009/da0593d9bcba33.jpg
#   inflating: /content/dataset/image/108/1516/2009/dc618e0cd8c27f.jpg
#   inflating: /content/dataset/image/108/1516/2009/dc6588fcc62ca3.jpg
#   inflating: /content/dataset/image/108/1516/2009/ddf351562dd037.jpg
#   inflating: /content/dataset/image/108/1516/2009/dfded384b25068.jpg
#   inflating: /content/dataset/image/108/1516/2009/e05aa582e708d4.jpg
#   inflating: /content/dataset/image/108/1516/2009/e3f39449188ce3.jpg
#   inflating: /content/dataset/image/108/1516/2009/e64b3d6feaa917.jpg
#   inflating: /content/dataset/image/108/1516/2009/ef2f0c4da4ba70.jpg
#   inflating: /content/dataset/image/108/1516/2009/f191a74103f7ad.jpg
#   inflating: /content/dataset/image/108/1516/2009/f1c31c3242cbaf.jpg
#   inflating: /content/dataset/image/108/1516/2009/fbfa6e96df2351.jpg
#   inflating: /content/dataset/image/108/1516/2010/27233fbbd2a09a.jpg
#   inflating: /content/dataset/image/108/1516/2010/3760f07e7448ab.jpg
#   inflating: /content/dataset/image/108/1516/2010/6197719e8df392.jpg
#   inflating: /content/dataset/image/108/1516/2010/65acab48bde860.jpg
#   inflating: /content/dataset/image/108/1516/2010/78fac4670b8750.jpg
#   inflating: /content/dataset/image/108/1516/2010/7bfaa2a5e0fc2c.jpg
#   inflating: /content/dataset/image/108/1516/2010/a9f5e621ed08d2.jpg
#   inflating: /content/dataset/image/108/1516/2010/aca5525203aa06.jpg
#   inflating: /content/dataset/image/108/1516/2010/b256ab940de625.jpg
#   inflating: /content/dataset/image/108/1516/2010/d640a170c01cb2.jpg
#   inflating: /content/dataset/image/108/1516/2010/e34c9e505ff047.jpg
#   inflating: /content/dataset/image/108/1516/2011/0e2ede6e2b3ff8.jpg
#   inflating: /content/dataset/image/108/1516/2011/18becbf55f4068.jpg
#   inflating: /content/dataset/image/108/1516/2011/22c204ecce0f10.jpg
#   inflating: /content/dataset/image/108/1516/2011/2680fa57e88d3a.jpg
#   inflating: /content/dataset/image/108/1516/2011/2905183b3b37ac.jpg
#   inflating: /content/dataset/image/108/1516/2011/3a8c2b63825f33.jpg
#   inflating: /content/dataset/image/108/1516/2011/3bc5f9b2f9a776.jpg
#   inflating: /content/dataset/image/108/1516/2011/3f83f709c4095c.jpg
#   inflating: /content/dataset/image/108/1516/2011/5e7b7a68ae2947.jpg
#   inflating: /content/dataset/image/108/1516/2011/6578f250faf874.jpg
#   inflating: /content/dataset/image/108/1516/2011/72ae46ad4dd0e7.jpg
#   inflating: /content/dataset/image/108/1516/2011/84e667b8557617.jpg
#   inflating: /content/dataset/image/108/1516/2011/87dfc159a6a30a.jpg
#   inflating: /content/dataset/image/108/1516/2011/8a565acfedffa2.jpg
#   inflating: /content/dataset/image/108/1516/2011/8c6d5673037d5a.jpg
#   inflating: /content/dataset/image/108/1516/2011/904dfad58d798a.jpg
#   inflating: /content/dataset/image/108/1516/2011/94b608cfb167f6.jpg
#   inflating: /content/dataset/image/108/1516/2011/983c5e6e53e4a1.jpg
#   inflating: /content/dataset/image/108/1516/2011/9d0d6c1feedf68.jpg
#   inflating: /content/dataset/image/108/1516/2011/9f6b435f5e1841.jpg
#   inflating: /content/dataset/image/108/1516/2011/a0530d5c9ee430.jpg
#   inflating: /content/dataset/image/108/1516/2011/a12c70ff54389c.jpg
#   inflating: /content/dataset/image/108/1516/2011/a496627d588403.jpg
#   inflating: /content/dataset/image/108/1516/2011/a4c9af57eb5633.jpg
#   inflating: /content/dataset/image/108/1516/2011/a9fe87109d7481.jpg
#   inflating: /content/dataset/image/108/1516/2011/afb9b05ca7698e.jpg
#   inflating: /content/dataset/image/108/1516/2011/be04b831e5acf6.jpg
#   inflating: /content/dataset/image/108/1516/2011/c1a38575a2acf7.jpg
#   inflating: /content/dataset/image/108/1516/2011/ca7673362efbda.jpg
#   inflating: /content/dataset/image/108/1516/2011/cc647d240bf7c2.jpg
#   inflating: /content/dataset/image/108/1516/2011/ce5a4c4e7ddd66.jpg
#   inflating: /content/dataset/image/108/1516/2011/d6521c14f9946b.jpg
#   inflating: /content/dataset/image/108/1516/2011/d94416690a07c7.jpg
#   inflating: /content/dataset/image/108/1516/2011/e2188e2abb0ad2.jpg
#   inflating: /content/dataset/image/108/1516/2011/f02cb55728bd60.jpg
#   inflating: /content/dataset/image/108/1516/2011/f79ffd185804fd.jpg
#   inflating: /content/dataset/image/108/1516/2011/f96c3da0f08013.jpg
#   inflating: /content/dataset/image/108/1516/2012/0cd2124700ed51.jpg
#   inflating: /content/dataset/image/108/1516/2012/110fb8051f49c7.jpg
#   inflating: /content/dataset/image/108/1516/2012/137ff6653158fc.jpg
#   inflating: /content/dataset/image/108/1516/2012/19d07a316e36af.jpg
#   inflating: /content/dataset/image/108/1516/2012/1d31cb0fc21fb9.jpg
#   inflating: /content/dataset/image/108/1516/2012/275078c884261f.jpg
#   inflating: /content/dataset/image/108/1516/2012/2cd07dfc48a74d.jpg
#   inflating: /content/dataset/image/108/1516/2012/399bb4b0b1703a.jpg
#   inflating: /content/dataset/image/108/1516/2012/453e52c950a2ca.jpg
#   inflating: /content/dataset/image/108/1516/2012/609d0a91505083.jpg
#   inflating: /content/dataset/image/108/1516/2012/68424ef537ad72.jpg
#   inflating: /content/dataset/image/108/1516/2012/71d980f309cd99.jpg
#   inflating: /content/dataset/image/108/1516/2012/7a2c376c98b19e.jpg
#   inflating: /content/dataset/image/108/1516/2012/7f811f9be31bbc.jpg
#   inflating: /content/dataset/image/108/1516/2012/97fa4036bd7113.jpg
#   inflating: /content/dataset/image/108/1516/2012/9be7632408969a.jpg
#   inflating: /content/dataset/image/108/1516/2012/b65c7fa71bf712.jpg
#   inflating: /content/dataset/image/108/1516/2012/c29bd8b4addff7.jpg
#   inflating: /content/dataset/image/108/1516/2012/c57d2b9c8311a4.jpg
#   inflating: /content/dataset/image/108/1516/2012/ca03e366d9d17e.jpg
#   inflating: /content/dataset/image/108/1516/2012/cd4ceabf2f2ea6.jpg
#   inflating: /content/dataset/image/108/1516/2012/d43f0e596b8453.jpg
#   inflating: /content/dataset/image/108/1516/2012/fe6d580a90de57.jpg
#   inflating: /content/dataset/image/108/1520/2013/02835735c05700.jpg
#   inflating: /content/dataset/image/108/1520/2013/0441ea6366435a.jpg
#   inflating: /content/dataset/image/108/1520/2013/07d8059deb8ab9.jpg
#   inflating: /content/dataset/image/108/1520/2013/0881dcb429f0d8.jpg
#   inflating: /content/dataset/image/108/1520/2013/0c7b7c8f71b57c.jpg
#   inflating: /content/dataset/image/108/1520/2013/16c82ddec96878.jpg
#   inflating: /content/dataset/image/108/1520/2013/1a9eeba380ca2f.jpg
#   inflating: /content/dataset/image/108/1520/2013/1f13be7b18e647.jpg
#   inflating: /content/dataset/image/108/1520/2013/1f306a87f955ec.jpg
#   inflating: /content/dataset/image/108/1520/2013/23811a20e3642d.jpg
#   inflating: /content/dataset/image/108/1520/2013/2484fbff2d1286.jpg
#   inflating: /content/dataset/image/108/1520/2013/30bdd809509267.jpg
#   inflating: /content/dataset/image/108/1520/2013/322c7c278e8fdf.jpg
#   inflating: /content/dataset/image/108/1520/2013/362be9558e2100.jpg
#   inflating: /content/dataset/image/108/1520/2013/3af7d3fbb83bac.jpg
#   inflating: /content/dataset/image/108/1520/2013/3b869228c7299d.jpg
#   inflating: /content/dataset/image/108/1520/2013/3e761455ba8e10.jpg
#   inflating: /content/dataset/image/108/1520/2013/3e77d9c9e5916d.jpg
#   inflating: /content/dataset/image/108/1520/2013/4183c9c9fc6ba7.jpg
#   inflating: /content/dataset/image/108/1520/2013/42219598a5d62e.jpg
#   inflating: /content/dataset/image/108/1520/2013/4d74150f8a23d5.jpg
#   inflating: /content/dataset/image/108/1520/2013/51bb84243ff52e.jpg
#   inflating: /content/dataset/image/108/1520/2013/5436718275f6c8.jpg
#   inflating: /content/dataset/image/108/1520/2013/57e58b9d04f17f.jpg
#   inflating: /content/dataset/image/108/1520/2013/5a6f4253ac1810.jpg
#   inflating: /content/dataset/image/108/1520/2013/5b5dba5413710e.jpg
#   inflating: /content/dataset/image/108/1520/2013/5d90ce23004a43.jpg
#   inflating: /content/dataset/image/108/1520/2013/5fdf3a0b6db9bb.jpg
#   inflating: /content/dataset/image/108/1520/2013/60df932339bc52.jpg
#   inflating: /content/dataset/image/108/1520/2013/618e31788f72ce.jpg
#   inflating: /content/dataset/image/108/1520/2013/622f2ba48199c8.jpg
#   inflating: /content/dataset/image/108/1520/2013/68cb30f8e0ad60.jpg
#   inflating: /content/dataset/image/108/1520/2013/6c24ff3249a81d.jpg
#   inflating: /content/dataset/image/108/1520/2013/6df6244bb26f36.jpg
#   inflating: /content/dataset/image/108/1520/2013/6fb281f4e88e53.jpg
#   inflating: /content/dataset/image/108/1520/2013/76b43ef115e22e.jpg
#   inflating: /content/dataset/image/108/1520/2013/78e6f927f53f3d.jpg
#   inflating: /content/dataset/image/108/1520/2013/8377a5a011a1f7.jpg
#   inflating: /content/dataset/image/108/1520/2013/86a7ce639fac42.jpg
#   inflating: /content/dataset/image/108/1520/2013/898c059f7ff08f.jpg
#   inflating: /content/dataset/image/108/1520/2013/8b47040fb9b83d.jpg
#   inflating: /content/dataset/image/108/1520/2013/8e0affbe45dd64.jpg
#   inflating: /content/dataset/image/108/1520/2013/8f83a23b3f33d1.jpg
#   inflating: /content/dataset/image/108/1520/2013/93683fede931e8.jpg
#   inflating: /content/dataset/image/108/1520/2013/93f44acb484e1a.jpg
#   inflating: /content/dataset/image/108/1520/2013/9473e887542414.jpg
#   inflating: /content/dataset/image/108/1520/2013/96faa04b663641.jpg
#   inflating: /content/dataset/image/108/1520/2013/971690f4f93dcd.jpg
#   inflating: /content/dataset/image/108/1520/2013/97b9e6343ee1e3.jpg
#   inflating: /content/dataset/image/108/1520/2013/983c45ae3dbd95.jpg
#   inflating: /content/dataset/image/108/1520/2013/9cf59f6c222163.jpg
#   inflating: /content/dataset/image/108/1520/2013/a04251b7378c75.jpg
#   inflating: /content/dataset/image/108/1520/2013/a1d91741de2918.jpg
#   inflating: /content/dataset/image/108/1520/2013/a63dadc3597e89.jpg
#   inflating: /content/dataset/image/108/1520/2013/a6ec8edba7f970.jpg
#   inflating: /content/dataset/image/108/1520/2013/a743fdfb70c160.jpg
#   inflating: /content/dataset/image/108/1520/2013/a96fc0cc6d20d1.jpg
#   inflating: /content/dataset/image/108/1520/2013/ab0b07daffb159.jpg
#   inflating: /content/dataset/image/108/1520/2013/ab746475b935f5.jpg
#   inflating: /content/dataset/image/108/1520/2013/ae3b259ea41121.jpg
#   inflating: /content/dataset/image/108/1520/2013/af6aa5e8a285ad.jpg
#   inflating: /content/dataset/image/108/1520/2013/b1710708bb4b7c.jpg
#   inflating: /content/dataset/image/108/1520/2013/b184a13e24ceca.jpg
#   inflating: /content/dataset/image/108/1520/2013/b372e1e92dc668.jpg
#   inflating: /content/dataset/image/108/1520/2013/b447cc00281f6f.jpg
#   inflating: /content/dataset/image/108/1520/2013/b591b24b8ae77e.jpg
#   inflating: /content/dataset/image/108/1520/2013/c117f62dc2cf9a.jpg
#   inflating: /content/dataset/image/108/1520/2013/c2066f7d26d6ab.jpg
#   inflating: /content/dataset/image/108/1520/2013/c2d89adfa30eea.jpg
#   inflating: /content/dataset/image/108/1520/2013/c5be4b52e2d49e.jpg
#   inflating: /content/dataset/image/108/1520/2013/c6dad8910890e1.jpg
#   inflating: /content/dataset/image/108/1520/2013/c7d3e6b9ee2366.jpg
#   inflating: /content/dataset/image/108/1520/2013/c99de0dce3ba93.jpg
#   inflating: /content/dataset/image/108/1520/2013/c9f45a4c905774.jpg
#   inflating: /content/dataset/image/108/1520/2013/ca8ec30d0f18d8.jpg
#   inflating: /content/dataset/image/108/1520/2013/ce572f377ef81c.jpg
#   inflating: /content/dataset/image/108/1520/2013/cea46692801de1.jpg
#   inflating: /content/dataset/image/108/1520/2013/cfdbdb3a616a7d.jpg
#   inflating: /content/dataset/image/108/1520/2013/d1a312a14ca904.jpg
#   inflating: /content/dataset/image/108/1520/2013/d2763ca4f506b3.jpg
#   inflating: /content/dataset/image/108/1520/2013/d3c76f1af1bf47.jpg
#   inflating: /content/dataset/image/108/1520/2013/d46821ea84819f.jpg
#   inflating: /content/dataset/image/108/1520/2013/d627382f0712fe.jpg
#   inflating: /content/dataset/image/108/1520/2013/d8c47c2bd9b05e.jpg
#   inflating: /content/dataset/image/108/1520/2013/d8dd1710db03d3.jpg
#   inflating: /content/dataset/image/108/1520/2013/da0d94c80a058f.jpg
#   inflating: /content/dataset/image/108/1520/2013/dafe0c69e1ab9e.jpg
#   inflating: /content/dataset/image/108/1520/2013/db743dcaee3ed1.jpg
#   inflating: /content/dataset/image/108/1520/2013/dd57578d76e0e6.jpg
#   inflating: /content/dataset/image/108/1520/2013/e0e6f479bbbd6c.jpg
#   inflating: /content/dataset/image/108/1520/2013/e7379a2b15ce0b.jpg
#   inflating: /content/dataset/image/108/1520/2013/e80acbe7f8fd8f.jpg
#   inflating: /content/dataset/image/108/1520/2013/e82161cb44d55f.jpg
#   inflating: /content/dataset/image/108/1520/2013/e8c66f5579e4ea.jpg
#   inflating: /content/dataset/image/108/1520/2013/e8f54a4f52ec66.jpg
#   inflating: /content/dataset/image/108/1520/2013/ea6c4a15f565d6.jpg
#   inflating: /content/dataset/image/108/1520/2013/ee0f4eeeeb0f9d.jpg
#   inflating: /content/dataset/image/108/1520/2013/ee6ff0fdd7884a.jpg
#   inflating: /content/dataset/image/108/1520/2013/f0b7d9eecbaaf3.jpg
#   inflating: /content/dataset/image/108/1520/2013/f1dd93b4a66a94.jpg
#   inflating: /content/dataset/image/108/1520/2013/f41393753b8efd.jpg
#   inflating: /content/dataset/image/108/1520/2013/f52386809b3c3f.jpg
#   inflating: /content/dataset/image/108/1520/2013/f54cc72089c05f.jpg
#   inflating: /content/dataset/image/108/1520/2013/f5a5f2085c4d36.jpg
#   inflating: /content/dataset/image/108/1520/2013/f9e1a275d50010.jpg
#   inflating: /content/dataset/image/108/1520/2013/fee0e3b2df09a2.jpg
#   inflating: /content/dataset/image/108/1520/2013/ff0d78be5fc0de.jpg
#   inflating: /content/dataset/image/108/1520/2014/15481362501e94.jpg
#   inflating: /content/dataset/image/108/1520/2014/2155f0517c86c4.jpg
#   inflating: /content/dataset/image/108/1520/2014/349621c8cc206e.jpg
#   inflating: /content/dataset/image/108/1520/2014/6af39bf0c4aac9.jpg
#   inflating: /content/dataset/image/108/1520/2014/7b5655a0081c12.jpg
#   inflating: /content/dataset/image/108/1520/2014/7e86b5451ed7c2.jpg
#   inflating: /content/dataset/image/108/1520/2014/98724b8c6e6e53.jpg
#   inflating: /content/dataset/image/108/1520/2014/d99cbf44f1514e.jpg
#   inflating: /content/dataset/image/108/1520/2014/e7c76a4b1f3b6a.jpg
#   inflating: /content/dataset/image/108/1520/2014/ea3ff217a19083.jpg
#   inflating: /content/dataset/image/108/1520/2014/ed0c1bad6dadff.jpg
#   inflating: /content/dataset/image/108/1520/2014/f75b1654660cae.jpg
#   inflating: /content/dataset/image/108/1520/2014/ff997c7c74af50.jpg
#   inflating: /content/dataset/image/108/1521/2009/03d76f18bda9d9.jpg
#   inflating: /content/dataset/image/108/1521/2009/06b17963102ccd.jpg
#   inflating: /content/dataset/image/108/1521/2009/18286404423a21.jpg
#   inflating: /content/dataset/image/108/1521/2009/2c2c2f0e6177a4.jpg
#   inflating: /content/dataset/image/108/1521/2009/44d7ccf4914099.jpg
#   inflating: /content/dataset/image/108/1521/2009/5288d275b7a4ab.jpg
#   inflating: /content/dataset/image/108/1521/2009/5c00f9525a0b49.jpg
#   inflating: /content/dataset/image/108/1521/2009/5d0bfb90dbdaf0.jpg
#   inflating: /content/dataset/image/108/1521/2009/5f39b48a490bcb.jpg
#   inflating: /content/dataset/image/108/1521/2009/6966fa4b1e00dd.jpg
#   inflating: /content/dataset/image/108/1521/2009/6da56462b3553e.jpg
#   inflating: /content/dataset/image/108/1521/2009/7640281b9c99ad.jpg
#   inflating: /content/dataset/image/108/1521/2009/7676b7fa76e061.jpg
#   inflating: /content/dataset/image/108/1521/2009/7aca082358779f.jpg
#   inflating: /content/dataset/image/108/1521/2009/7cab7b609f13df.jpg
#   inflating: /content/dataset/image/108/1521/2009/7e5321708f7757.jpg
#   inflating: /content/dataset/image/108/1521/2009/7eef94a256a8ef.jpg
#   inflating: /content/dataset/image/108/1521/2009/89c6706386ec63.jpg
#   inflating: /content/dataset/image/108/1521/2009/b8122a7ab1126f.jpg
#   inflating: /content/dataset/image/108/1521/2009/c7b36a4a89da60.jpg
#   inflating: /content/dataset/image/108/1521/2009/d64b49d528564f.jpg
#   inflating: /content/dataset/image/108/1521/2009/da6d92238f03b4.jpg
#   inflating: /content/dataset/image/108/1521/2009/db6e1e01075386.jpg
#   inflating: /content/dataset/image/108/1521/2009/e10ec1fd495799.jpg
#   inflating: /content/dataset/image/108/1521/2009/ea3d12685421b2.jpg
#   inflating: /content/dataset/image/108/1521/2009/f5c0230f318c79.jpg
#   inflating: /content/dataset/image/108/1521/2010/0aaba820abd94d.jpg
#   inflating: /content/dataset/image/108/1521/2010/0d62c854ef2dc0.jpg
#   inflating: /content/dataset/image/108/1521/2010/0e0f1a680076b4.jpg
#   inflating: /content/dataset/image/108/1521/2010/12204277cb8ef4.jpg
#   inflating: /content/dataset/image/108/1521/2010/1b671cf8534794.jpg
#   inflating: /content/dataset/image/108/1521/2010/1d1cee79835884.jpg
#   inflating: /content/dataset/image/108/1521/2010/1ddf681d4a8839.jpg
#   inflating: /content/dataset/image/108/1521/2010/1fd9be3efa5828.jpg
#   inflating: /content/dataset/image/108/1521/2010/2e749878fce3ca.jpg
#   inflating: /content/dataset/image/108/1521/2010/3cdd540d33f70a.jpg
#   inflating: /content/dataset/image/108/1521/2010/3d31c7b2fb3919.jpg
#   inflating: /content/dataset/image/108/1521/2010/41d524050e97cd.jpg
#   inflating: /content/dataset/image/108/1521/2010/5ff7989e815fde.jpg
#   inflating: /content/dataset/image/108/1521/2010/6f189c391179a1.jpg
#   inflating: /content/dataset/image/108/1521/2010/7428a424fd6a43.jpg
#   inflating: /content/dataset/image/108/1521/2010/75055f4e5b1cc1.jpg
#   inflating: /content/dataset/image/108/1521/2010/7726f2673f0ba8.jpg
#   inflating: /content/dataset/image/108/1521/2010/84a876f019f8bd.jpg
#   inflating: /content/dataset/image/108/1521/2010/979148d90987b6.jpg
#   inflating: /content/dataset/image/108/1521/2010/a17dc4dd8194fb.jpg
#   inflating: /content/dataset/image/108/1521/2010/b6a4a040bb2beb.jpg
#   inflating: /content/dataset/image/108/1521/2010/bd08e7a5c090e0.jpg
#   inflating: /content/dataset/image/108/1521/2010/c95f448faf7155.jpg
#   inflating: /content/dataset/image/108/1521/2010/ca0d9934808637.jpg
#   inflating: /content/dataset/image/108/1521/2010/d255ca2044d2b5.jpg
#   inflating: /content/dataset/image/108/1521/2010/dbf01e83c7feb2.jpg
#   inflating: /content/dataset/image/108/1521/2010/dc090d05ee5ff4.jpg
#   inflating: /content/dataset/image/108/1521/2010/ef91d2714446b5.jpg
#   inflating: /content/dataset/image/108/1521/2010/f1482b1c63073d.jpg
#   inflating: /content/dataset/image/108/1521/2010/fae3d95049529a.jpg
#   inflating: /content/dataset/image/108/1521/2011/031ac08df3f96f.jpg
#   inflating: /content/dataset/image/108/1521/2011/07212c5f7cf2be.jpg
#   inflating: /content/dataset/image/108/1521/2011/0eb3e96cb02bf7.jpg
#   inflating: /content/dataset/image/108/1521/2011/1a2d8bac3f4d58.jpg
#   inflating: /content/dataset/image/108/1521/2011/1fe5f64ee108bc.jpg
#   inflating: /content/dataset/image/108/1521/2011/2404d3d788fa2f.jpg
#   inflating: /content/dataset/image/108/1521/2011/27b5a7545c8210.jpg
#   inflating: /content/dataset/image/108/1521/2011/37f2150cc23dff.jpg
#   inflating: /content/dataset/image/108/1521/2011/3e61c66ee76b64.jpg
#   inflating: /content/dataset/image/108/1521/2011/4d15c353aab39d.jpg
#   inflating: /content/dataset/image/108/1521/2011/4ff4749a44ef43.jpg
#   inflating: /content/dataset/image/108/1521/2011/61ccad85f0d668.jpg
#   inflating: /content/dataset/image/108/1521/2011/6692487f79f6ca.jpg
#   inflating: /content/dataset/image/108/1521/2011/6af150d424d3e1.jpg
#   inflating: /content/dataset/image/108/1521/2011/753d0952e82978.jpg
#   inflating: /content/dataset/image/108/1521/2011/7cb9001abe2812.jpg
#   inflating: /content/dataset/image/108/1521/2011/7fe0133485c0d0.jpg
#   inflating: /content/dataset/image/108/1521/2011/85d95a81fe6180.jpg
#   inflating: /content/dataset/image/108/1521/2011/8d247869eb383f.jpg
#   inflating: /content/dataset/image/108/1521/2011/91b9cdeb50c720.jpg
#   inflating: /content/dataset/image/108/1521/2011/a66a88d51824b3.jpg
#   inflating: /content/dataset/image/108/1521/2011/aae40b05494638.jpg
#   inflating: /content/dataset/image/108/1521/2011/b75c2f2668f843.jpg
#   inflating: /content/dataset/image/108/1521/2011/b85187044c4463.jpg
#   inflating: /content/dataset/image/108/1521/2011/c0fe71ec895f0b.jpg
#   inflating: /content/dataset/image/108/1521/2011/c40f870c24ff09.jpg
#   inflating: /content/dataset/image/108/1521/2011/d49180299b1d2b.jpg
#   inflating: /content/dataset/image/108/1521/2011/e8f91a49a85817.jpg
#   inflating: /content/dataset/image/108/1521/2011/ebb6386d2afa57.jpg
#   inflating: /content/dataset/image/108/1521/2011/ef5145781b7f1e.jpg
#   inflating: /content/dataset/image/108/1521/2012/2209ffbf5206de.jpg
#   inflating: /content/dataset/image/108/1521/2012/4927ebc4376ded.jpg
#   inflating: /content/dataset/image/108/1521/2012/5464f2c1745231.jpg
#   inflating: /content/dataset/image/108/1521/2012/670a0a8cad906e.jpg
#   inflating: /content/dataset/image/108/1521/2012/6874d06aff0b11.jpg
#   inflating: /content/dataset/image/108/1521/2012/73090caa1d9baf.jpg
#   inflating: /content/dataset/image/108/1521/2012/74a13e5822e901.jpg
#   inflating: /content/dataset/image/108/1521/2012/a1d7c319be2cd7.jpg
#   inflating: /content/dataset/image/108/1521/2012/a900cb993e35b1.jpg
#   inflating: /content/dataset/image/108/1521/2012/b2644d65cc6b48.jpg
#   inflating: /content/dataset/image/108/1521/2012/ba71cf864a6944.jpg
#   inflating: /content/dataset/image/108/1521/2012/bcc3d225e735c1.jpg
#   inflating: /content/dataset/image/108/1521/2012/e387b873463beb.jpg
#   inflating: /content/dataset/image/108/1521/2012/e983aeb8ea3606.jpg
#   inflating: /content/dataset/image/108/1521/2012/fcb6dc657bd7dc.jpg
#   inflating: /content/dataset/image/108/1521/2012/fd3e89a94c825d.jpg
#   inflating: /content/dataset/image/108/1521/2013/055149fa0680bf.jpg
#   inflating: /content/dataset/image/108/1521/2013/0ba7883f247b85.jpg
#   inflating: /content/dataset/image/108/1521/2013/1d26e27663404c.jpg
#   inflating: /content/dataset/image/108/1521/2013/2050501a9dbacd.jpg
#   inflating: /content/dataset/image/108/1521/2013/2eed0ec2101114.jpg
#   inflating: /content/dataset/image/108/1521/2013/4cadc0e05e8a11.jpg
#   inflating: /content/dataset/image/108/1521/2013/4eb1e2b85976b3.jpg
#   inflating: /content/dataset/image/108/1521/2013/4f627cbb2a33f4.jpg
#   inflating: /content/dataset/image/108/1521/2013/5e7e3895dc7342.jpg
#   inflating: /content/dataset/image/108/1521/2013/611b0c1748bd31.jpg
#   inflating: /content/dataset/image/108/1521/2013/6fbf1480d3d86e.jpg
#   inflating: /content/dataset/image/108/1521/2013/8a754584a6d1fa.jpg
#   inflating: /content/dataset/image/108/1521/2013/8e96174fbb1405.jpg
#   inflating: /content/dataset/image/108/1521/2013/94763783ffe92e.jpg
#   inflating: /content/dataset/image/108/1521/2013/97adef9cec5f9e.jpg
#   inflating: /content/dataset/image/108/1521/2013/a33def54f9de33.jpg
#   inflating: /content/dataset/image/108/1521/2013/b096c1273955d6.jpg
#   inflating: /content/dataset/image/108/1521/2013/b2ae52a0b3fb38.jpg
#   inflating: /content/dataset/image/108/1521/2013/dd834d6c46f7b3.jpg
#   inflating: /content/dataset/image/108/1521/2013/e1da88f9ee6dc4.jpg
#   inflating: /content/dataset/image/108/1521/2013/e5331a0c6aabbc.jpg
#   inflating: /content/dataset/image/108/1521/2013/e75674e4ac124f.jpg
#   inflating: /content/dataset/image/108/1521/2013/f1c2ee51c28fae.jpg
#   inflating: /content/dataset/image/108/1521/2013/f5ab863a1d9bd1.jpg
#   inflating: /content/dataset/image/108/1521/2013/f8581dd0c6c00f.jpg
#   inflating: /content/dataset/image/108/1521/2013/ffed3a13a2498b.jpg
#   inflating: /content/dataset/image/108/1522/2014/025263e038988b.jpg
#   inflating: /content/dataset/image/108/1522/2014/03e32589767356.jpg
#   inflating: /content/dataset/image/108/1522/2014/0c1702ad3fe1a9.jpg
#   inflating: /content/dataset/image/108/1522/2014/0ea4a79bd5e7b0.jpg
#   inflating: /content/dataset/image/108/1522/2014/0ef905ae34def7.jpg
#   inflating: /content/dataset/image/108/1522/2014/0f6b9299f28af4.jpg
#   inflating: /content/dataset/image/108/1522/2014/12c3789751fcdf.jpg
#   inflating: /content/dataset/image/108/1522/2014/1399b91353b3b7.jpg
#   inflating: /content/dataset/image/108/1522/2014/1e8ce3ec2409cb.jpg
#   inflating: /content/dataset/image/108/1522/2014/1fedce404ce7aa.jpg
#   inflating: /content/dataset/image/108/1522/2014/23941677ed6dfc.jpg
#   inflating: /content/dataset/image/108/1522/2014/28a6d10850566e.jpg
#   inflating: /content/dataset/image/108/1522/2014/28fea708aa9d14.jpg
#   inflating: /content/dataset/image/108/1522/2014/29b7b5878697c8.jpg
#   inflating: /content/dataset/image/108/1522/2014/35197e10405117.jpg
#   inflating: /content/dataset/image/108/1522/2014/36f6a846624add.jpg
#   inflating: /content/dataset/image/108/1522/2014/385c30f04821e0.jpg
#   inflating: /content/dataset/image/108/1522/2014/38a0e405f8960b.jpg
#   inflating: /content/dataset/image/108/1522/2014/3aac54704f4b4d.jpg
# ...
#   inflating: /content/dataset/image/111/1706/2009/fe9e2eddc439de.jpg
#   inflating: /content/dataset/image/111/1706/2010/0038b810368001.jpg
#   inflating: /content/dataset/image/111/1706/2010/313c21d75c91f1.jpg
#   inflating: /content/dataset/image/111/1706/2010/461f13a761c48e.jpg
#   inflating: /content/dataset/image/111/1706/2010/5bf249a6bb1c48.jpg
#   inflating: /content/dataset/image/111/1706/2010/64675ab28fc572.jpg
#   inflating: /content/dataset/image/111/1706/2010/6a54a7d92c4581.jpg
#   inflating: /content/dataset/image/111/1706/2010/863b0037144768.jpg
#   inflating: /content/dataset/image/111/1706/2010/8a927a4dc0bd7a.jpg
#   inflating: /content/dataset/image/111/1706/2010/8b45f728cf25d0.jpg
#   inflating: /content/dataset/image/111/1706/2010/8e0f1b52b41bfe.jpg
#   inflating: /content/dataset/image/111/1706/2010/910a1070330407.jpg
#   inflating: /content/dataset/image/111/1706/2010/91602fc7ffb990.jpg
#   inflating: /content/dataset/image/111/1706/2010/98a05774f450ee.jpg
#   inflating: /content/dataset/image/111/1706/2010/9bfd333d292734.jpg
#   inflating: /content/dataset/image/111/1706/2010/ace40edb2176c9.jpg
#   inflating: /content/dataset/image/111/1706/2010/b159b5ce419694.jpg
#   inflating: /content/dataset/image/111/1706/2010/b9220fb075710d.jpg
#   inflating: /content/dataset/image/111/1706/2010/bd244e2184d990.jpg
#   inflating: /content/dataset/image/111/1706/2010/befa88351032cd.jpg
#   inflating: /content/dataset/image/111/1706/2010/d2392cd8e194bd.jpg
#   inflating: /content/dataset/image/111/1706/2010/e0576d62698476.jpg
#   inflating: /content/dataset/image/111/1706/2010/e3e4845f6b672e.jpg
#   inflating: /content/dataset/image/111/1706/2010/e4ad8f2b1b8712.jpg
#   inflating: /content/dataset/image/111/1706/2010/e4b293211dce8d.jpg
#   inflating: /content/dataset/image/111/1706/2010/e71124fea6f089.jpg
#   inflating: /content/dataset/image/111/1706/2010/e7621c9e128a76.jpg
#   inflating: /content/dataset/image/111/1706/2010/f042098c033c0f.jpg
#   inflating: /content/dataset/image/111/1706/2010/fb4d9804809e27.jpg
#   inflating: /content/dataset/image/111/1706/2010/fcbdb262e913cb.jpg
#   inflating: /content/dataset/image/111/1706/2011/0197314a440873.jpg
#   inflating: /content/dataset/image/111/1706/2011/0ade22d6b1685b.jpg
#   inflating: /content/dataset/image/111/1706/2011/120c4b5b600006.jpg
#   inflating: /content/dataset/image/111/1706/2011/12d31a1acd7d50.jpg
#   inflating: /content/dataset/image/111/1706/2011/188d3c3536915e.jpg
#   inflating: /content/dataset/image/111/1706/2011/2970311b3a9e26.jpg
#   inflating: /content/dataset/image/111/1706/2011/3679e5ba7dbfcc.jpg
#   inflating: /content/dataset/image/111/1706/2011/3a56a931375177.jpg
#   inflating: /content/dataset/image/111/1706/2011/47fca4a121f157.jpg
#   inflating: /content/dataset/image/111/1706/2011/4a54b0ee602a23.jpg
#   inflating: /content/dataset/image/111/1706/2011/4e5cd56e71b2d7.jpg
#   inflating: /content/dataset/image/111/1706/2011/5340f00e3844ae.jpg
#   inflating: /content/dataset/image/111/1706/2011/5e39b76f6a5280.jpg
#   inflating: /content/dataset/image/111/1706/2011/6234cc5cf59ea9.jpg
#   inflating: /content/dataset/image/111/1706/2011/62712950ef86e8.jpg
#   inflating: /content/dataset/image/111/1706/2011/652b6653cb00ed.jpg
#   inflating: /content/dataset/image/111/1706/2011/824680a155cdab.jpg
#   inflating: /content/dataset/image/111/1706/2011/8a855ff04f1f21.jpg
#   inflating: /content/dataset/image/111/1706/2011/986adea1b0bf88.jpg
#   inflating: /content/dataset/image/111/1706/2011/9a4f0423f0fc35.jpg
#   inflating: /content/dataset/image/111/1706/2011/9d37f5a843873c.jpg
#   inflating: /content/dataset/image/111/1706/2011/a46228b15c22bc.jpg
#   inflating: /content/dataset/image/111/1706/2011/b9bcf3c970bfbe.jpg
#   inflating: /content/dataset/image/111/1706/2011/c52218b34718f0.jpg
#   inflating: /content/dataset/image/111/1706/2011/c5b3d42abd7906.jpg
#   inflating: /content/dataset/image/111/1706/2011/cab7a0fa1c0eac.jpg
#   inflating: /content/dataset/image/111/1706/2011/cdcddd60c0c14f.jpg
#   inflating: /content/dataset/image/111/1706/2011/e4621c368f8c19.jpg
#   inflating: /content/dataset/image/111/1706/2011/f670d14b1613ed.jpg
#   inflating: /content/dataset/image/111/1706/2011/f8310c58481036.jpg
#   inflating: /content/dataset/image/111/1706/2012/03ff3d88e5053b.jpg
#   inflating: /content/dataset/image/111/1706/2012/05ad8722f24341.jpg
#   inflating: /content/dataset/image/111/1706/2012/0b81be9db375e8.jpg
#   inflating: /content/dataset/image/111/1706/2012/0fa54c318e8087.jpg
#   inflating: /content/dataset/image/111/1706/2012/28a9437fd5f994.jpg
#   inflating: /content/dataset/image/111/1706/2012/3097811f5eba24.jpg
#   inflating: /content/dataset/image/111/1706/2012/37cbe29192dfce.jpg
#   inflating: /content/dataset/image/111/1706/2012/4f100a59136045.jpg
#   inflating: /content/dataset/image/111/1706/2012/563e028474b17f.jpg
#   inflating: /content/dataset/image/111/1706/2012/57ae9bb69eeae8.jpg
#   inflating: /content/dataset/image/111/1706/2012/5a27bd011398a0.jpg
#   inflating: /content/dataset/image/111/1706/2012/5fda8df9025fd7.jpg
#   inflating: /content/dataset/image/111/1706/2012/672b29e7f861b2.jpg
#   inflating: /content/dataset/image/111/1706/2012/730cb1dcccbaeb.jpg
#   inflating: /content/dataset/image/111/1706/2012/78692ff7cca510.jpg
#   inflating: /content/dataset/image/111/1706/2012/7d374f8f87def4.jpg
#   inflating: /content/dataset/image/111/1706/2012/7f23788d6f96a4.jpg
#   inflating: /content/dataset/image/111/1706/2012/9173c222049f89.jpg
#   inflating: /content/dataset/image/111/1706/2012/92b900332b50d4.jpg
#   inflating: /content/dataset/image/111/1706/2012/92e2db06beb289.jpg
#   inflating: /content/dataset/image/111/1706/2012/94bc1b062f9f01.jpg
#   inflating: /content/dataset/image/111/1706/2012/94d37ef3f132e8.jpg
#   inflating: /content/dataset/image/111/1706/2012/95fa189e177886.jpg
#   inflating: /content/dataset/image/111/1706/2012/a9c59dd76fa194.jpg
#   inflating: /content/dataset/image/111/1706/2012/b9035765f35b9a.jpg
#   inflating: /content/dataset/image/111/1706/2012/bde0615fc6770d.jpg
#   inflating: /content/dataset/image/111/1706/2012/c1981e778c9eb9.jpg
#   inflating: /content/dataset/image/111/1706/2012/c6f6e6543c5015.jpg
#   inflating: /content/dataset/image/111/1706/2012/e14f283804e38a.jpg
#   inflating: /content/dataset/image/111/1706/2012/e6b7f381ebbb26.jpg
#   inflating: /content/dataset/image/111/1706/2013/01d951652d4298.jpg
#   inflating: /content/dataset/image/111/1706/2013/0ed26fcfa398dd.jpg
#   inflating: /content/dataset/image/111/1706/2013/1ac074b0d879ec.jpg
#   inflating: /content/dataset/image/111/1706/2013/1c8c0accbc0d44.jpg
#   inflating: /content/dataset/image/111/1706/2013/1edcd9e1945056.jpg
#   inflating: /content/dataset/image/111/1706/2013/2ae07cd4d3622a.jpg
#   inflating: /content/dataset/image/111/1706/2013/3c88c2abe4590e.jpg
#   inflating: /content/dataset/image/111/1706/2013/47d8288c7edf43.jpg
#   inflating: /content/dataset/image/111/1706/2013/5ee73c3a93883c.jpg
#   inflating: /content/dataset/image/111/1706/2013/63a4484a59fdc5.jpg
#   inflating: /content/dataset/image/111/1706/2013/6631d1bdeaa817.jpg
#   inflating: /content/dataset/image/111/1706/2013/85f3e1df778806.jpg
#   inflating: /content/dataset/image/111/1706/2013/8e1e48547448c7.jpg
#   inflating: /content/dataset/image/111/1706/2013/978ba656c73787.jpg
#   inflating: /content/dataset/image/111/1706/2013/9945a35c7342fd.jpg
#   inflating: /content/dataset/image/111/1706/2013/a2782326d79d5f.jpg
#   inflating: /content/dataset/image/111/1706/2013/a4cbcf096d8113.jpg
#   inflating: /content/dataset/image/111/1706/2013/acf321443cb1a6.jpg
#   inflating: /content/dataset/image/111/1706/2013/ad364bdb1dde37.jpg
#   inflating: /content/dataset/image/111/1706/2013/b1bcf27bff091c.jpg
#   inflating: /content/dataset/image/111/1706/2013/b2005b6a441d5a.jpg
#   inflating: /content/dataset/image/111/1706/2013/b252ee4c4ba4d4.jpg
#   inflating: /content/dataset/image/111/1706/2013/b640410a08645f.jpg
#   inflating: /content/dataset/image/111/1706/2013/baa74648f68d45.jpg
#   inflating: /content/dataset/image/111/1706/2013/c6396642a08a37.jpg
#   inflating: /content/dataset/image/111/1706/2013/d458181bbf055c.jpg
#   inflating: /content/dataset/image/111/1706/2013/e2697b42b714ce.jpg
#   inflating: /content/dataset/image/111/1706/2013/ee965393cce090.jpg
#   inflating: /content/dataset/image/111/1706/2013/f4a90017cf884a.jpg
#   inflating: /content/dataset/image/111/1706/2013/fadefb35497980.jpg
#   inflating: /content/dataset/image/111/1706/2014/0f9f7aec54d2d3.jpg
#   inflating: /content/dataset/image/111/1706/2014/136bafea22aa47.jpg
#   inflating: /content/dataset/image/111/1706/2014/243a1feac93e84.jpg
#   inflating: /content/dataset/image/111/1706/2014/3003bcc7739950.jpg
#   inflating: /content/dataset/image/111/1706/2014/349a7e363a9bef.jpg
#   inflating: /content/dataset/image/111/1706/2014/353d96f9883391.jpg
#   inflating: /content/dataset/image/111/1706/2014/394f7c7e041889.jpg
#   inflating: /content/dataset/image/111/1706/2014/41b4a5683646dd.jpg
#   inflating: /content/dataset/image/111/1706/2014/448b906e36155c.jpg
#   inflating: /content/dataset/image/111/1706/2014/4d623e367da9b6.jpg
#   inflating: /content/dataset/image/111/1706/2014/4fd671d2ef85e6.jpg
#   inflating: /content/dataset/image/111/1706/2014/524d8a886217a7.jpg
#   inflating: /content/dataset/image/111/1706/2014/5281f581839459.jpg
#   inflating: /content/dataset/image/111/1706/2014/5ec482d85c033b.jpg
#   inflating: /content/dataset/image/111/1706/2014/6f09054b513322.jpg
#   inflating: /content/dataset/image/111/1706/2014/8350399f8b24b6.jpg
#   inflating: /content/dataset/image/111/1706/2014/88e8669ec2c44c.jpg
#   inflating: /content/dataset/image/111/1706/2014/8ca7392d277f3a.jpg
#   inflating: /content/dataset/image/111/1706/2014/9119ccf87b3802.jpg
#   inflating: /content/dataset/image/111/1706/2014/a5d4e984726f2c.jpg
#   inflating: /content/dataset/image/111/1706/2014/ae6028dea3da54.jpg
#   inflating: /content/dataset/image/111/1706/2014/b1e6b7da193b66.jpg
#   inflating: /content/dataset/image/111/1706/2014/c457d28b7db0d5.jpg
#   inflating: /content/dataset/image/111/1706/2014/d591824c4fdc79.jpg
#   inflating: /content/dataset/image/111/1706/2014/d67ae9335e8eec.jpg
#   inflating: /content/dataset/image/111/1706/2014/dbcad5d367cabd.jpg
#   inflating: /content/dataset/image/111/1706/2014/e2eaea670b485c.jpg
#   inflating: /content/dataset/image/111/1706/2014/e50a67e4f87965.jpg
#   inflating: /content/dataset/image/111/1706/2014/fca25bba7cfe75.jpg
#   inflating: /content/dataset/image/111/1706/2014/ffd1154c1c431a.jpg
#   inflating: /content/dataset/image/111/1706/2015/0faed9e0bab2af.jpg
#   inflating: /content/dataset/image/111/1706/2015/23409b1f2ca0f9.jpg
#   inflating: /content/dataset/image/111/1706/2015/2b65e5dff7a93d.jpg
#   inflating: /content/dataset/image/111/1706/2015/391e446bcca447.jpg
#   inflating: /content/dataset/image/111/1706/2015/3ec06fb72ef607.jpg
#   inflating: /content/dataset/image/111/1706/2015/406ec2f4a7d4d1.jpg
#   inflating: /content/dataset/image/111/1706/2015/40a44ee856d74b.jpg
#   inflating: /content/dataset/image/111/1706/2015/4bb01ef445059e.jpg
#   inflating: /content/dataset/image/111/1706/2015/550e6138d0bd6b.jpg
#   inflating: /content/dataset/image/111/1706/2015/56d95aeaaf1789.jpg
#   inflating: /content/dataset/image/111/1706/2015/587b1dfbacfdbd.jpg
#   inflating: /content/dataset/image/111/1706/2015/5d4efad1dbb630.jpg
#   inflating: /content/dataset/image/111/1706/2015/64717b54fa4e83.jpg
#   inflating: /content/dataset/image/111/1706/2015/6b15af2150e831.jpg
#   inflating: /content/dataset/image/111/1706/2015/6d4359b89436e3.jpg
#   inflating: /content/dataset/image/111/1706/2015/6d68990b073a34.jpg
#   inflating: /content/dataset/image/111/1706/2015/7041a749344a2d.jpg
#   inflating: /content/dataset/image/111/1706/2015/7f0015b95a27fc.jpg
#   inflating: /content/dataset/image/111/1706/2015/8545dfb3b03eb5.jpg
#   inflating: /content/dataset/image/111/1706/2015/9c15d7709e2346.jpg
#   inflating: /content/dataset/image/111/1706/2015/ae5d40c10dbf16.jpg
#   inflating: /content/dataset/image/111/1706/2015/b797a524f5c79e.jpg
#   inflating: /content/dataset/image/111/1706/2015/dcb6ebc3c50fbe.jpg
#   inflating: /content/dataset/image/111/1706/2015/dd42d32538e730.jpg
#   inflating: /content/dataset/image/111/1706/2015/f8e50e424fce61.jpg
#   inflating: /content/dataset/image/111/1706/2015/faf3167515af79.jpg
#   inflating: /content/dataset/image/111/1707/2008/0745ec57663b28.jpg
#   inflating: /content/dataset/image/111/1707/2008/0a9fb6bb827fcf.jpg
#   inflating: /content/dataset/image/111/1707/2008/12bab53e8e52f3.jpg
#   inflating: /content/dataset/image/111/1707/2008/1bdd81d79f6b34.jpg
#   inflating: /content/dataset/image/111/1707/2008/25d6eaebe17301.jpg
#   inflating: /content/dataset/image/111/1707/2008/2ffea29fb68386.jpg
#   inflating: /content/dataset/image/111/1707/2008/32d097ae1a519f.jpg
#   inflating: /content/dataset/image/111/1707/2008/3ebfa5df74c188.jpg
#   inflating: /content/dataset/image/111/1707/2008/47b7dbc0fd0e35.jpg
#   inflating: /content/dataset/image/111/1707/2008/4f3375762c6f34.jpg
#   inflating: /content/dataset/image/111/1707/2008/53271458617b1d.jpg
#   inflating: /content/dataset/image/111/1707/2008/6ec095a532bf80.jpg
#   inflating: /content/dataset/image/111/1707/2008/7271f6b2fe062a.jpg
#   inflating: /content/dataset/image/111/1707/2008/9239638086e4f9.jpg
#   inflating: /content/dataset/image/111/1707/2008/943c9c445e8524.jpg
#   inflating: /content/dataset/image/111/1707/2008/97c78c75146caf.jpg
#   inflating: /content/dataset/image/111/1707/2008/9931d4ad36d0ff.jpg
#   inflating: /content/dataset/image/111/1707/2008/a70c41055fb47d.jpg
#   inflating: /content/dataset/image/111/1707/2008/a858629e7a3418.jpg
#   inflating: /content/dataset/image/111/1707/2008/b03b04a534941a.jpg
#   inflating: /content/dataset/image/111/1707/2008/b36e85e5fd9e9e.jpg
#   inflating: /content/dataset/image/111/1707/2008/c36f141b2438f0.jpg
#   inflating: /content/dataset/image/111/1707/2008/cc084343a5a72b.jpg
#   inflating: /content/dataset/image/111/1707/2008/cdb06e0eb35c8b.jpg
#   inflating: /content/dataset/image/111/1707/2008/d28c4aadeab35e.jpg
#   inflating: /content/dataset/image/111/1707/2008/d87f49de9f6739.jpg
#   inflating: /content/dataset/image/111/1707/2008/ddd5234a8ae9b6.jpg
#   inflating: /content/dataset/image/111/1707/2008/e58c0c3f022d00.jpg
#   inflating: /content/dataset/image/111/1707/2008/ee24a41d9e567e.jpg
#   inflating: /content/dataset/image/111/1707/2008/f08f60b88792ba.jpg
#   inflating: /content/dataset/image/111/1707/2010/0c84da2e8e2308.jpg
#   inflating: /content/dataset/image/111/1707/2010/145e9e897991cc.jpg
#   inflating: /content/dataset/image/111/1707/2010/1cd458a91b0f5f.jpg
#   inflating: /content/dataset/image/111/1707/2010/23be51d42a0be2.jpg
#   inflating: /content/dataset/image/111/1707/2010/29b4aa79947ce8.jpg
#   inflating: /content/dataset/image/111/1707/2010/2d9697863efb1c.jpg
#   inflating: /content/dataset/image/111/1707/2010/331edbe63321b1.jpg
#   inflating: /content/dataset/image/111/1707/2010/3ef6b3823519e4.jpg
#   inflating: /content/dataset/image/111/1707/2010/4e3c42e94c7eb6.jpg
#   inflating: /content/dataset/image/111/1707/2010/6132da10af5294.jpg
#   inflating: /content/dataset/image/111/1707/2010/6507a1f87e68e0.jpg
#   inflating: /content/dataset/image/111/1707/2010/6bd875a7b6e206.jpg
#   inflating: /content/dataset/image/111/1707/2010/8d4effce112435.jpg
#   inflating: /content/dataset/image/111/1707/2010/90577d25a462a3.jpg
#   inflating: /content/dataset/image/111/1707/2010/9d6da5a881056a.jpg
#   inflating: /content/dataset/image/111/1707/2010/a7e04446987d94.jpg
#   inflating: /content/dataset/image/111/1707/2010/ab6d085c24cd82.jpg
#   inflating: /content/dataset/image/111/1707/2010/b81b53f94a56a7.jpg
#   inflating: /content/dataset/image/111/1707/2010/ba902e28f975f0.jpg

# %% [markdown]
# # CIFAR 100

# %%
#@title CIFAR100 Classes & Superclasses

if DATASET == 'cifar100':

  # Define the classes and superclasses
  cifar100_classes = [
      # Superclass: Aquatic Mammals
      {"class": "beaver", "superclass": "aquatic mammals"},
      {"class": "dolphin", "superclass": "aquatic mammals"},
      {"class": "otter", "superclass": "aquatic mammals"},
      {"class": "seal", "superclass": "aquatic mammals"},
      {"class": "whale", "superclass": "aquatic mammals"},

      # Superclass: Fish
      {"class": "aquarium fish", "superclass": "fish"},
      {"class": "flatfish", "superclass": "fish"},
      {"class": "ray", "superclass": "fish"},
      {"class": "shark", "superclass": "fish"},
      {"class": "trout", "superclass": "fish"},

      # Superclass: Flowers
      {"class": "orchid", "superclass": "flowers"},
      {"class": "poppy", "superclass": "flowers"},
      {"class": "rose", "superclass": "flowers"},
      {"class": "sunflower", "superclass": "flowers"},
      {"class": "tulip", "superclass": "flowers"},

      # Superclass: Food Containers
      {"class": "bottle", "superclass": "food containers"},
      {"class": "bowl", "superclass": "food containers"},
      {"class": "can", "superclass": "food containers"},
      {"class": "cup", "superclass": "food containers"},
      {"class": "plate", "superclass": "food containers"},

      # Superclass: Fruits and Vegetables
      {"class": "apple", "superclass": "fruits and vegetables"},
      {"class": "mushroom", "superclass": "fruits and vegetables"},
      {"class": "orange", "superclass": "fruits and vegetables"},
      {"class": "pear", "superclass": "fruits and vegetables"},
      {"class": "sweet pepper", "superclass": "fruits and vegetables"},

      # Superclass: Household Electrical Devices
      {"class": "clock", "superclass": "household electrical devices"},
      {"class": "keyboard", "superclass": "household electrical devices"},
      {"class": "lamp", "superclass": "household electrical devices"},
      {"class": "telephone", "superclass": "household electrical devices"},
      {"class": "television", "superclass": "household electrical devices"},

      # Superclass: Household Furniture
      {"class": "bed", "superclass": "household furniture"},
      {"class": "chair", "superclass": "household furniture"},
      {"class": "couch", "superclass": "household furniture"},
      {"class": "table", "superclass": "household furniture"},
      {"class": "wardrobe", "superclass": "household furniture"},

      # Superclass: Insects
      {"class": "bee", "superclass": "insects"},
      {"class": "beetle", "superclass": "insects"},
      {"class": "butterfly", "superclass": "insects"},
      {"class": "caterpillar", "superclass": "insects"},
      {"class": "cockroach", "superclass": "insects"},

      # Superclass: Large Carnivores
      {"class": "bear", "superclass": "large carnivores"},
      {"class": "leopard", "superclass": "large carnivores"},
      {"class": "lion", "superclass": "large carnivores"},
      {"class": "tiger", "superclass": "large carnivores"},
      {"class": "wolf", "superclass": "large carnivores"},

      # Superclass: Large Man-made Outdoor Things
      {"class": "bridge", "superclass": "large man-made outdoor things"},
      {"class": "castle", "superclass": "large man-made outdoor things"},
      {"class": "house", "superclass": "large man-made outdoor things"},
      {"class": "road", "superclass": "large man-made outdoor things"},
      {"class": "skyscraper", "superclass": "large man-made outdoor things"},

      # Superclass: Large Natural Outdoor Scenes
      {"class": "cloud", "superclass": "large natural outdoor scenes"},
      {"class": "forest", "superclass": "large natural outdoor scenes"},
      {"class": "mountain", "superclass": "large natural outdoor scenes"},
      {"class": "plain", "superclass": "large natural outdoor scenes"},
      {"class": "sea", "superclass": "large natural outdoor scenes"},

      # Superclass: Large Omnivores and Herbivores
      {"class": "camel", "superclass": "large omnivores and herbivores"},
      {"class": "cattle", "superclass": "large omnivores and herbivores"},
      {"class": "chimpanzee", "superclass": "large omnivores and herbivores"},
      {"class": "elephant", "superclass": "large omnivores and herbivores"},
      {"class": "kangaroo", "superclass": "large omnivores and herbivores"},

      # Superclass: Medium-sized Mammals
      {"class": "fox", "superclass": "medium-sized mammals"},
      {"class": "porcupine", "superclass": "medium-sized mammals"},
      {"class": "possum", "superclass": "medium-sized mammals"},
      {"class": "raccoon", "superclass": "medium-sized mammals"},
      {"class": "skunk", "superclass": "medium-sized mammals"},

      # Superclass: Non-insect Invertebrates
      {"class": "crab", "superclass": "non-insect invertebrates"},
      {"class": "lobster", "superclass": "non-insect invertebrates"},
      {"class": "snail", "superclass": "non-insect invertebrates"},
      {"class": "spider", "superclass": "non-insect invertebrates"},
      {"class": "worm", "superclass": "non-insect invertebrates"},

      # Superclass: People
      {"class": "baby", "superclass": "people"},
      {"class": "boy", "superclass": "people"},
      {"class": "girl", "superclass": "people"},
      {"class": "man", "superclass": "people"},
      {"class": "woman", "superclass": "people"},

      # Superclass: Reptiles
      {"class": "crocodile", "superclass": "reptiles"},
      {"class": "dinosaur", "superclass": "reptiles"},
      {"class": "lizard", "superclass": "reptiles"},
      {"class": "snake", "superclass": "reptiles"},
      {"class": "turtle", "superclass": "reptiles"},

      # Superclass: Small Mammals
      {"class": "hamster", "superclass": "small mammals"},
      {"class": "mouse", "superclass": "small mammals"},
      {"class": "rabbit", "superclass": "small mammals"},
      {"class": "shrew", "superclass": "small mammals"},
      {"class": "squirrel", "superclass": "small mammals"},

      # Superclass: Trees
      {"class": "maple tree", "superclass": "trees"},
      {"class": "oak tree", "superclass": "trees"},
      {"class": "palm tree", "superclass": "trees"},
      {"class": "pine tree", "superclass": "trees"},
      {"class": "willow tree", "superclass": "trees"},

      # Superclass: Vehicles 1
      {"class": "bicycle", "superclass": "vehicles 1"},
      {"class": "bus", "superclass": "vehicles 1"},
      {"class": "motorcycle", "superclass": "vehicles 1"},
      {"class": "pickup truck", "superclass": "vehicles 1"},
      {"class": "train", "superclass": "vehicles 1"},

      # Superclass: Vehicles 2
      {"class": "lawn mower", "superclass": "vehicles 2"},
      {"class": "rocket", "superclass": "vehicles 2"},
      {"class": "streetcar", "superclass": "vehicles 2"},
      {"class": "tank", "superclass": "vehicles 2"},
      {"class": "tractor", "superclass": "vehicles 2"},
  ]

  # Write to JSON file
  with open('cifar100_classes.json', 'w') as json_file:
      json.dump(cifar100_classes, json_file, indent=4)

  superclasses = [
      "aquatic mammals",          # 1-5
      "fish",                     # 6-10
      "flowers",                  # 11-15
      "food containers",          # 16-20
      "fruits and vegetables",    # 21-25
      "household electrical devices",  # 26-30
      "household furniture",      # 31-35
      "insects",                  # 36-40
      "large carnivores",         # 41-45
      "large man-made outdoor things", # 46-50
      "large natural outdoor scenes",  # 51-55
      "large omnivores and herbivores",# 56-60
      "medium-sized mammals",     # 61-65
      "non-insect invertebrates", # 66-70
      "people",                   # 71-75
      "reptiles",                 # 76-80
      "small mammals",            # 81-85
      "trees",                    # 86-90
      "vehicles 1",               # 91-95
      "vehicles 2"                # 96-100
  ]

  classes = [
      # Aquatic Mammals
      "beaver", "dolphin", "otter", "seal", "whale",

      # Fish
      "aquarium fish", "flatfish", "ray", "shark", "trout",

      # Flowers
      "orchid", "poppy", "rose", "sunflower", "tulip",

      # Food Containers
      "bottle", "bowl", "can", "cup", "plate",

      # Fruits and Vegetables
      "apple", "mushroom", "orange", "pear", "sweet pepper",

      # Household Electrical Devices
      "clock", "keyboard", "lamp", "telephone", "television",

      # Household Furniture
      "bed", "chair", "couch", "table", "wardrobe",

      # Insects
      "bee", "beetle", "butterfly", "caterpillar", "cockroach",

      # Large Carnivores
      "bear", "leopard", "lion", "tiger", "wolf",

      # Large Man-made Outdoor Things
      "bridge", "castle", "house", "road", "skyscraper",

      # Large Natural Outdoor Scenes
      "cloud", "forest", "mountain", "plain", "sea",

      # Large Omnivores and Herbivores
      "camel", "cattle", "chimpanzee", "elephant", "kangaroo",

      # Medium-sized Mammals
      "fox", "porcupine", "possum", "raccoon", "skunk",

      # Non-insect Invertebrates
      "crab", "lobster", "snail", "spider", "worm",

      # People
      "baby", "boy", "girl", "man", "woman",

      # Reptiles
      "crocodile", "dinosaur", "lizard", "snake", "turtle",

      # Small Mammals
      "hamster", "mouse", "rabbit", "shrew", "squirrel",

      # Trees
      "maple tree", "oak tree", "palm tree", "pine tree", "willow tree",

      # Vehicles 1
      "bicycle", "bus", "motorcycle", "pickup truck", "train",

      # Vehicles 2
      "lawn mower", "rocket", "streetcar", "tank", "tractor"
  ]

# %%
if DATASET == 'cifar100':

  file_path = '/content/dataset/test/cifar-100-python/meta'

  # Unpickle the file
  with open(file_path, 'rb') as file:
      data = pickle.load(file)

  alphabetical_to_original_label = {}

  for label_id, label in enumerate(data['fine_label_names']):
    label = label.replace('_', ' ')
    new_index = classes.index(label)
    superclass = cifar100_classes[new_index]['superclass']
    new_superclass_index = superclasses.index(superclass)
    # print(label, new_index, new_superclass_index)
    alphabetical_to_original_label[label_id] = {'index': new_index, 'class':classes[new_index], 'super_index':new_superclass_index, 'superclass': superclass}

  print(alphabetical_to_original_label)

  superclass_and_class_to_hierarchic_label = {}

  for key in alphabetical_to_original_label:
    info = alphabetical_to_original_label[key]
    superclass = info['superclass']
    if superclass not in superclass_and_class_to_hierarchic_label:
      hierarchic_label = 0
      superclass_and_class_to_hierarchic_label[superclass] = 0
    else:
      hierarchic_label = superclass_and_class_to_hierarchic_label[superclass] + 1
      superclass_and_class_to_hierarchic_label[superclass] = hierarchic_label
    info['hierarchic_index'] = hierarchic_label
    alphabetical_to_original_label[key] = info

  print(alphabetical_to_original_label)

# %%
if DATASET == 'cifar100':
  for td_id, td in enumerate(train_dataset):
    pil_img = td[0]
    numpy_img = np.clip(pil_img.permute(1, 2, 0).numpy()[:, :, ::-1] * 255, 0, 255)
    class_label = td[1]
    print(numpy_img.shape)
    # cv2_imshow(numpy_img)
    # print(alphabetical_to_original_label[class_label]['class'], alphabetical_to_original_label[class_label]['superclass'])
    if td_id % 10 == 9:
      break

# %%
if DATASET == 'cifar100':
  train_size = int(0.8 * len(train_dataset))
  val_size = len(train_dataset) - train_size

  # Split the dataset into training and validation
  train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

  # Create data loaders for each
  train_loader_classic  = DataLoader(train_dataset, batch_size=64, shuffle=True)
  val_loader_clasic = DataLoader(val_dataset, batch_size=64, shuffle=False)
  test_loader_clasic = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # INaturalist Classes and Superclasses

# %%
if DATASET == 'INaturalist':
  pass

# %% [markdown]
# # Places365

# %%
if DATASET == 'Places365':
  pass

# %% [markdown]
# # Standford Cars

# %%
from torch.utils.data import Dataset
from PIL import Image
from scipy.io import loadmat
import pandas as pd

class StandfordCarsDataset(Dataset):
    def __init__(self, root, split, transform=None, target_transform=None):
        """
        Args:
            data (any format): The data (e.g., list of file paths, array of images).
            labels (any format): The labels associated with the data.
            transform (callable, optional): Optional transform to apply to a sample.
        """
        self.root = root
        self.split = split
        if self.split == 'train' or self.split == 'val':
          self.path = 'cars_train'
        else:
          self.path = 'cars_train'

        self.image_paths = self.root + '/' + self.path + '/' + self.path + '/'
        self.label_path = self.root + '/cars_annos.mat'
        annotation_path = '/content/dataset/cardatasettrain.csv' # if self.split == 'train' else '/content/dataset/cardatasettest.csv'
        self.annotation_df = pd.read_csv(annotation_path)
        self.data = []
        self.labels = []
        self.classes = []
        self.alphabetical_to_original_label = {}
        self.load_data()
        self.transform = transform
        self.target_transform = target_transform

    def load_data(self):
      data = loadmat(self.label_path)
      self.classes = data['class_names'][0]
      self.hierarchic_classes = list(set([cls[0].split(' ')[0] for cls in self.classes]))
      # no_samples = 8144 if self.split =='train' else 8041 # len(data['annotations'][0])
      no_samples = len(self.annotation_df)
      # for ids, sample in enumerate(data['annotations'][0]):
      for ids, sample in self.annotation_df.iterrows():
        # if (self.split == 'train' and ids < no_samples * 0.7) or (self.split == 'val' and (ids >= no_samples * 0.7 and ids < no_samples * 0.9)) or (self.split == 'test' and ids >= no_samples * 0.9):
        image_name =  sample['image']  # sample[0][0].split('/')[-1]
        image_no = int(image_name.split('.')[0])
        # if (self.split == 'train' and image_no < no_samples) or (self.split == 'val' and image_no > 8144 and image_no < 8144 + no_samples *0.8) or (self.split == 'test' and image_no > 8144 and image_no >= 8144 + no_samples *0.8):
        #  if self.split in ['val', 'test']:
        if (self.split == 'train' and ids <= no_samples * 0.7) or (self.split == 'val' and ids > no_samples * 0.7 and ids < no_samples * 0.8) or (self.split == 'test' and ids >= no_samples * 0.8):
            image_name = str(image_no).zfill(5) + '.jpg'
            self.data.append(self.image_paths + image_name)
            class_id = sample['Class'] - 1 # sample[5][0][0] - 1
            if class_id not in self.alphabetical_to_original_label:
              superclass = self.classes[class_id][0].split(' ')[0]
              self.alphabetical_to_original_label[class_id] = {'index': class_id, 'class': self.classes[class_id], 'super_index': self.hierarchic_classes.index(superclass), 'superclass':superclass}
            self.labels.append(class_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Load the sample data and label
        sample = Image.open(self.data[idx]).convert("RGB") # torchvision.io.read_image(self.data[idx])
        label = self.labels[idx]

        # Apply any transformation if provided
        if self.transform:
            sample = self.transform(sample)

        if self.target_transform:
          label = self.target_transform(label)

        return sample, label

if DATASET == 'StandfordCars':
    train_dataset = StandfordCarsDataset(root='/content/dataset', split='train', transform=TRAIN_TRANSFORMS)
    alphabetical_to_original_label = train_dataset.alphabetical_to_original_label
    val_dataset = StandfordCarsDataset(root='/content/dataset', split='val', transform=TEST_TRANSFORMS)
    test_dataset = StandfordCarsDataset(root='/content/dataset', split='test', transform=TEST_TRANSFORMS)
    train_loader_classic  = DataLoader(train_dataset, batch_size=64, shuffle=True)
    val_loader_clasic = DataLoader(val_dataset, batch_size=64, shuffle=False)
    test_loader_clasic = DataLoader(test_dataset, batch_size=64, shuffle=False)
    # print(alphabetical_to_original_label)

# %% [markdown]
# # Comp Cars

# %%
import os
from PIL import Image
import scipy.io
from torch.utils.data import Dataset
import torchvision.transforms as transforms
import random

class CompCarsDataset(Dataset):
    def __init__(self, root_dir='/content/dataset/', split='train', transform=None, target_transform=None):
        """
        Args:
            root_dir (str): Path to dataset (train or test folder).
            mat_file (str): Path to .mat file containing class names.
            transform (callable, optional): Transformations to apply.
        """
        self.root_dir = root_dir
        self.image_dir = root_dir + 'image/'
        self.label_dir = root_dir + 'label/'
        self.split_dir = root_dir + 'train_test_split/'
        self.misc_dir = root_dir + 'misc/'
        self.train_test_split = root_dir + 'train_test_split/classification/'
        self.train_images = [filename for filename in [line.strip() for line in open(self.train_test_split + 'train.txt')]]
        random.shuffle(self.train_images)
        self.test_images = [filename for filename in [line.strip() for line in open(self.train_test_split + 'test.txt')]]
        self.transform = transform
        self.split = split
        self.target_transform = target_transform
        self.makes, self.models = self._load_class_names(root_dir + '/misc/make_model_name.mat')
        # print(len(self.makes))
        # print(len(self.models))

        self.image_paths = []
        self.labels = []

        self.alphabetical_to_original_label = {}

        # Collect all image paths and their corresponding labels
        self.no_classlabels = -1
        self.no_makes = -1
        self.no_models = -1
        for make in os.listdir(self.image_dir):
            make_path = os.path.join(self.image_dir, make)
            self.no_makes += 1
            for model in os.listdir(make_path):
                model_path = os.path.join(make_path, model)
                self.no_models += 1
                for year in os.listdir(model_path):
                    year_path = os.path.join(model_path, year)
                    self.no_classlabels += 1
                    self.alphabetical_to_original_label[self.no_classlabels] = {'index': self.no_classlabels, 'class': self.models[self.no_models], \
                                                                                'super_index': self.no_makes, 'superclass': self.makes[self.no_makes]}
                    for img_name in os.listdir(year_path):
                      img_path = os.path.join(year_path, img_name)
                      img_local_path = make + '/' + model + '/' + year + '/' + img_name
                      if self.split == 'train' or self.split == 'val':
                        if img_local_path in self.train_images:
                          img_index = self.train_images.index(img_local_path)
                          if img_index <= 0.8 * len(self.train_images) and self.split == 'train':
                            self.image_paths.append(img_path)
                            self.labels.append(self.no_classlabels)
                          if img_index > 0.8 * len(self.train_images) and self.split == 'val':
                            self.image_paths.append(img_path)
                            self.labels.append(self.no_classlabels)
                      elif img_local_path in self.test_images and self.split == 'test':
                        self.image_paths.append(img_path)
                        self.labels.append(self.no_classlabels)

        combined = list(zip(self.image_paths, self.labels))
        random.shuffle(combined)
        self.image_paths, self.labels = zip(*combined)

    def _load_class_names(self, mat_file):
        data = scipy.io.loadmat(mat_file)
        makes_names = data.get('make_names')
        if makes_names is not None:
            makes =  [name[0] for name in makes_names.flatten()]
        else:
            raise ValueError("Could not find 'make_names' key in .mat file")
        model_names = data.get('model_names')
        # print(model_names.flatten())
        if model_names is not None:
            models =  [name for name in model_names.flatten()]
        else:
            raise ValueError("Could not find 'model_names' key in .mat file")
        # print(models)
        return makes, models

    def get_alphabetical_to_original_label(self):
        return self.alphabetical_to_original_label

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]

        image = Image.open(img_path).convert("RGB")  # Open image

        if self.transform:
            image = self.transform(image)  # Apply transformations

        if self.target_transform:
            label = self.target_transform(label)

        return image, label

if DATASET == 'CompCars':
    train_dataset = CompCarsDataset(transform=TRAIN_TRANSFORMS, split='train')
    alphabetical_to_original_label = train_dataset.alphabetical_to_original_label
    val_dataset = CompCarsDataset(transform=TEST_TRANSFORMS, split='val')
    test_dataset = CompCarsDataset(transform=TEST_TRANSFORMS, split='test')
    print(len(train_dataset), len(val_dataset), len(test_dataset))
    train_loader_classic  = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader_clasic = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
    test_loader_clasic = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# # Model

# %%
def print_number_of_parameters(model):

  total_params = sum(p.numel() for p in model.parameters())

  # Print the total number of parameters
  print(f"Total number of parameters: {total_params}")

# %%
#@title Flat MobileNetv3

class ClassicMobileNetV3(nn.Module):
    def __init__(self, num_classes=100, pretrained=True, dropout_p=0.5):
        super(ClassicMobileNetV3, self).__init__()

        # Load the pre-trained MobileNetV3 model from torchvision
        self.mobilenet = MODEL(pretrained=pretrained)

        if 'mobilenet_v3' in MODEL_NAME:

          # Modify the first convolutional layer to accept (28, 28) input size
          # self.mobilenet.features[0][0] = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)

          # Extract the number of features from the original classifier
          in_features = self.mobilenet.classifier[-1].in_features

          # Replace the classifier with a new sequence including Dropout
          '''
          self.mobilenet.classifier[-1] = nn.Sequential(
              # nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          '''
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )

          self.mobilenet.classifier[-1] = model_head

        elif 'resnet' in MODEL_NAME:
          in_features = self.mobilenet.fc.in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.fc = model_head
        elif 'swin' in MODEL_NAME:
          self.mobilenet.head = nn.Linear(self.mobilenet.head.in_features, num_classes)
        elif 'vit_b_16' in MODEL_NAME:
          self.mobilenet.heads.head = nn.Linear(self.mobilenet.heads.head.in_features, num_classes)
        elif 'vgg' in MODEL_NAME:
          # ? Redundant path
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Linear(in_features, num_classes)
        elif 'densenet' in MODEL_NAME:
          in_features = self.mobilenet.classifier.in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier = model_head
        elif 'efficientnet' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier[-1] = model_head
        elif 'maxvit' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier[-1] = model_head
        elif 'convnext' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          model_head = nn.Sequential(
              nn.Dropout(p=dropout_p),  # Dropout layer with probability p
              nn.Linear(in_features, num_classes)  # Final fully connected layer
          )
          self.mobilenet.classifier[-1] = model_head
        else:
          assert False


    def forward(self, x):
        return self.mobilenet(x)

classic_model = ClassicMobileNetV3(num_classes=NUM_CLASSES, pretrained=True, dropout_p = DROPOUT)
print_number_of_parameters(classic_model)

input = torch.randn(1, 3, 224, 224)  # Example input
flops, params = profile(classic_model, inputs=(input,))
print(f"FLOPs: {flops}, Parameters: {params}")

# %%
#@title Local Classifier at each hierarchic granularity

class HierarchicMobileNetV3(nn.Module):
    def __init__(self, num_superclasses=20, num_subclasses = [5 for _ in range(20)], pretrained=True, device="cuda"):

      super(HierarchicMobileNetV3, self).__init__()

      self.num_superclasses = num_superclasses
      self.num_subclasses = num_subclasses

      self.superclass_clasifier = ClassicMobileNetV3(num_superclasses, pretrained)

      # self.class_classifiers = [ClassicMobileNetV3(num_subclasses[i], pretrained) for i in range(num_superclasses)]
      self.class_classifiers = nn.ModuleList(
            [ClassicMobileNetV3(num_subclasses[i], pretrained).to(device) for i in range(num_superclasses)]
        )


    def forward(self, x):
        # Predict the superclass
        # x = x.to(next(self.parameters()).device)
        superclass_prediction = self.superclass_clasifier(x)

        # Determine the predicted superclass for each item in the batch
        chosen_superclass = torch.argmax(superclass_prediction, dim=1)

        # Prepare an empty tensor to store the subclass predictions
        batch_size = x.size(0)
        class_predictions = torch.zeros(batch_size, max(self.num_subclasses), device=x.device)

        for i in range(batch_size):
            # For each item in the batch, select the corresponding subclass classifier
            class_predictions[i] = self.class_classifiers[chosen_superclass[i]](x[i].unsqueeze(0))

        return class_predictions, superclass_prediction

# %%
#@title Global Classifier

class GlobalMobileNetV3(nn.Module):
  def __init__(self, num_superclasses=20, num_subclasses = 100, pretrained=True):

      self.num_superclasses = num_superclasses
      self.num_subclasses = num_subclasses

      self.mobilenet = ClassicMobileNetV3(num_superclasses + num_subclasses)

  def forward(self, x):
      return self.mobilenet(x)

# %%
#@title Parallel MT Hierarchical

class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x


class ParallelMultiTaskMobileNetV3(nn.Module):
    def __init__(self, num_superclasses=20, num_subclasses=100, pretrained=True, dropout_p=0.5):
        super(ParallelMultiTaskMobileNetV3, self).__init__()

        # Load the pre-trained MobileNetV3 model from torchvision
        self.mobilenet = MODEL(pretrained=pretrained)
        # Define Dropout layer

        if 'mobilenet_v3' in MODEL_NAME:
          # Modify the first convolutional layer to accept (28, 28) input size
          # self.mobilenet.features[0][0] = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)

          # Extract the number of features from the original classifier
          in_features = self.mobilenet.classifier[-1].in_features

          # Replace the original classifier with an identity layer
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'resnet' in MODEL_NAME:
          in_features = self.mobilenet.fc.in_features
          self.mobilenet.fc = nn.Dropout(p=dropout_p)

        elif 'swin' in MODEL_NAME:
          in_features = self.mobilenet.head.in_features
          self.mobilenet.head = nn.Dropout(p=dropout_p)

        elif 'vit_b_16' in MODEL_NAME:
          in_features = self.mobilenet.heads.head.in_features
          self.mobilenet.heads.head = nn.Dropout(p=dropout_p)

        elif 'vgg' in MODEL_NAME:
          # ? Redundant path
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'densenet' in MODEL_NAME:
          in_features = self.mobilenet.classifier.in_features
          self.mobilenet.classifier = nn.Dropout(p=dropout_p)

        elif 'efficientnet' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'maxvit' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'convnext' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        self.superclass_classifier = nn.Linear(in_features, num_superclasses)
        self.subclass_classifier = nn.Linear(in_features, num_subclasses)

    def forward(self, x):
        # Pass input through the feature extractor
        features = self.mobilenet(x)
        features = torch.flatten(features, 1)  # Flatten the output for the classifier

        # Apply Dropout to the features
        # features = self.dropout(features)

        # Compute superclass and subclass predictions
        superclass_output = self.superclass_classifier(features)
        subclass_output = self.subclass_classifier(features)

        return subclass_output, superclass_output

parallel_model = ParallelMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True, dropout_p = DROPOUT)
print_number_of_parameters(parallel_model)

input = torch.randn(1, 3, 224, 224)  # Example input
flops, params = profile(parallel_model, inputs=(input,))
print(f"FLOPs: {flops}, Parameters: {params}")

# %%
#@title Cascaded MT Hierarchical

class CascadedMultiTaskMobileNetV3(nn.Module):
    def __init__(self, num_superclasses=20, num_subclasses=100, pretrained=True, dropout_p=0.5):
        super(CascadedMultiTaskMobileNetV3, self).__init__()

        # Load the pre-trained MobileNetV3 model from torchvision
        self.mobilenet = MODEL(pretrained=pretrained)

        # Modify the first convolutional layer to accept (28, 28) input size
        # self.mobilenet.features[0][0] = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1, bias=False)
        if 'mobilenet_v3' in MODEL_NAME:
        # Adjust the classifier input size if needed (e.g., due to smaller input size)
          in_features = self.mobilenet.classifier[-1].in_features

          # Replace the original classifier with an identity layer
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'resnet' in MODEL_NAME:
          in_features = self.mobilenet.fc.in_features
          self.mobilenet.fc = nn.Dropout(p=dropout_p)

        elif 'swin' in MODEL_NAME:
          in_features = self.mobilenet.head.in_features
          self.mobilenet.head = nn.Dropout(p=dropout_p)

        elif 'vit_b_16' in MODEL_NAME:
          in_features = self.mobilenet.heads.head.in_features
          self.mobilenet.heads.head = nn.Dropout(p=dropout_p)

        elif 'vgg' in MODEL_NAME:
          # ? Redundant path
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'densenet' in MODEL_NAME:
          in_features = self.mobilenet.classifier.in_features
          self.mobilenet.classifier = nn.Dropout(p=dropout_p)

        elif 'efficientnet' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'maxvit' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        elif 'convnext' in MODEL_NAME:
          in_features = self.mobilenet.classifier[-1].in_features
          self.mobilenet.classifier[-1] = nn.Dropout(p=dropout_p)

        # Superclass classifier
        self.superclass_classifier = nn.Linear(in_features, num_superclasses)

        # Subclass classifier with additional input for superclass prediction
        self.subclass_classifier = nn.Linear(in_features + num_superclasses, num_subclasses)

    def forward(self, x):
        # Pass input through the feature extractor (all layers except the classifier)
        features = self.mobilenet(x)
        features = torch.flatten(features, 1)

        # Apply Dropout to the features
        # features = self.dropout(features)

        # Compute superclass prediction
        superclass_output = self.superclass_classifier(features)

        # Concatenate the superclass prediction with the features
        combined_input = torch.cat((features, superclass_output), dim=1)

        # Apply Dropout to the combined input before subclass classification
        # combined_input = self.dropout(combined_input)

        # Compute subclass prediction using combined input
        subclass_output = self.subclass_classifier(combined_input)

        return subclass_output, superclass_output

cascaded_model = CascadedMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True, dropout_p = DROPOUT)
print_number_of_parameters(cascaded_model)

input = torch.randn(1, 3, 224, 224)  # Example input
flops, params = profile(cascaded_model, inputs=(input,))
print(f"FLOPs: {flops}, Parameters: {params}")

# %%
# Implement Deep Supervised MT

# %% [markdown]
# # Extra Dataloaders

# %%
def get_hierarchic_labels(target):
    superclass_label = alphabetical_to_original_label[target]['super_index']
    target = alphabetical_to_original_label[target]['index']
    return superclass_label, target

# Modify the dataset to return hierarchical labels
if DATASET == 'cifar100':
  train_dataset_hierarchic = torchvision.datasets.CIFAR100(root='/content/dataset/train/', train=True, download=False, transform=TRAIN_TRANSFORMS, target_transform=get_hierarchic_labels)
  train_dataset_hierarchic, val_dataset_hierarchic = random_split(train_dataset_hierarchic, [train_size, val_size])
  test_dataset_hierarchic = torchvision.datasets.CIFAR100(root='/content/dataset/test/', train=False, download=False, transform=TEST_TRANSFORMS, target_transform=get_hierarchic_labels)
elif DATASET == 'StandfordCars':
  train_dataset_hierarchic = StandfordCarsDataset(root='/content/dataset', split='train', transform=TRAIN_TRANSFORMS, target_transform=get_hierarchic_labels)
  val_dataset_hierarchic = StandfordCarsDataset(root='/content/dataset', split='val', transform=TEST_TRANSFORMS, target_transform=get_hierarchic_labels)
  test_dataset_hierarchic = StandfordCarsDataset(root='/content/dataset', split='test', transform=TEST_TRANSFORMS, target_transform=get_hierarchic_labels)
elif DATASET == 'CompCars':
  train_dataset_hierarchic = CompCarsDataset(transform=TRAIN_TRANSFORMS, split='train', target_transform=get_hierarchic_labels)
  val_dataset_hierarchic = CompCarsDataset(transform=TEST_TRANSFORMS, split='val', target_transform=get_hierarchic_labels)
  test_dataset_hierarchic = CompCarsDataset(transform=TEST_TRANSFORMS, split='test', target_transform=get_hierarchic_labels)

# DataLoader for HierarchicMobileNetV3
train_loader_hierarchic = DataLoader(train_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader_hierarchic = DataLoader(val_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
test_loader_hierarchic = DataLoader(test_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %%
def get_global_labels(target):
    superclass_label = alphabetical_to_original_label[target]['super_index']
    global_label = superclass_label * 100 + v
    return global_label

# Load and split the dataset for GlobalMobileNetV3
if DATASET == 'cifar100':
  full_global_dataset = torchvision.datasets. CIFAR100(root='/content/dataset/train/', train=True, download=False, transform=TRAIN_TRANSFORMS, target_transform=get_global_labels)
  train_dataset_global, val_dataset_global = random_split(full_global_dataset, [train_size, val_size])
  test_dataset_global = torchvision.datasets.CIFAR100(root='/content/dataset/test/', train=False, download=False, transform=TEST_TRANSFORMS, target_transform=get_global_labels)
elif DATASET == 'StandfordCars':
   train_dataset_global = StandfordCarsDataset(root='/content/dataset', split='train', transform=TRAIN_TRANSFORMS, target_transform=get_global_labels)
   val_dataset_global = StandfordCarsDataset(root='/content/dataset', split='val', transform=TEST_TRANSFORMS, target_transform=get_global_labels)
   test_dataset_global = StandfordCarsDataset(root='/content/dataset', split='test', transform=TEST_TRANSFORMS, target_transform=get_global_labels)
elif DATASET == 'CompCars':
  train_dataset_global = CompCarsDataset(transform=TRAIN_TRANSFORMS, split='train', target_transform=get_global_labels)
  val_dataset_global = CompCarsDataset(transform=TEST_TRANSFORMS, split='val', target_transform=get_global_labels)
  test_dataset_global = CompCarsDataset(transform=TEST_TRANSFORMS, split='test', target_transform=get_global_labels)

# DataLoader for GlobalMobileNetV3
train_loader_global = DataLoader(train_dataset_global, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader_global = DataLoader(val_dataset_global, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
test_loader_global = DataLoader(test_dataset_global, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %%
# DataLoader for ParallelMultiTaskMobileNetV3 (superclass and subclass)
train_loader_parallel = DataLoader(train_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader_parallel = DataLoader(val_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
test_loader_parallel = DataLoader(test_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %%
# DataLoader for CascadedMultiTaskMobileNetV3 (superclass and subclass)
train_loader_cascaded = DataLoader(train_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader_cascaded = DataLoader(val_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
test_loader_cascaded = DataLoader(test_dataset_hierarchic, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# # Training Procedures

# %%
import torch
import copy
from torch.optim.lr_scheduler import OneCycleLR

def train_classic_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda', max_lr=MAX_LR, phases=['train', 'val']):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss':[], 'test_acc':[],  'train_acc_superclass': [], 'val_acc_superclass': [], 'test_acc_superclass':[]}

    # Calculate total steps for 1CycleLR (total number of batches in training phase)
    total_steps = len(dataloaders['train']) * num_epochs

    # Initialize the 1CycleLR scheduler
    scheduler = OneCycleLR(optimizer, max_lr=max_lr, steps_per_epoch=len(dataloaders['train']), epochs=num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        scheduler.step()  # Update the learning rate according to the 1Cycle policy

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()

                superclass_labels, _ = zip(*[get_hierarchic_labels(int(element)) for element in labels.data])
                superclass_labels = torch.tensor(superclass_labels)

                superclass_preds, _ = zip(*[get_hierarchic_labels(int(element)) for element in preds])
                superclass_preds = torch.tensor(superclass_preds)

                running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()


            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)


            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Save the model if validation loss has decreased
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                model_save_path = BASE_DIR + f'classic_model_epoch.pt'
                torch.save(model.state_dict(), model_save_path)
                print(f'New best model saved with validation loss: {best_val_loss:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    return model, history

# %%
def train_hierarchic_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss':[], 'test_acc':[]}


    device2 = next(model.class_classifiers[0].mobilenet.parameters()).device
    print(f"The first classifier's MobileNetV3 model is on: {device2}")

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)
                    hierarchic_labels = torch.zeros(subclass_labels.shape[0], device=device)
                    for idx, subclass_label in enumerate(subclass_labels):
                      hierarchic_label = alphabetical_to_original_label[subclass_label.item()]['hierarchic_index']
                      hierarchic_labels[idx] = hierarchic_label
                    hierarchic_labels = hierarchic_labels.long()
                    superclass_loss = criterion(superclass_outputs, superclass_labels)
                    subclass_loss = criterion(subclass_outputs, hierarchic_labels)
                    loss = superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum((subclass_preds == hierarchic_labels.data) * (superclass_preds == superclass_labels.data)).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase])
            epoch_acc = running_corrects / len(dataloaders[phase])
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase])

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model, history

# %%
def train_hierarchic_mobilenet_fast(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss':[], 'test_acc':[]}

    # Precompute hierarchic label mapping on CPU for faster indexing
    original_to_hierarchic = torch.tensor(
        [alphabetical_to_original_label[i]['hierarchic_index'] for i in range(len(alphabetical_to_original_label))],
        dtype=torch.long, device=device
    )

    for epoch in range(num_epochs):

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)

                    # Vectorized label conversion
                    hierarchic_labels = original_to_hierarchic[subclass_labels]

                    superclass_loss = criterion(superclass_outputs, superclass_labels)
                    subclass_loss = criterion(subclass_outputs, hierarchic_labels)
                    loss = superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum((subclass_preds == hierarchic_labels) & (superclass_preds == superclass_labels)).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)

            # Correct the calculation of loss and accuracy
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model, history

# %%
'''
def train_global_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda'):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()

            epoch_loss = running_loss / len(dataloaders[phase])
            epoch_acc = running_corrects / len(dataloaders[phase])

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model, history
'''

# %%
import torch
import copy

def train_parallel_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda', max_lr=MAX_LR, phases=['train', 'val']):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'train_acc_superclass': [], 'val_acc_superclass': [], 'test_loss':[], 'test_acc':[], 'test_acc_superclass':[]}

    # Calculate total steps for 1CycleLR (total number of batches in training phase)
    total_steps = len(dataloaders['train']) * num_epochs

    # Initialize the 1CycleLR scheduler
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=max_lr, steps_per_epoch=len(dataloaders['train']), epochs=num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)
                    superclass_loss = criterion(superclass_outputs, superclass_labels) * LOSS_WEIGHTS[1]
                    subclass_loss = criterion(subclass_outputs, subclass_labels) * LOSS_WEIGHTS[0]
                    loss = subclass_loss # superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum(subclass_preds == subclass_labels.data).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        superclass_loss.backward(retain_graph=True)
                        subclass_loss.backward()
                        optimizer.step()
                        scheduler.step()  # Update the learning rate according to the 1Cycle policy

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f} Superclass Acc: {epoch_acc_superclass:.4f}')

            # Save the model if validation loss has decreased
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                model_save_path = BASE_DIR + f'parallel_model_epoch.pt'
                torch.save(model.state_dict(), model_save_path)
                print(f'New best model saved with validation loss: {best_val_loss:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    return model, history

# %%
import torch
import copy

def train_cascaded_mobilenet(model, dataloaders, criterion, optimizer, num_epochs=25, device='cuda', max_lr=MAX_LR, phases=['train', 'val']):
    model = model.to(device)
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'train_acc_superclass': [], 'val_acc_superclass': [], 'test_loss':[], 'test_acc':[], 'test_acc_superclass':[]}

    # Calculate total steps for 1CycleLR (total number of batches in training phase)
    total_steps = len(dataloaders['train']) * num_epochs

    # Initialize the 1CycleLR scheduler
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=max_lr, steps_per_epoch=len(dataloaders['train']), epochs=num_epochs)

    best_model_wts = copy.deepcopy(model.state_dict())
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0
            running_corrects_superclass = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                superclass_labels, subclass_labels = labels
                superclass_labels = superclass_labels.to(device)
                subclass_labels = subclass_labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    subclass_outputs, superclass_outputs = model(inputs)
                    superclass_loss = criterion(superclass_outputs, superclass_labels) * LOSS_WEIGHTS[1]
                    subclass_loss = criterion(subclass_outputs, subclass_labels) * LOSS_WEIGHTS[0]
                    loss = subclass_loss # superclass_loss + subclass_loss

                    _, superclass_preds = torch.max(superclass_outputs, 1)
                    _, subclass_preds = torch.max(subclass_outputs, 1)
                    running_corrects += torch.sum(subclass_preds == subclass_labels.data).item()
                    running_corrects_superclass += torch.sum(superclass_preds == superclass_labels.data).item()

                    if phase == 'train':
                        superclass_loss.backward(retain_graph=True)
                        subclass_loss.backward()
                        optimizer.step()
                        scheduler.step()  # Update the learning rate according to the 1Cycle policy

                running_loss += loss.item() * inputs.size(0)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            epoch_acc_superclass = running_corrects_superclass / len(dataloaders[phase].dataset)

            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            history[f'{phase}_acc_superclass'].append(epoch_acc_superclass)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f} Superclass Acc: {epoch_acc_superclass:.4f}')

            # Save the model if validation loss has decreased
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())
                model_save_path = BASE_DIR + f'cascaded_model_epoch.pt'
                torch.save(model.state_dict(), model_save_path)
                print(f'New best model saved with validation loss: {best_val_loss:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)

    return model, history

# %% [markdown]
# # Train

# %%
# Initialize the model
classic_model = ClassicMobileNetV3(num_classes=NUM_CLASSES, pretrained=True)

# Define the loss function and optimizer
optimizer = optim.Adam(classic_model.parameters(), lr=LR)

# Call the training function for ClassicMobileNetV3
trained_classic_model, classic_history = train_classic_mobilenet(
    model=classic_model,
    dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Swin_S_Weights.IMAGENET1K_V1`. You can also use `weights=Swin_S_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/10
# ----------
# Train Loss: 4.9943 Acc: 0.0282
# Val Loss: 3.7196 Acc: 0.1252
# New best model saved with validation loss: 3.7196
# Epoch 2/10
# ----------
# Train Loss: 3.1732 Acc: 0.2417
# Val Loss: 2.7636 Acc: 0.3006
# New best model saved with validation loss: 2.7636
# Epoch 3/10
# ----------
# Train Loss: 2.3887 Acc: 0.3812
# Val Loss: 2.8723 Acc: 0.2822
# Epoch 4/10
# ----------
# Train Loss: 1.7594 Acc: 0.5271
# Val Loss: 1.9104 Acc: 0.5067
# New best model saved with validation loss: 1.9104
# Epoch 5/10
# ----------
# Train Loss: 1.2136 Acc: 0.6490
# Val Loss: 1.4894 Acc: 0.5853
# New best model saved with validation loss: 1.4894
# Epoch 6/10
# ----------
# Train Loss: 0.6642 Acc: 0.8088
# Val Loss: 1.0048 Acc: 0.7141
# New best model saved with validation loss: 1.0048
# Epoch 7/10
# ----------
# Train Loss: 0.2728 Acc: 0.9232
# Val Loss: 0.7953 Acc: 0.7828
# New best model saved with validation loss: 0.7953
# Epoch 8/10
# ----------
# Train Loss: 0.0934 Acc: 0.9795
# Val Loss: 0.7357 Acc: 0.8049
# New best model saved with validation loss: 0.7357
# Epoch 9/10
# ----------
# Train Loss: 0.0440 Acc: 0.9953
# Val Loss: 0.7098 Acc: 0.8074
# New best model saved with validation loss: 0.7098
# Epoch 10/10
# ----------
# Train Loss: 0.0342 Acc: 0.9961
# Val Loss: 0.7059 Acc: 0.8086
# New best model saved with validation loss: 0.7059

# %%
# hierarchic_model = HierarchicMobileNetV3(num_superclasses=20, num_subclasses=[5 for _ in range(20)], pretrained=True, device=DEVICE)
# optimizer = optim.Adam(hierarchic_model.parameters(), lr=LR)

'''
trained_hierarchic_model, hierarchic_history = train_hierarchic_mobilenet_fast(
    model=hierarchic_model,
    dataloaders={'train': train_loader_hierarchic, 'val': val_loader_hierarchic, 'test':test_loader_hierarchic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
'''
# Out:
# "\ntrained_hierarchic_model, hierarchic_history = train_hierarchic_mobilenet_fast(\n    model=hierarchic_model,\n    dataloaders={'train': train_loader_hierarchic, 'val': val_loader_hierarchic, 'test':test_loader_hierarchic},\n    criterion=criterion,\n    optimizer=optimizer,\n    num_epochs=EPOCHS,\n    device=DEVICE  # or 'cpu' if you don't have a GPU\n)\n"

# %%
parallel_model = ParallelMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True)
optimizer = optim.Adam(parallel_model.parameters(), lr=LR)

# Call the training function for ParallelMultiTaskMobileNetV3
trained_parallel_model, parallel_history = train_parallel_mobilenet(
    model=parallel_model,
    dataloaders={'train': train_loader_parallel, 'val': val_loader_parallel, 'test':test_loader_parallel},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
# Out:
# Epoch 1/10
# ----------
# Train Loss: 4.5688 Acc: 0.0195 Superclass Acc: 0.0982
# Val Loss: 3.7523 Acc: 0.0834 Superclass Acc: 0.2282
# New best model saved with validation loss: 3.7523
# Epoch 2/10
# ----------
# Train Loss: 3.4604 Acc: 0.1302 Superclass Acc: 0.2603
# Val Loss: 3.2382 Acc: 0.1411 Superclass Acc: 0.3202
# New best model saved with validation loss: 3.2382
# Epoch 3/10
# ----------
# Train Loss: 2.9357 Acc: 0.2089 Superclass Acc: 0.3520
# Val Loss: 3.6961 Acc: 0.1337 Superclass Acc: 0.3092
# Epoch 4/10
# ----------
# Train Loss: 2.3978 Acc: 0.3019 Superclass Acc: 0.4224
# Val Loss: 2.2504 Acc: 0.3387 Superclass Acc: 0.4969
# New best model saved with validation loss: 2.2504
# Epoch 5/10
# ----------
# Train Loss: 1.8300 Acc: 0.4352 Superclass Acc: 0.5227
# Val Loss: 1.5434 Acc: 0.5153 Superclass Acc: 0.6209
# New best model saved with validation loss: 1.5434
# Epoch 6/10
# ----------
# Train Loss: 1.1426 Acc: 0.6185 Superclass Acc: 0.6366
# Val Loss: 1.2457 Acc: 0.6049 Superclass Acc: 0.6798
# New best model saved with validation loss: 1.2457
# Epoch 7/10
# ----------
# Train Loss: 0.5949 Acc: 0.7911 Superclass Acc: 0.7616
# Val Loss: 0.9801 Acc: 0.6896 Superclass Acc: 0.7436
# New best model saved with validation loss: 0.9801
# Epoch 8/10
# ----------
# Train Loss: 0.2866 Acc: 0.8958 Superclass Acc: 0.8409
# Val Loss: 0.8726 Acc: 0.7202 Superclass Acc: 0.7951
# New best model saved with validation loss: 0.8726
# Epoch 9/10
# ----------
# Train Loss: 0.1090 Acc: 0.9672 Superclass Acc: 0.9130
# Val Loss: 0.8092 Acc: 0.7571 Superclass Acc: 0.8000
# New best model saved with validation loss: 0.8092
# Epoch 10/10
# ----------
# Train Loss: 0.0733 Acc: 0.9797 Superclass Acc: 0.9284
# Val Loss: 0.8021 Acc: 0.7595 Superclass Acc: 0.8025
# New best model saved with validation loss: 0.8021

# %%
cascaded_model = CascadedMultiTaskMobileNetV3(num_superclasses=NUM_SUPERCLASSES, num_subclasses=NUM_SUBCLASSES, pretrained=True)
optimizer = optim.Adam(cascaded_model.parameters(), lr=LR)

trained_cascaded_model, cascaded_history = train_cascaded_mobilenet(
    model=cascaded_model,
    dataloaders={'train': train_loader_cascaded, 'val': val_loader_cascaded, 'test':test_loader_cascaded},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=EPOCHS,
    device=DEVICE  # or 'cpu' if you don't have a GPU
)
# Out:
# Epoch 1/10
# ----------
# Train Loss: 4.6582 Acc: 0.0144 Superclass Acc: 0.0958
# Val Loss: 4.0078 Acc: 0.0577 Superclass Acc: 0.1804
# New best model saved with validation loss: 4.0078
# Epoch 2/10
# ----------
# Train Loss: 3.6048 Acc: 0.1045 Superclass Acc: 0.2129
# Val Loss: 3.2582 Acc: 0.1571 Superclass Acc: 0.2994
# New best model saved with validation loss: 3.2582
# Epoch 3/10
# ----------
# Train Loss: 3.0315 Acc: 0.1801 Superclass Acc: 0.3156
# Val Loss: 3.1092 Acc: 0.1767 Superclass Acc: 0.3472
# New best model saved with validation loss: 3.1092
# Epoch 4/10
# ----------
# Train Loss: 2.4876 Acc: 0.2738 Superclass Acc: 0.3943
# Val Loss: 2.2424 Acc: 0.3264 Superclass Acc: 0.4564
# New best model saved with validation loss: 2.2424
# Epoch 5/10
# ----------
# Train Loss: 1.8556 Acc: 0.4317 Superclass Acc: 0.4913
# Val Loss: 1.8161 Acc: 0.4258 Superclass Acc: 0.5337
# New best model saved with validation loss: 1.8161
# Epoch 6/10
# ----------
# Train Loss: 1.3822 Acc: 0.5513 Superclass Acc: 0.5710
# Val Loss: 1.2773 Acc: 0.5926 Superclass Acc: 0.6528
# New best model saved with validation loss: 1.2773
# Epoch 7/10
# ----------
# Train Loss: 0.7056 Acc: 0.7451 Superclass Acc: 0.7025
# Val Loss: 1.1085 Acc: 0.6515 Superclass Acc: 0.6822
# New best model saved with validation loss: 1.1085
# Epoch 8/10
# ----------
# Train Loss: 0.3008 Acc: 0.8900 Superclass Acc: 0.8067
# Val Loss: 0.9426 Acc: 0.7104 Superclass Acc: 0.7656
# New best model saved with validation loss: 0.9426
# Epoch 9/10
# ----------
# Train Loss: 0.1292 Acc: 0.9551 Superclass Acc: 0.8777
# Val Loss: 0.8845 Acc: 0.7436 Superclass Acc: 0.7804
# New best model saved with validation loss: 0.8845
# Epoch 10/10
# ----------
# Train Loss: 0.0778 Acc: 0.9763 Superclass Acc: 0.8972
# Val Loss: 0.8819 Acc: 0.7350 Superclass Acc: 0.7730
# New best model saved with validation loss: 0.8819

# %% [markdown]
# # Plot

# %%
import os
import matplotlib.pyplot as plt

# Assuming you have these history dictionaries from your training sessions
# Each dictionary should contain lists like 'train_acc', 'val_acc', 'train_loss', 'val_loss'

# List of histories and labels for the plot
histories = [
    ('Classic', classic_history),
    # ('Hierarchic', hierarchic_history),
    ('Parallel', parallel_history),
    ('Cascaded', cascaded_history)
]

# Function to create a folder and save the plot
def save_plot(history_key, title, ylabel, save_path):
    # Create the directory if it doesn't exist

    # Plot the metric for each model
    plt.figure(figsize=(12, 8))
    for label, history in histories:
      if history_key in history:
        plt.plot(history[history_key], label=f'{label} {title}')

    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel(ylabel)
    plt.legend(loc='best')
    plt.grid(True)

    # Save the plot to the specified path
    plt.savefig(save_path)

    # Optionally, show the plot (you can comment this out if you don't want to display it)
    plt.show()

# Define the base directory where you want to save the plots
base_dir = BASE_DIR

# Save plots for each metric
save_plot('train_acc', 'Training Accuracy', 'Accuracy', os.path.join(base_dir, 'training_accuracy.png'))
save_plot('val_acc', 'Validation Accuracy', 'Accuracy', os.path.join(base_dir, 'validation_accuracy.png'))
save_plot('train_acc_superclass', 'Training Superclass Accuracy', 'Accuracy', os.path.join(base_dir, 'training_accuracy_superclass.png'))
save_plot('val_acc_superclass', 'Validation Superclass Accuracy', 'Accuracy', os.path.join(base_dir, 'validation_accuracy_superclass.png'))
save_plot('train_loss', 'Training Loss', 'Loss', os.path.join(base_dir, 'training_loss.png'))
save_plot('val_loss', 'Validation Loss', 'Loss', os.path.join(base_dir, 'validation_loss.png'))

# %%
with open(os.path.join(base_dir, "history_classic.json"), "w") as f:
    json.dump(classic_history, f)

with open(os.path.join(base_dir, "history_parallel.json"), "w") as f:
    json.dump(parallel_history, f)

with open(os.path.join(base_dir, "history_cascaded.json"), "w") as f:
    json.dump(cascaded_history, f)

# %% [markdown]
# # Test

# %%
optimizer = optim.Adam(trained_classic_model.parameters(), lr=LR)

_, classic_history = train_classic_mobilenet(
    model=trained_classic_model,
    dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
)

classic_accuracy = classic_history['test_acc']
classic_superclass_accuracy = classic_history['test_acc_superclass']

optimizer = optim.Adam(trained_parallel_model.parameters(), lr=LR)

_, parallel_history = train_parallel_mobilenet(
    model=trained_parallel_model,
    dataloaders={'train': train_loader_parallel, 'val': val_loader_parallel, 'test':test_loader_parallel},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
)

parallel_accuracy = parallel_history['test_acc']
parallel_superclass_accuracy = parallel_history['test_acc_superclass']

optimizer = optim.Adam(trained_cascaded_model.parameters(), lr=LR)

_, cascaded_history = train_cascaded_mobilenet(
    model=trained_cascaded_model,
    dataloaders={'train': train_loader_cascaded, 'val': val_loader_cascaded, 'test':test_loader_cascaded},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
)

cascaded_accuracy = cascaded_history['test_acc']
cascaded_superclass_accuracy = cascaded_history['test_acc_superclass']
# Out:
# Epoch 1/1
# ----------
# Test Loss: 0.8622 Acc: 0.7666
# Epoch 1/1
# ----------
# Test Loss: 0.9645 Acc: 0.7383 Superclass Acc: 0.7727
# Epoch 1/1
# ----------
# Test Loss: 0.9891 Acc: 0.7162 Superclass Acc: 0.7303

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Classic Accuracy', 'Parallel Accuracy', 'Cascaded Accuracy']

values = [classic_accuracy[0], parallel_accuracy[0], cascaded_accuracy[0]]

# Create a bar plot
plt.bar(categories, values)

# Add titles and labels
plt.title('Test Accuracy')
plt.xlabel('Method')
plt.ylabel('Accuracy')

for i, value in enumerate(values):
    plt.text(i, value + 0.01, f'{value:.3f}', ha='center', va='bottom')

plt.savefig(os.path.join(base_dir, 'test_accuracy.png'))

plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Classic Acc.', 'Parallel Acc.', 'Cascaded Acc.']

values = [classic_superclass_accuracy[0], parallel_superclass_accuracy[0], cascaded_superclass_accuracy[0]]

# Create a bar plot
plt.bar(categories, values)

# Add titles and labels
plt.title('Test Superclass Accuracy')
plt.xlabel('Method')
plt.ylabel('Accuracy')

for i, value in enumerate(values):
    plt.text(i, value + 0.01, f'{value:.3f}', ha='center', va='bottom')

plt.savefig(os.path.join(base_dir, 'test_superclass_accuracy.png'))

plt.show()

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # Top 5 Accuracy

# %%
dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic}
device = 'cuda'

def topn_accuracy(output, target, n = 5):
    # Get the top 5 predicted class indices
    top5_preds = torch.topk(output, n, dim=1).indices  # (batch_size, 5)

    correct = top5_preds.eq(target.view(-1, 1)).sum().item()  # Count correct top-5 matches

    # Compute accuracy
    return correct / target.size(0)  # Convert to percentage


def top5acc(RoootPath, exp_no, n = 5):
  exp_path = RootPath + str(exp_no) + '/'
  optimizer = optim.Adam(classic_model.parameters(), lr=LR)
  classic_state = torch.load(exp_path + 'classic_model_epoch.pt')
  # print(classic_state.keys())
  classic_model.load_state_dict(classic_state, strict=False)
  parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'), strict=False)
  cascaded_model.load_state_dict(torch.load(exp_path + 'cascaded_model_epoch.pt'), strict=False)

  phase = 'test'
  all_classic_outputs = torch.empty(0, device=device)
  all_parallel_outputs = torch.empty(0, device=device)
  all_cascaded_outputs = torch.empty(0, device=device)
  all_labels = torch.empty(0, dtype=torch.long, device=device)
  classic_model.to(device)
  parallel_model.to(device)
  cascaded_model.to(device)
  classic_model.eval()
  parallel_model.eval()
  cascaded_model.eval()
  for inputs, labels in dataloaders[phase]:
    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()

    with torch.set_grad_enabled(phase == 'train'):
        classic_outputs = classic_model(inputs)
        parallel_outputs = parallel_model(inputs)[0]
        cascaded_outputs = cascaded_model(inputs)[0]

    all_classic_outputs = torch.cat((all_classic_outputs, classic_outputs), dim=0)
    all_parallel_outputs = torch.cat((all_parallel_outputs, parallel_outputs), dim=0)
    all_cascaded_outputs = torch.cat((all_cascaded_outputs, cascaded_outputs), dim=0)
    all_labels = torch.cat((all_labels, labels), dim=0)

  classic_top5_acc = topn_accuracy(all_classic_outputs, all_labels, n)
  parallel_top5_acc = topn_accuracy(all_parallel_outputs, all_labels, n)
  cascaded_top5_acc = topn_accuracy(all_cascaded_outputs, all_labels, n)
  print(n, round(classic_top5_acc, 3), round(parallel_top5_acc, 3), round(cascaded_top5_acc, 3))


RootPath = '/content/drive/MyDrive/New Exps/SamplesH/'
exp_no = 47
top5acc(RootPath, exp_no, 1)
top5acc(RootPath, exp_no, 2)
top5acc(RootPath, exp_no, 3)
top5acc(RootPath, exp_no, 4)
top5acc(RootPath, exp_no, 5)
top5acc(RootPath, exp_no, 6)
top5acc(RootPath, exp_no, 7)
top5acc(RootPath, exp_no, 8)
top5acc(RootPath, exp_no, 9)
top5acc(RootPath, exp_no, 10)

# %% [markdown]
# # Load Test

# %%
ROOT_PATH = '/content/drive/MyDrive/New Exps/SamplesH/'

# %%
for exp_no in range(24, 35):
  exp_path = ROOT_PATH + str(exp_no) + '/' + 'exp_info.json'

  with open(exp_path, 'r') as file:
      data = json.load(file)

  print(json.dumps(data, indent=4))

# %%
def re_evalutate_model(RoootPath, exp_no):
  exp_path = RootPath + str(exp_no) + '/'
  optimizer = optim.Adam(classic_model.parameters(), lr=LR)
  classic_model.load_state_dict(torch.load(exp_path + 'classic_model_epoch.pt'))
  parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'))
  cascaded_model.load_state_dict(torch.load(exp_path + 'cascaded_model_epoch.pt'))
  _, classic_history = train_classic_mobilenet(
    model=classic_model,
    dataloaders={'train': train_loader_classic, 'val': val_loader_clasic, 'test':test_loader_clasic},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
  )

  _, parallel_history = train_parallel_mobilenet(
    model=classic_model,
    dataloaders={'train': train_loader_parallel, 'val': val_loader_parallel, 'test':test_loader_parallel},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
  )

  _, cascaded_history = train_cascaded_mobilenet(
    model=classic_model,
    dataloaders={'train': train_loader_cascaded, 'val': val_loader_cascaded, 'test':test_loader_cascaded},
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=1,
    device=DEVICE,  # or 'cpu' if you don't have a GPU
    phases = ['test']
  )

  classic_accuracy = classic_history['test_acc']
  classic_superclass_accuracy = classic_history['test_acc_superclass']
  parallel_accuracy = parallel_history['test_acc']
  parallel_superclass_accuracy = parallel_history['test_acc_superclass']
  cascaded_accuracy = cascaded_history['test_acc']
  cascaded_superclass_accuracy = cascaded_history['test_acc_superclass']
  print(exp_no, classic_accuracy, classic_superclass_accuracy)
  return classic_history, parallel_history, cascaded_history

# %%
import matplotlib.pyplot as plt

RootPath = '/content/drive/MyDrive/New Exps/SamplesH/'

# max_vit_list = [43, 48, 52, 55, 58, 61]
# conv_next_list = [44, 47, 53, 56, 59, 62]
dense_list = [92, 93]

for exp_no in dense_list:
  exp_path = RootPath + str(exp_no) + '/'
  classic_history, parallel_history, cascaded_history = re_evalutate_model(RootPath, exp_no)
  base_dir = exp_path
  # Sample data
  categories = ['Classic Accuracy', 'Parallel Accuracy', 'Cascaded Accuracy']

  values = [classic_accuracy[0], parallel_accuracy[0], cascaded_accuracy[0]]

  # Create a bar plot
  plt.bar(categories, values)

  # Add titles and labels
  plt.title('Test Accuracy')
  plt.xlabel('Method')
  plt.ylabel('Accuracy')

  for i, value in enumerate(values):
      plt.text(i, value + 0.01, f'{value:.3f}', ha='center', va='bottom')

  plt.savefig(os.path.join(base_dir, 'test_accuracy.png'))

  plt.show()
  plt.close()

  import matplotlib.pyplot as plt

  # Sample data
  categories = ['Classic Acc.', 'Parallel Acc.', 'Cascaded Acc.']

  values = [classic_superclass_accuracy[0], parallel_superclass_accuracy[0], cascaded_superclass_accuracy[0]]

  # Create a bar plot
  plt.bar(categories, values)

  # Add titles and labels
  plt.title('Test Superclass Accuracy')
  plt.xlabel('Method')
  plt.ylabel('Accuracy')

  for i, value in enumerate(values):
      plt.text(i, value + 0.01, f'{value:.3f}', ha='center', va='bottom')

  plt.savefig(os.path.join(base_dir, 'test_superclass_accuracy.png'))

  plt.show()
  plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e8e5905c22fb> in <cell line: 0>()
#       7 for exp_no in dense_list:
#       8   # exp_path = RootPath + str(exp_no) + '/'
# ----> 9   classic_history, parallel_history, cascaded_history = re_evalutate_model(RootPath, exp_no)
#      10
#      11
#
# <ipython-input-1-2070f06296a4> in re_evalutate_model(RoootPath, exp_no)
#       1 def re_evalutate_model(RoootPath, exp_no):
#       2   exp_path = RootPath + str(exp_no) + '/'
# ----> 3   optimizer = optim.Adam(classic_model.parameters(), lr=LR)
#       4   classic_model.load_state_dict(torch.load(exp_path + 'classic_model_epoch.pt'))
#       5   # parallel_model.load_state_dict(torch.load(exp_path + 'parallel_model_epoch.pt'))
#
# NameError: name 'classic_model' is not defined
